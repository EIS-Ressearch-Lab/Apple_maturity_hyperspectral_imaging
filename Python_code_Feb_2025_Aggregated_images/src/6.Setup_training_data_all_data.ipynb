# %%
import re
import glob
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.preprocessing import OneHotEncoder

# %%
img_size = 30
# img_size = 50
if img_size == 30:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/30px_files/'
elif img_size == 50: 
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/50px_files/'


# Brix
BB_NZ2023_y_brix = np.load(f'{y_file_path}BB_NZ2023_y_brix.npy')
CX_NZ2023_y_brix = np.load(f'{y_file_path}CX_NZ2023_y_brix.npy')
FJ_NZ2023_y_brix = np.load(f'{y_file_path}FJ_NZ2023_y_brix.npy')
GL_NZ2023_y_brix = np.load(f'{y_file_path}GL_NZ2023_y_brix.npy')
GD_NZ2023_y_brix = np.load(f'{y_file_path}GD_NZ2023_y_brix.npy')
BB_NZ2024_y_brix = np.load(f'{y_file_path}BB_NZ2024_y_brix.npy')
FJ_NZ2024_y_brix = np.load(f'{y_file_path}FJ_NZ2024_y_brix.npy')
GL_NZ2024_y_brix = np.load(f'{y_file_path}GL_NZ2024_y_brix.npy')
GD_NZ2024_y_brix = np.load(f'{y_file_path}GD_NZ2024_y_brix.npy')
BB_UK2024_y_brix = np.load(f'{y_file_path}BB_UK2024_y_brix.npy')
CX_UK2024_y_brix = np.load(f'{y_file_path}CX_UK2024_y_brix.npy')
FJ_UK2024_y_brix = np.load(f'{y_file_path}FJ_UK2024_y_brix.npy')
GL_UK2024_y_brix = np.load(f'{y_file_path}GL_UK2024_y_brix.npy')
GD_UK2024_y_brix = np.load(f'{y_file_path}GD_UK2024_y_brix.npy')
JZ_UK2024_y_brix = np.load(f'{y_file_path}JZ_UK2024_y_brix.npy')




# Firmness
BB_NZ2023_y_firmness = np.load(f'{y_file_path}BB_NZ2023_y_firmness.npy')
CX_NZ2023_y_firmness = np.load(f'{y_file_path}CX_NZ2023_y_firmness.npy')
FJ_NZ2023_y_firmness = np.load(f'{y_file_path}FJ_NZ2023_y_firmness.npy')
GL_NZ2023_y_firmness = np.load(f'{y_file_path}GL_NZ2023_y_firmness.npy')
GD_NZ2023_y_firmness = np.load(f'{y_file_path}GD_NZ2023_y_firmness.npy')
BB_NZ2024_y_firmness = np.load(f'{y_file_path}BB_NZ2024_y_firmness.npy')
FJ_NZ2024_y_firmness = np.load(f'{y_file_path}FJ_NZ2024_y_firmness.npy')
GL_NZ2024_y_firmness = np.load(f'{y_file_path}GL_NZ2024_y_firmness.npy')
GD_NZ2024_y_firmness = np.load(f'{y_file_path}GD_NZ2024_y_firmness.npy')
BB_UK2024_y_firmness = np.load(f'{y_file_path}BB_UK2024_y_firmness.npy')
CX_UK2024_y_firmness = np.load(f'{y_file_path}CX_UK2024_y_firmness.npy')
FJ_UK2024_y_firmness = np.load(f'{y_file_path}FJ_UK2024_y_firmness.npy')
GL_UK2024_y_firmness = np.load(f'{y_file_path}GL_UK2024_y_firmness.npy')
GD_UK2024_y_firmness = np.load(f'{y_file_path}GD_UK2024_y_firmness.npy')
JZ_UK2024_y_firmness = np.load(f'{y_file_path}JZ_UK2024_y_firmness.npy')




# Starch
BB_NZ2023_y_starch = np.load(f'{y_file_path}BB_NZ2023_y_starch.npy')
CX_NZ2023_y_starch = np.load(f'{y_file_path}CX_NZ2023_y_starch.npy')
FJ_NZ2023_y_starch = np.load(f'{y_file_path}FJ_NZ2023_y_starch.npy')
GL_NZ2023_y_starch = np.load(f'{y_file_path}GL_NZ2023_y_starch.npy')
GD_NZ2023_y_starch = np.load(f'{y_file_path}GD_NZ2023_y_starch.npy')
BB_NZ2024_y_starch = np.load(f'{y_file_path}BB_NZ2024_y_starch.npy')
FJ_NZ2024_y_starch = np.load(f'{y_file_path}FJ_NZ2024_y_starch.npy')
GL_NZ2024_y_starch = np.load(f'{y_file_path}GL_NZ2024_y_starch.npy')
GD_NZ2024_y_starch = np.load(f'{y_file_path}GD_NZ2024_y_starch.npy')
BB_UK2024_y_starch = np.load(f'{y_file_path}BB_UK2024_y_starch.npy')
CX_UK2024_y_starch = np.load(f'{y_file_path}CX_UK2024_y_starch.npy')
FJ_UK2024_y_starch = np.load(f'{y_file_path}FJ_UK2024_y_starch.npy')
GL_UK2024_y_starch = np.load(f'{y_file_path}GL_UK2024_y_starch.npy')
GD_UK2024_y_starch = np.load(f'{y_file_path}GD_UK2024_y_starch.npy')
JZ_UK2024_y_starch = np.load(f'{y_file_path}JZ_UK2024_y_starch.npy')

BB_side_A_y_brix = np.load('BB_side_A_y_brix.npy')
CX_side_A_y_brix = np.load('CX_side_A_y_brix.npy')
FJ_side_A_y_brix = np.load('FJ_side_A_y_brix.npy')
GL_side_A_y_brix = np.load('GL_side_A_y_brix.npy')
GD_side_A_y_brix = np.load('GD_side_A_y_brix.npy')
JZ_side_A_y_brix = np.load('JZ_side_A_y_brix.npy')
BB_side_A_y_firmness = np.load('BB_side_A_y_firmness.npy')
CX_side_A_y_firmness = np.load('CX_side_A_y_firmness.npy')
FJ_side_A_y_firmness = np.load('FJ_side_A_y_firmness.npy')
GL_side_A_y_firmness = np.load('GL_side_A_y_firmness.npy')
GD_side_A_y_firmness = np.load('GD_side_A_y_firmness.npy')
JZ_side_A_y_firmness = np.load('JZ_side_A_y_firmness.npy')
BB_side_A_y_starch = np.load('BB_side_A_y_starch.npy')
CX_side_A_y_starch = np.load('CX_side_A_y_starch.npy')
FJ_side_A_y_starch = np.load('FJ_side_A_y_starch.npy')
GL_side_A_y_starch = np.load('GL_side_A_y_starch.npy')
GD_side_A_y_starch = np.load('GD_side_A_y_starch.npy')
JZ_side_A_y_starch = np.load('JZ_side_A_y_starch.npy')


var3_folder = 'all_3_variables/' # 30px files uses the same files as 50px files
BB_NZ2023_y_3_var = np.load(f'{y_file_path}{var3_folder}BB_NZ2023_y_3_var.npy')
CX_NZ2023_y_3_var = np.load(f'{y_file_path}{var3_folder}CX_NZ2023_y_3_var.npy')
FJ_NZ2023_y_3_var = np.load(f'{y_file_path}{var3_folder}FJ_NZ2023_y_3_var.npy')
GL_NZ2023_y_3_var = np.load(f'{y_file_path}{var3_folder}GL_NZ2023_y_3_var.npy')
GD_NZ2023_y_3_var = np.load(f'{y_file_path}{var3_folder}GD_NZ2023_y_3_var.npy')
BB_NZ2024_y_3_var = np.load(f'{y_file_path}{var3_folder}BB_NZ2024_y_3_var.npy')
FJ_NZ2024_y_3_var = np.load(f'{y_file_path}{var3_folder}FJ_NZ2024_y_3_var.npy')
GL_NZ2024_y_3_var = np.load(f'{y_file_path}{var3_folder}GL_NZ2024_y_3_var.npy')
GD_NZ2024_y_3_var = np.load(f'{y_file_path}{var3_folder}GD_NZ2024_y_3_var.npy')
BB_UK2024_y_3_var = np.load(f'{y_file_path}{var3_folder}BB_UK2024_y_3_var.npy')
CX_UK2024_y_3_var = np.load(f'{y_file_path}{var3_folder}CX_UK2024_y_3_var.npy')
FJ_UK2024_y_3_var = np.load(f'{y_file_path}{var3_folder}FJ_UK2024_y_3_var.npy')
GL_UK2024_y_3_var = np.load(f'{y_file_path}{var3_folder}GL_UK2024_y_3_var.npy')
GD_UK2024_y_3_var = np.load(f'{y_file_path}{var3_folder}GD_UK2024_y_3_var.npy')
JZ_UK2024_y_3_var = np.load(f'{y_file_path}{var3_folder}JZ_UK2024_y_3_var.npy')

# %%
print(BB_NZ2024_y_starch.max())
print(FJ_NZ2024_y_starch.max())
print(GL_NZ2024_y_starch.max())
print(GD_NZ2024_y_3_var)
# Out:
# 100
# 99
# 100
# [[13.     7.175 39.   ]
#  [13.66   6.82  21.   ]
#  [12.51   8.55  84.   ]
#  ...
#  [14.36   7.825 43.   ]
#  [13.48   6.83  35.   ]
#  [12.4    6.79  42.   ]]

# %%
import pandas as pd
BB_NZ2023_y_firmness_df = pd.DataFrame(BB_NZ2023_y_firmness)
CX_NZ2023_y_firmness_df = pd.DataFrame(CX_NZ2023_y_firmness)
FJ_NZ2023_y_firmness_df = pd.DataFrame(FJ_NZ2023_y_firmness)
GL_NZ2023_y_firmness_df = pd.DataFrame(GL_NZ2023_y_firmness)
GD_NZ2023_y_firmness_df = pd.DataFrame(GD_NZ2023_y_firmness)
BB_NZ2024_y_firmness_df = pd.DataFrame(BB_NZ2024_y_firmness)
FJ_NZ2024_y_firmness_df = pd.DataFrame(FJ_NZ2024_y_firmness)
GL_NZ2024_y_firmness_df = pd.DataFrame(GL_NZ2024_y_firmness)
GD_NZ2024_y_firmness_df = pd.DataFrame(GD_NZ2024_y_firmness)
BB_UK2024_y_firmness_df = pd.DataFrame(BB_UK2024_y_firmness)
CX_UK2024_y_firmness_df = pd.DataFrame(CX_UK2024_y_firmness)
FJ_UK2024_y_firmness_df = pd.DataFrame(FJ_UK2024_y_firmness)
GL_UK2024_y_firmness_df = pd.DataFrame(GL_UK2024_y_firmness)
GD_UK2024_y_firmness_df = pd.DataFrame(GD_UK2024_y_firmness)
JZ_UK2024_y_firmness_df = pd.DataFrame(JZ_UK2024_y_firmness)

BB_side_A_y_brix_df = pd.DataFrame(BB_side_A_y_brix)
CX_side_A_y_brix_df = pd.DataFrame(CX_side_A_y_brix)
FJ_side_A_y_brix_df = pd.DataFrame(FJ_side_A_y_brix)
GL_side_A_y_brix_df = pd.DataFrame(GL_side_A_y_brix)
GD_side_A_y_brix_df = pd.DataFrame(GD_side_A_y_brix)
JZ_side_A_y_brix_df = pd.DataFrame(JZ_side_A_y_brix)
BB_side_A_y_firmness_df = pd.DataFrame(BB_side_A_y_firmness)
CX_side_A_y_firmness_df = pd.DataFrame(CX_side_A_y_firmness)
FJ_side_A_y_firmness_df = pd.DataFrame(FJ_side_A_y_firmness)
GL_side_A_y_firmness_df = pd.DataFrame(GL_side_A_y_firmness)
GD_side_A_y_firmness_df = pd.DataFrame(GD_side_A_y_firmness)
JZ_side_A_y_firmness_df = pd.DataFrame(JZ_side_A_y_firmness)
BB_side_A_y_starch_df = pd.DataFrame(BB_side_A_y_starch)
CX_side_A_y_starch_df = pd.DataFrame(CX_side_A_y_starch)
FJ_side_A_y_starch_df = pd.DataFrame(FJ_side_A_y_starch)
GL_side_A_y_starch_df = pd.DataFrame(GL_side_A_y_starch)
GD_side_A_y_starch_df = pd.DataFrame(GD_side_A_y_starch)
JZ_side_A_y_starch_df = pd.DataFrame(JZ_side_A_y_starch)


BB_NZ2023_y_3_var_df = pd.DataFrame(BB_NZ2023_y_3_var)
CX_NZ2023_y_3_var_df = pd.DataFrame(CX_NZ2023_y_3_var)
FJ_NZ2023_y_3_var_df = pd.DataFrame(FJ_NZ2023_y_3_var)
GL_NZ2023_y_3_var_df = pd.DataFrame(GL_NZ2023_y_3_var)
GD_NZ2023_y_3_var_df = pd.DataFrame(GD_NZ2023_y_3_var)
BB_NZ2024_y_3_var_df = pd.DataFrame(BB_NZ2024_y_3_var)
FJ_NZ2024_y_3_var_df = pd.DataFrame(FJ_NZ2024_y_3_var)
GL_NZ2024_y_3_var_df = pd.DataFrame(GL_NZ2024_y_3_var)
GD_NZ2024_y_3_var_df = pd.DataFrame(GD_NZ2024_y_3_var)
BB_UK2024_y_3_var_df = pd.DataFrame(BB_UK2024_y_3_var)
CX_UK2024_y_3_var_df = pd.DataFrame(CX_UK2024_y_3_var)
FJ_UK2024_y_3_var_df = pd.DataFrame(FJ_UK2024_y_3_var)
GL_UK2024_y_3_var_df = pd.DataFrame(GL_UK2024_y_3_var)
GD_UK2024_y_3_var_df = pd.DataFrame(GD_UK2024_y_3_var)
JZ_UK2024_y_3_var_df = pd.DataFrame(JZ_UK2024_y_3_var)

# %%
print(type(BB_NZ2023_y_firmness_df))
print(type(CX_NZ2023_y_firmness_df))
print(type(FJ_NZ2023_y_firmness_df))
print(type(GL_NZ2023_y_firmness_df))
print(type(GD_NZ2023_y_firmness_df))
print(type(BB_NZ2024_y_firmness_df))
print(type(FJ_NZ2024_y_firmness_df))
print(type(GL_NZ2024_y_firmness_df))
print(type(GD_NZ2024_y_firmness_df))
print(type(BB_UK2024_y_firmness_df))
print(type(CX_UK2024_y_firmness_df))
print(type(FJ_UK2024_y_firmness_df))
print(type(GL_UK2024_y_firmness_df))
print(type(GD_UK2024_y_firmness_df))
print(type(JZ_UK2024_y_firmness_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
NZ2023 =  pd.concat([BB_NZ2023_y_firmness_df,
CX_NZ2023_y_firmness_df,
FJ_NZ2023_y_firmness_df,
GL_NZ2023_y_firmness_df,
GD_NZ2023_y_firmness_df])
NZ2024 = pd.concat([BB_NZ2024_y_firmness_df,
FJ_NZ2024_y_firmness_df,
GL_NZ2024_y_firmness_df,
GD_NZ2024_y_firmness_df])
UK2024 = pd.concat([BB_UK2024_y_firmness_df,
CX_UK2024_y_firmness_df,
FJ_UK2024_y_firmness_df,
GL_UK2024_y_firmness_df,
GD_UK2024_y_firmness_df,
JZ_UK2024_y_firmness_df])

# %%
print(UK2024.iloc[:, 0].describe())
# Out:
# count    10245.000000
# mean         8.723443
# std          1.265562
# min          2.967170
# 25%          7.835142
# 50%          8.766857
# 75%          9.553976
# max         14.548291
# Name: 0, dtype: float64

# %%
if img_size == 30:
    x_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/x_files_May2025/30px_files/'
elif img_size == 50:
    x_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/x_files_May2025/50px_files/'


BB_NZ2023_x = np.load(f'{x_file_path}BB_NZ2023_x.npy')
CX_NZ2023_x = np.load(f'{x_file_path}CX_NZ2023_x.npy')
FJ_NZ2023_x = np.load(f'{x_file_path}FJ_NZ2023_x.npy')
GL_NZ2023_x = np.load(f'{x_file_path}GL_NZ2023_x.npy')
GD_NZ2023_x = np.load(f'{x_file_path}GD_NZ2023_x.npy')
BB_NZ2024_x = np.load(f'{x_file_path}BB_NZ2024_x.npy')
FJ_NZ2024_x = np.load(f'{x_file_path}FJ_NZ2024_x.npy')
GL_NZ2024_x = np.load(f'{x_file_path}GL_NZ2024_x.npy')
GD_NZ2024_x = np.load(f'{x_file_path}GD_NZ2024_x.npy')
BB_UK2024_x = np.load(f'{x_file_path}BB_UK2024_x.npy')
CX_UK2024_x = np.load(f'{x_file_path}CX_UK2024_x.npy')
FJ_UK2024_x = np.load(f'{x_file_path}FJ_UK2024_x.npy')
GL_UK2024_x = np.load(f'{x_file_path}GL_UK2024_x.npy')
GD_UK2024_x = np.load(f'{x_file_path}GD_UK2024_x.npy')
JZ_UK2024_x = np.load(f'{x_file_path}JZ_UK2024_x.npy')

Side_A_BB_x = np.load(f'{x_file_path}Side_A_BB_x.npy')
Side_A_CX_x = np.load(f'{x_file_path}Side_A_CX_x.npy')
Side_A_FJ_x = np.load(f'{x_file_path}Side_A_FJ_x.npy')
Side_A_GL_x = np.load(f'{x_file_path}Side_A_GL_x.npy')
Side_A_GD_x = np.load(f'{x_file_path}Side_A_GD_x.npy')
Side_A_JZ_x = np.load(f'{x_file_path}Side_A_JZ_x.npy')

# %%
print(BB_NZ2023_x[:3])
# Out:
# ['30x/NZ2023/30px_Braeburn_1655_1582.npy'
#  '30x/NZ2023/30px_Braeburn_1656_1583.npy'
#  '30x/NZ2023/30px_Braeburn_1657_1584.npy']

# %%
print(Side_A_CX_x)
# Out:
# ["30x/NZ2023/30px_Cox's Orange Pippin_944_885.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_945_886.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_946_887.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_947_888.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_948_889.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_949_890.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_950_891.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_951_892.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_960_893.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_961_894.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_962_895.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_963_896.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_964_897.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_965_898.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_966_899.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_967_900.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_968_901.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_969_902.npy"
# ...

# %%
print(CX_NZ2023_x[0:3])
# Out:
# ["30x/NZ2023/30px_Cox's Orange Pippin_944_885.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_945_886.npy"
#  "30x/NZ2023/30px_Cox's Orange Pippin_946_887.npy"]

# %%
encoder = OneHotEncoder(categories=[['BB', 'CX', 'FJ', 'GL', 'GD', 'JZ']], handle_unknown='ignore', sparse_output=False)

# %% [markdown]
# ## NZ2023

# %%
# Brix only NZ2023

Braeburn_X_train_NZ2023_1_Brix, Braeburn_X_validate_NZ2023_Brix, Braeburn_Y_train_NZ2023_1_Brix, Braeburn_Y_validate_NZ2023_Brix = train_test_split(BB_NZ2023_x, BB_NZ2023_y_brix, test_size = 0.02, random_state = 42)
Cox_X_train_NZ2023_1_Brix, Cox_X_validate_NZ2023_Brix, Cox_Y_train_NZ2023_1_Brix, Cox_Y_validate_NZ2023_Brix = train_test_split(CX_NZ2023_x, CX_NZ2023_y_brix, test_size = 0.02, random_state = 42)
Fuji_X_train_NZ2023_1_Brix, Fuji_X_validate_NZ2023_Brix, Fuji_Y_train_NZ2023_1_Brix, Fuji_Y_validate_NZ2023_Brix = train_test_split(FJ_NZ2023_x, FJ_NZ2023_y_brix, test_size = 0.02, random_state = 42)
Gala_X_train_NZ2023_1_Brix, Gala_X_validate_NZ2023_Brix, Gala_Y_train_NZ2023_1_Brix, Gala_Y_validate_NZ2023_Brix = train_test_split(GL_NZ2023_x, GL_NZ2023_y_brix, test_size = 0.02, random_state = 42)
GD_X_train_NZ2023_1_Brix, GD_X_validate_NZ2023_Brix, GD_Y_train_NZ2023_1_Brix, GD_Y_validate_NZ2023_Brix = train_test_split(GD_NZ2023_x, GD_NZ2023_y_brix, test_size = 0.02, random_state = 42)

Braeburn_X_train_NZ2023_Brix, Braeburn_X_test_NZ2023_Brix, Braeburn_Y_train_NZ2023_Brix, Braeburn_Y_test_NZ2023_Brix = train_test_split(Braeburn_X_train_NZ2023_1_Brix, Braeburn_Y_train_NZ2023_1_Brix, test_size = 0.18, random_state = 42)
Cox_X_train_NZ2023_Brix, Cox_X_test_NZ2023_Brix, Cox_Y_train_NZ2023_Brix, Cox_Y_test_NZ2023_Brix = train_test_split(Cox_X_train_NZ2023_1_Brix, Cox_Y_train_NZ2023_1_Brix, test_size = 0.18, random_state = 42)
Fuji_X_train_NZ2023_Brix, Fuji_X_test_NZ2023_Brix, Fuji_Y_train_NZ2023_Brix, Fuji_Y_test_NZ2023_Brix = train_test_split(Fuji_X_train_NZ2023_1_Brix, Fuji_Y_train_NZ2023_1_Brix, test_size = 0.18, random_state = 42)
Gala_X_train_NZ2023_Brix, Gala_X_test_NZ2023_Brix, Gala_Y_train_NZ2023_Brix, Gala_Y_test_NZ2023_Brix = train_test_split(Gala_X_train_NZ2023_1_Brix, Gala_Y_train_NZ2023_1_Brix, test_size = 0.18, random_state = 42)
GD_X_train_NZ2023_Brix, GD_X_test_NZ2023_Brix, GD_Y_train_NZ2023_Brix, GD_Y_test_NZ2023_Brix = train_test_split(GD_X_train_NZ2023_1_Brix, GD_Y_train_NZ2023_1_Brix, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_NZ2023_Brix = np.concatenate((Braeburn_Y_train_NZ2023_Brix, Cox_Y_train_NZ2023_Brix, Fuji_Y_train_NZ2023_Brix, Gala_Y_train_NZ2023_Brix, GD_Y_train_NZ2023_Brix), axis=0)
Y_validate_NZ2023_Brix = np.concatenate((Braeburn_Y_validate_NZ2023_Brix, Cox_Y_validate_NZ2023_Brix, Fuji_Y_validate_NZ2023_Brix, Gala_Y_validate_NZ2023_Brix, GD_Y_validate_NZ2023_Brix), axis=0)
Y_test_NZ2023_Brix = np.concatenate((Braeburn_Y_test_NZ2023_Brix, Cox_Y_test_NZ2023_Brix, Fuji_Y_test_NZ2023_Brix, Gala_Y_test_NZ2023_Brix, GD_Y_test_NZ2023_Brix), axis=0)
X_train_NZ2023_Brix = np.concatenate((Braeburn_X_train_NZ2023_Brix, Cox_X_train_NZ2023_Brix, Fuji_X_train_NZ2023_Brix, Gala_X_train_NZ2023_Brix, GD_X_train_NZ2023_Brix), axis=0)
X_validate_NZ2023_Brix = np.concatenate((Braeburn_X_validate_NZ2023_Brix, Cox_X_validate_NZ2023_Brix, Fuji_X_validate_NZ2023_Brix, Gala_X_validate_NZ2023_Brix, GD_X_validate_NZ2023_Brix), axis=0)
X_test_NZ2023_Brix = np.concatenate((Braeburn_X_test_NZ2023_Brix, Cox_X_test_NZ2023_Brix, Fuji_X_test_NZ2023_Brix, Gala_X_test_NZ2023_Brix, GD_X_test_NZ2023_Brix), axis=0)

# %%
# Hot encoding

Braeburn_X_train_NZ2023_Brix_labels = np.array(["BB"]*len(Braeburn_X_train_NZ2023_Brix))
Cox_X_train_NZ2023_Brix_labels = np.array(["CX"]*len(Cox_X_train_NZ2023_Brix))
Fuji_X_train_NZ2023_Brix_labels = np.array(["FJ"]*len(Fuji_X_train_NZ2023_Brix))
Gala_X_train_NZ2023_Brix_labels = np.array(["GL"]*len(Gala_X_train_NZ2023_Brix))
GD_X_train_NZ2023_Brix_labels = np.array(["GD"]*len(GD_X_train_NZ2023_Brix))
Braeburn_X_test_NZ2023_Brix_labels = np.array(["BB"]*len(Braeburn_X_test_NZ2023_Brix))
Cox_X_test_NZ2023_Brix_labels = np.array(["CX"]*len(Cox_X_test_NZ2023_Brix))
Fuji_X_test_NZ2023_Brix_labels = np.array(["FJ"]*len(Fuji_X_test_NZ2023_Brix))
Gala_X_test_NZ2023_Brix_labels = np.array(["GL"]*len(Gala_X_test_NZ2023_Brix))
GD_X_test_NZ2023_Brix_labels = np.array(["GD"]*len(GD_X_test_NZ2023_Brix))
Braeburn_X_validate_NZ2023_Brix_labels = np.array(["BB"]*len(Braeburn_X_validate_NZ2023_Brix))
Cox_X_validate_NZ2023_Brix_labels = np.array(["CX"]*len(Cox_X_validate_NZ2023_Brix))
Fuji_X_validate_NZ2023_Brix_labels = np.array(["FJ"]*len(Fuji_X_validate_NZ2023_Brix))
Gala_X_validate_NZ2023_Brix_labels = np.array(["GL"]*len(Gala_X_validate_NZ2023_Brix))
GD_X_validate_NZ2023_Brix_labels = np.array(["GD"]*len(GD_X_validate_NZ2023_Brix))

Braeburn_X_train_NZ2023_Brix_encoded = encoder.fit_transform(Braeburn_X_train_NZ2023_Brix_labels.reshape(-1, 1))
Cox_X_train_NZ2023_Brix_encoded = encoder.fit_transform(Cox_X_train_NZ2023_Brix_labels.reshape(-1, 1))
Fuji_X_train_NZ2023_Brix_encoded = encoder.fit_transform(Fuji_X_train_NZ2023_Brix_labels.reshape(-1, 1))
Gala_X_train_NZ2023_Brix_encoded = encoder.fit_transform(Gala_X_train_NZ2023_Brix_labels.reshape(-1, 1))
GD_X_train_NZ2023_Brix_encoded = encoder.fit_transform(GD_X_train_NZ2023_Brix_labels.reshape(-1, 1))
Braeburn_X_test_NZ2023_Brix_encoded = encoder.fit_transform(Braeburn_X_test_NZ2023_Brix_labels.reshape(-1, 1))
Cox_X_test_NZ2023_Brix_encoded = encoder.fit_transform(Cox_X_test_NZ2023_Brix_labels.reshape(-1, 1))
Fuji_X_test_NZ2023_Brix_encoded = encoder.fit_transform(Fuji_X_test_NZ2023_Brix_labels.reshape(-1, 1))
Gala_X_test_NZ2023_Brix_encoded = encoder.fit_transform(Gala_X_test_NZ2023_Brix_labels.reshape(-1, 1))
GD_X_test_NZ2023_Brix_encoded = encoder.fit_transform(GD_X_test_NZ2023_Brix_labels.reshape(-1, 1))
Braeburn_X_validate_NZ2023_Brix_encoded = encoder.fit_transform(Braeburn_X_validate_NZ2023_Brix_labels.reshape(-1, 1))
Cox_X_validate_NZ2023_Brix_encoded = encoder.fit_transform(Cox_X_validate_NZ2023_Brix_labels.reshape(-1, 1))
Fuji_X_validate_NZ2023_Brix_encoded = encoder.fit_transform(Fuji_X_validate_NZ2023_Brix_labels.reshape(-1, 1))
Gala_X_validate_NZ2023_Brix_encoded = encoder.fit_transform(Gala_X_validate_NZ2023_Brix_labels.reshape(-1, 1))
GD_X_validate_NZ2023_Brix_encoded = encoder.fit_transform(GD_X_validate_NZ2023_Brix_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_NZ2023_Brix_encoder = np.concatenate((Braeburn_X_train_NZ2023_Brix_encoded, Cox_X_train_NZ2023_Brix_encoded, Fuji_X_train_NZ2023_Brix_encoded, Gala_X_train_NZ2023_Brix_encoded, GD_X_train_NZ2023_Brix_encoded), axis=0)
X_validate_NZ2023_Brix_encoder= np.concatenate((Braeburn_X_validate_NZ2023_Brix_encoded, Cox_X_validate_NZ2023_Brix_encoded, Fuji_X_validate_NZ2023_Brix_encoded, Gala_X_validate_NZ2023_Brix_encoded, GD_X_validate_NZ2023_Brix_encoded), axis=0)
X_test_NZ2023_Brix_encoder = np.concatenate((Braeburn_X_test_NZ2023_Brix_encoded, Cox_X_test_NZ2023_Brix_encoded, Fuji_X_test_NZ2023_Brix_encoded, Gala_X_test_NZ2023_Brix_encoded, GD_X_test_NZ2023_Brix_encoded), axis=0)

# %%
# Shuffle the data

Y_train_NZ2023_Brix_shuffled, X_train_NZ2023_Brix_shuffled, X_train_NZ2023_Brix_encoder = shuffle(Y_train_NZ2023_Brix, X_train_NZ2023_Brix, X_train_NZ2023_Brix_encoder, random_state=775)
Y_validate_NZ2023_Brix_shuffled, X_validate_NZ2023_Brix_shuffled, X_validate_NZ2023_Brix_encoder = shuffle(Y_validate_NZ2023_Brix, X_validate_NZ2023_Brix, X_validate_NZ2023_Brix_encoder, random_state=775)
Y_test_NZ2023_Brix_shuffled, X_test_NZ2023_Brix_shuffled, X_test_NZ2023_Brix_encoder = shuffle(Y_test_NZ2023_Brix, X_test_NZ2023_Brix, X_test_NZ2023_Brix_encoder, random_state=775)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}NZ2023/Y_train_NZ2023_Brix_shuffled.npy', Y_train_NZ2023_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2023/Y_validate_NZ2023_Brix_shuffled.npy', Y_validate_NZ2023_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2023/Y_test_NZ2023_Brix_shuffled.npy', Y_test_NZ2023_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_train_NZ2023_Brix_shuffled.npy', X_train_NZ2023_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_validate_NZ2023_Brix_shuffled.npy', X_validate_NZ2023_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_test_NZ2023_Brix_shuffled.npy', X_test_NZ2023_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_train_NZ2023_Brix_encoder_shuffled.npy', X_train_NZ2023_Brix_encoder)
np.save(f'{training_data_save_path}NZ2023/X_validate_NZ2023_Brix_encoder_shuffled.npy', X_validate_NZ2023_Brix_encoder)
np.save(f'{training_data_save_path}NZ2023/X_test_NZ2023_Brix_encoder_shuffled.npy', X_test_NZ2023_Brix_encoder)

# %%
# Starch only NZ2023

Braeburn_X_train_NZ2023_1_Starch, Braeburn_X_validate_NZ2023_Starch, Braeburn_Y_train_NZ2023_1_Starch, Braeburn_Y_validate_NZ2023_Starch = train_test_split(BB_NZ2023_x, BB_NZ2023_y_starch, test_size = 0.02, random_state = 42)
Cox_X_train_NZ2023_1_Starch, Cox_X_validate_NZ2023_Starch, Cox_Y_train_NZ2023_1_Starch, Cox_Y_validate_NZ2023_Starch = train_test_split(CX_NZ2023_x, CX_NZ2023_y_starch, test_size = 0.02, random_state = 42)
Fuji_X_train_NZ2023_1_Starch, Fuji_X_validate_NZ2023_Starch, Fuji_Y_train_NZ2023_1_Starch, Fuji_Y_validate_NZ2023_Starch = train_test_split(FJ_NZ2023_x, FJ_NZ2023_y_starch, test_size = 0.02, random_state = 42)
Gala_X_train_NZ2023_1_Starch, Gala_X_validate_NZ2023_Starch, Gala_Y_train_NZ2023_1_Starch, Gala_Y_validate_NZ2023_Starch = train_test_split(GL_NZ2023_x, GL_NZ2023_y_starch, test_size = 0.02, random_state = 42)
GD_X_train_NZ2023_1_Starch, GD_X_validate_NZ2023_Starch, GD_Y_train_NZ2023_1_Starch, GD_Y_validate_NZ2023_Starch = train_test_split(GD_NZ2023_x, GD_NZ2023_y_starch, test_size = 0.02, random_state = 42)

Braeburn_X_train_NZ2023_Starch, Braeburn_X_test_NZ2023_Starch, Braeburn_Y_train_NZ2023_Starch, Braeburn_Y_test_NZ2023_Starch = train_test_split(Braeburn_X_train_NZ2023_1_Starch, Braeburn_Y_train_NZ2023_1_Starch, test_size = 0.18, random_state = 42)
Cox_X_train_NZ2023_Starch, Cox_X_test_NZ2023_Starch, Cox_Y_train_NZ2023_Starch, Cox_Y_test_NZ2023_Starch = train_test_split(Cox_X_train_NZ2023_1_Starch, Cox_Y_train_NZ2023_1_Starch, test_size = 0.18, random_state = 42)
Fuji_X_train_NZ2023_Starch, Fuji_X_test_NZ2023_Starch, Fuji_Y_train_NZ2023_Starch, Fuji_Y_test_NZ2023_Starch = train_test_split(Fuji_X_train_NZ2023_1_Starch, Fuji_Y_train_NZ2023_1_Starch, test_size = 0.18, random_state = 42)
Gala_X_train_NZ2023_Starch, Gala_X_test_NZ2023_Starch, Gala_Y_train_NZ2023_Starch, Gala_Y_test_NZ2023_Starch = train_test_split(Gala_X_train_NZ2023_1_Starch, Gala_Y_train_NZ2023_1_Starch, test_size = 0.18, random_state = 42)
GD_X_train_NZ2023_Starch, GD_X_test_NZ2023_Starch, GD_Y_train_NZ2023_Starch, GD_Y_test_NZ2023_Starch = train_test_split(GD_X_train_NZ2023_1_Starch, GD_Y_train_NZ2023_1_Starch, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_NZ2023_Starch = np.concatenate((Braeburn_Y_train_NZ2023_Starch, Cox_Y_train_NZ2023_Starch, Fuji_Y_train_NZ2023_Starch, Gala_Y_train_NZ2023_Starch, GD_Y_train_NZ2023_Starch), axis=0)
Y_validate_NZ2023_Starch = np.concatenate((Braeburn_Y_validate_NZ2023_Starch, Cox_Y_validate_NZ2023_Starch, Fuji_Y_validate_NZ2023_Starch, Gala_Y_validate_NZ2023_Starch, GD_Y_validate_NZ2023_Starch), axis=0)
Y_test_NZ2023_Starch = np.concatenate((Braeburn_Y_test_NZ2023_Starch, Cox_Y_test_NZ2023_Starch, Fuji_Y_test_NZ2023_Starch, Gala_Y_test_NZ2023_Starch, GD_Y_test_NZ2023_Starch), axis=0)
X_train_NZ2023_Starch = np.concatenate((Braeburn_X_train_NZ2023_Starch, Cox_X_train_NZ2023_Starch, Fuji_X_train_NZ2023_Starch, Gala_X_train_NZ2023_Starch, GD_X_train_NZ2023_Starch), axis=0)
X_validate_NZ2023_Starch = np.concatenate((Braeburn_X_validate_NZ2023_Starch, Cox_X_validate_NZ2023_Starch, Fuji_X_validate_NZ2023_Starch, Gala_X_validate_NZ2023_Starch, GD_X_validate_NZ2023_Starch), axis=0)
X_test_NZ2023_Starch = np.concatenate((Braeburn_X_test_NZ2023_Starch, Cox_X_test_NZ2023_Starch, Fuji_X_test_NZ2023_Starch, Gala_X_test_NZ2023_Starch, GD_X_test_NZ2023_Starch), axis=0)

# %%
# Hot encoding

Braeburn_X_train_NZ2023_Starch_labels = np.array(["BB"]*len(Braeburn_X_train_NZ2023_Starch))
Cox_X_train_NZ2023_Starch_labels = np.array(["CX"]*len(Cox_X_train_NZ2023_Starch))
Fuji_X_train_NZ2023_Starch_labels = np.array(["FJ"]*len(Fuji_X_train_NZ2023_Starch))
Gala_X_train_NZ2023_Starch_labels = np.array(["GL"]*len(Gala_X_train_NZ2023_Starch))
GD_X_train_NZ2023_Starch_labels = np.array(["GD"]*len(GD_X_train_NZ2023_Starch))
Braeburn_X_test_NZ2023_Starch_labels = np.array(["BB"]*len(Braeburn_X_test_NZ2023_Starch))
Cox_X_test_NZ2023_Starch_labels = np.array(["CX"]*len(Cox_X_test_NZ2023_Starch))
Fuji_X_test_NZ2023_Starch_labels = np.array(["FJ"]*len(Fuji_X_test_NZ2023_Starch))
Gala_X_test_NZ2023_Starch_labels = np.array(["GL"]*len(Gala_X_test_NZ2023_Starch))
GD_X_test_NZ2023_Starch_labels = np.array(["GD"]*len(GD_X_test_NZ2023_Starch))
Braeburn_X_validate_NZ2023_Starch_labels = np.array(["BB"]*len(Braeburn_X_validate_NZ2023_Starch))
Cox_X_validate_NZ2023_Starch_labels = np.array(["CX"]*len(Cox_X_validate_NZ2023_Starch))
Fuji_X_validate_NZ2023_Starch_labels = np.array(["FJ"]*len(Fuji_X_validate_NZ2023_Starch))
Gala_X_validate_NZ2023_Starch_labels = np.array(["GL"]*len(Gala_X_validate_NZ2023_Starch))
GD_X_validate_NZ2023_Starch_labels = np.array(["GD"]*len(GD_X_validate_NZ2023_Starch))



Braeburn_X_train_NZ2023_Starch_encoded = encoder.fit_transform(Braeburn_X_train_NZ2023_Starch_labels.reshape(-1, 1))
Cox_X_train_NZ2023_Starch_encoded = encoder.fit_transform(Cox_X_train_NZ2023_Starch_labels.reshape(-1, 1))
Fuji_X_train_NZ2023_Starch_encoded = encoder.fit_transform(Fuji_X_train_NZ2023_Starch_labels.reshape(-1, 1))
Gala_X_train_NZ2023_Starch_encoded = encoder.fit_transform(Gala_X_train_NZ2023_Starch_labels.reshape(-1, 1))
GD_X_train_NZ2023_Starch_encoded = encoder.fit_transform(GD_X_train_NZ2023_Starch_labels.reshape(-1, 1))
Braeburn_X_test_NZ2023_Starch_encoded = encoder.fit_transform(Braeburn_X_test_NZ2023_Starch_labels.reshape(-1, 1))
Cox_X_test_NZ2023_Starch_encoded = encoder.fit_transform(Cox_X_test_NZ2023_Starch_labels.reshape(-1, 1))
Fuji_X_test_NZ2023_Starch_encoded = encoder.fit_transform(Fuji_X_test_NZ2023_Starch_labels.reshape(-1, 1))
Gala_X_test_NZ2023_Starch_encoded = encoder.fit_transform(Gala_X_test_NZ2023_Starch_labels.reshape(-1, 1))
GD_X_test_NZ2023_Starch_encoded = encoder.fit_transform(GD_X_test_NZ2023_Starch_labels.reshape(-1, 1))
Braeburn_X_validate_NZ2023_Starch_encoded = encoder.fit_transform(Braeburn_X_validate_NZ2023_Starch_labels.reshape(-1, 1))
Cox_X_validate_NZ2023_Starch_encoded = encoder.fit_transform(Cox_X_validate_NZ2023_Starch_labels.reshape(-1, 1))
Fuji_X_validate_NZ2023_Starch_encoded = encoder.fit_transform(Fuji_X_validate_NZ2023_Starch_labels.reshape(-1, 1))
Gala_X_validate_NZ2023_Starch_encoded = encoder.fit_transform(Gala_X_validate_NZ2023_Starch_labels.reshape(-1, 1))
GD_X_validate_NZ2023_Starch_encoded = encoder.fit_transform(GD_X_validate_NZ2023_Starch_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_NZ2023_Starch_encoder = np.concatenate((Braeburn_X_train_NZ2023_Starch_encoded, Cox_X_train_NZ2023_Starch_encoded, Fuji_X_train_NZ2023_Starch_encoded, Gala_X_train_NZ2023_Starch_encoded, GD_X_train_NZ2023_Starch_encoded), axis=0)
X_validate_NZ2023_Starch_encoder= np.concatenate((Braeburn_X_validate_NZ2023_Starch_encoded, Cox_X_validate_NZ2023_Starch_encoded, Fuji_X_validate_NZ2023_Starch_encoded, Gala_X_validate_NZ2023_Starch_encoded, GD_X_validate_NZ2023_Starch_encoded), axis=0)
X_test_NZ2023_Starch_encoder = np.concatenate((Braeburn_X_test_NZ2023_Starch_encoded, Cox_X_test_NZ2023_Starch_encoded, Fuji_X_test_NZ2023_Starch_encoded, Gala_X_test_NZ2023_Starch_encoded, GD_X_test_NZ2023_Starch_encoded), axis=0)

# %%
# Shuffle the data

Y_train_NZ2023_Starch_shuffled, X_train_NZ2023_Starch_shuffled, X_train_NZ2023_Starch_encoder = shuffle(Y_train_NZ2023_Starch, X_train_NZ2023_Starch, X_train_NZ2023_Starch_encoder, random_state=775)
Y_validate_NZ2023_Starch_shuffled, X_validate_NZ2023_Starch_shuffled, X_validate_NZ2023_Starch_encoder = shuffle(Y_validate_NZ2023_Starch, X_validate_NZ2023_Starch, X_validate_NZ2023_Starch_encoder, random_state=775)
Y_test_NZ2023_Starch_shuffled, X_test_NZ2023_Starch_shuffled, X_test_NZ2023_Starch_encoder = shuffle(Y_test_NZ2023_Starch, X_test_NZ2023_Starch, X_test_NZ2023_Starch_encoder, random_state=775)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}NZ2023/Y_train_NZ2023_Starch_shuffled.npy', Y_train_NZ2023_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2023/Y_validate_NZ2023_Starch_shuffled.npy', Y_validate_NZ2023_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2023/Y_test_NZ2023_Starch_shuffled.npy', Y_test_NZ2023_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_train_NZ2023_Starch_shuffled.npy', X_train_NZ2023_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_validate_NZ2023_Starch_shuffled.npy', X_validate_NZ2023_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_test_NZ2023_Starch_shuffled.npy', X_test_NZ2023_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_train_NZ2023_Starch_encoder_shuffled.npy', X_train_NZ2023_Starch_encoder)
np.save(f'{training_data_save_path}NZ2023/X_validate_NZ2023_Starch_encoder_shuffled.npy', X_validate_NZ2023_Starch_encoder)
np.save(f'{training_data_save_path}NZ2023/X_test_NZ2023_Starch_encoder_shuffled.npy', X_test_NZ2023_Starch_encoder)

# %%
# Firmness only NZ2023

Braeburn_X_train_NZ2023_1_Firmness, Braeburn_X_validate_NZ2023_Firmness, Braeburn_Y_train_NZ2023_1_Firmness, Braeburn_Y_validate_NZ2023_Firmness = train_test_split(BB_NZ2023_x, BB_NZ2023_y_firmness, test_size = 0.02, random_state = 42)
Cox_X_train_NZ2023_1_Firmness, Cox_X_validate_NZ2023_Firmness, Cox_Y_train_NZ2023_1_Firmness, Cox_Y_validate_NZ2023_Firmness = train_test_split(CX_NZ2023_x, CX_NZ2023_y_firmness, test_size = 0.02, random_state = 42)
Fuji_X_train_NZ2023_1_Firmness, Fuji_X_validate_NZ2023_Firmness, Fuji_Y_train_NZ2023_1_Firmness, Fuji_Y_validate_NZ2023_Firmness = train_test_split(FJ_NZ2023_x, FJ_NZ2023_y_firmness, test_size = 0.02, random_state = 42)
Gala_X_train_NZ2023_1_Firmness, Gala_X_validate_NZ2023_Firmness, Gala_Y_train_NZ2023_1_Firmness, Gala_Y_validate_NZ2023_Firmness = train_test_split(GL_NZ2023_x, GL_NZ2023_y_firmness, test_size = 0.02, random_state = 42)
GD_X_train_NZ2023_1_Firmness, GD_X_validate_NZ2023_Firmness, GD_Y_train_NZ2023_1_Firmness, GD_Y_validate_NZ2023_Firmness = train_test_split(GD_NZ2023_x, GD_NZ2023_y_firmness, test_size = 0.02, random_state = 42)

Braeburn_X_train_NZ2023_Firmness, Braeburn_X_test_NZ2023_Firmness, Braeburn_Y_train_NZ2023_Firmness, Braeburn_Y_test_NZ2023_Firmness = train_test_split(Braeburn_X_train_NZ2023_1_Firmness, Braeburn_Y_train_NZ2023_1_Firmness, test_size = 0.18, random_state = 42)
Cox_X_train_NZ2023_Firmness, Cox_X_test_NZ2023_Firmness, Cox_Y_train_NZ2023_Firmness, Cox_Y_test_NZ2023_Firmness = train_test_split(Cox_X_train_NZ2023_1_Firmness, Cox_Y_train_NZ2023_1_Firmness, test_size = 0.18, random_state = 42)
Fuji_X_train_NZ2023_Firmness, Fuji_X_test_NZ2023_Firmness, Fuji_Y_train_NZ2023_Firmness, Fuji_Y_test_NZ2023_Firmness = train_test_split(Fuji_X_train_NZ2023_1_Firmness, Fuji_Y_train_NZ2023_1_Firmness, test_size = 0.18, random_state = 42)
Gala_X_train_NZ2023_Firmness, Gala_X_test_NZ2023_Firmness, Gala_Y_train_NZ2023_Firmness, Gala_Y_test_NZ2023_Firmness = train_test_split(Gala_X_train_NZ2023_1_Firmness, Gala_Y_train_NZ2023_1_Firmness, test_size = 0.18, random_state = 42)
GD_X_train_NZ2023_Firmness, GD_X_test_NZ2023_Firmness, GD_Y_train_NZ2023_Firmness, GD_Y_test_NZ2023_Firmness = train_test_split(GD_X_train_NZ2023_1_Firmness, GD_Y_train_NZ2023_1_Firmness, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_NZ2023_Firmness = np.concatenate((Braeburn_Y_train_NZ2023_Firmness, Cox_Y_train_NZ2023_Firmness, Fuji_Y_train_NZ2023_Firmness, Gala_Y_train_NZ2023_Firmness, GD_Y_train_NZ2023_Firmness), axis=0)
Y_validate_NZ2023_Firmness = np.concatenate((Braeburn_Y_validate_NZ2023_Firmness, Cox_Y_validate_NZ2023_Firmness, Fuji_Y_validate_NZ2023_Firmness, Gala_Y_validate_NZ2023_Firmness, GD_Y_validate_NZ2023_Firmness), axis=0)
Y_test_NZ2023_Firmness = np.concatenate((Braeburn_Y_test_NZ2023_Firmness, Cox_Y_test_NZ2023_Firmness, Fuji_Y_test_NZ2023_Firmness, Gala_Y_test_NZ2023_Firmness, GD_Y_test_NZ2023_Firmness), axis=0)
X_train_NZ2023_Firmness = np.concatenate((Braeburn_X_train_NZ2023_Firmness, Cox_X_train_NZ2023_Firmness, Fuji_X_train_NZ2023_Firmness, Gala_X_train_NZ2023_Firmness, GD_X_train_NZ2023_Firmness), axis=0)
X_validate_NZ2023_Firmness = np.concatenate((Braeburn_X_validate_NZ2023_Firmness, Cox_X_validate_NZ2023_Firmness, Fuji_X_validate_NZ2023_Firmness, Gala_X_validate_NZ2023_Firmness, GD_X_validate_NZ2023_Firmness), axis=0)
X_test_NZ2023_Firmness = np.concatenate((Braeburn_X_test_NZ2023_Firmness, Cox_X_test_NZ2023_Firmness, Fuji_X_test_NZ2023_Firmness, Gala_X_test_NZ2023_Firmness, GD_X_test_NZ2023_Firmness), axis=0)

# %%
# Hot encoding

Braeburn_X_train_NZ2023_Firmness_labels = np.array(["BB"]*len(Braeburn_X_train_NZ2023_Firmness))
Cox_X_train_NZ2023_Firmness_labels = np.array(["CX"]*len(Cox_X_train_NZ2023_Firmness))
Fuji_X_train_NZ2023_Firmness_labels = np.array(["FJ"]*len(Fuji_X_train_NZ2023_Firmness))
Gala_X_train_NZ2023_Firmness_labels = np.array(["GL"]*len(Gala_X_train_NZ2023_Firmness))
GD_X_train_NZ2023_Firmness_labels = np.array(["GD"]*len(GD_X_train_NZ2023_Firmness))
Braeburn_X_test_NZ2023_Firmness_labels = np.array(["BB"]*len(Braeburn_X_test_NZ2023_Firmness))
Cox_X_test_NZ2023_Firmness_labels = np.array(["CX"]*len(Cox_X_test_NZ2023_Firmness))
Fuji_X_test_NZ2023_Firmness_labels = np.array(["FJ"]*len(Fuji_X_test_NZ2023_Firmness))
Gala_X_test_NZ2023_Firmness_labels = np.array(["GL"]*len(Gala_X_test_NZ2023_Firmness))
GD_X_test_NZ2023_Firmness_labels = np.array(["GD"]*len(GD_X_test_NZ2023_Firmness))
Braeburn_X_validate_NZ2023_Firmness_labels = np.array(["BB"]*len(Braeburn_X_validate_NZ2023_Firmness))
Cox_X_validate_NZ2023_Firmness_labels = np.array(["CX"]*len(Cox_X_validate_NZ2023_Firmness))
Fuji_X_validate_NZ2023_Firmness_labels = np.array(["FJ"]*len(Fuji_X_validate_NZ2023_Firmness))
Gala_X_validate_NZ2023_Firmness_labels = np.array(["GL"]*len(Gala_X_validate_NZ2023_Firmness))
GD_X_validate_NZ2023_Firmness_labels = np.array(["GD"]*len(GD_X_validate_NZ2023_Firmness))



Braeburn_X_train_NZ2023_Firmness_encoded = encoder.fit_transform(Braeburn_X_train_NZ2023_Firmness_labels.reshape(-1, 1))
Cox_X_train_NZ2023_Firmness_encoded = encoder.fit_transform(Cox_X_train_NZ2023_Firmness_labels.reshape(-1, 1))
Fuji_X_train_NZ2023_Firmness_encoded = encoder.fit_transform(Fuji_X_train_NZ2023_Firmness_labels.reshape(-1, 1))
Gala_X_train_NZ2023_Firmness_encoded = encoder.fit_transform(Gala_X_train_NZ2023_Firmness_labels.reshape(-1, 1))
GD_X_train_NZ2023_Firmness_encoded = encoder.fit_transform(GD_X_train_NZ2023_Firmness_labels.reshape(-1, 1))
Braeburn_X_test_NZ2023_Firmness_encoded = encoder.fit_transform(Braeburn_X_test_NZ2023_Firmness_labels.reshape(-1, 1))
Cox_X_test_NZ2023_Firmness_encoded = encoder.fit_transform(Cox_X_test_NZ2023_Firmness_labels.reshape(-1, 1))
Fuji_X_test_NZ2023_Firmness_encoded = encoder.fit_transform(Fuji_X_test_NZ2023_Firmness_labels.reshape(-1, 1))
Gala_X_test_NZ2023_Firmness_encoded = encoder.fit_transform(Gala_X_test_NZ2023_Firmness_labels.reshape(-1, 1))
GD_X_test_NZ2023_Firmness_encoded = encoder.fit_transform(GD_X_test_NZ2023_Firmness_labels.reshape(-1, 1))
Braeburn_X_validate_NZ2023_Firmness_encoded = encoder.fit_transform(Braeburn_X_validate_NZ2023_Firmness_labels.reshape(-1, 1))
Cox_X_validate_NZ2023_Firmness_encoded = encoder.fit_transform(Cox_X_validate_NZ2023_Firmness_labels.reshape(-1, 1))
Fuji_X_validate_NZ2023_Firmness_encoded = encoder.fit_transform(Fuji_X_validate_NZ2023_Firmness_labels.reshape(-1, 1))
Gala_X_validate_NZ2023_Firmness_encoded = encoder.fit_transform(Gala_X_validate_NZ2023_Firmness_labels.reshape(-1, 1))
GD_X_validate_NZ2023_Firmness_encoded = encoder.fit_transform(GD_X_validate_NZ2023_Firmness_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_NZ2023_Firmness_encoder = np.concatenate((Braeburn_X_train_NZ2023_Firmness_encoded, Cox_X_train_NZ2023_Firmness_encoded, Fuji_X_train_NZ2023_Firmness_encoded, Gala_X_train_NZ2023_Firmness_encoded, GD_X_train_NZ2023_Firmness_encoded), axis=0)
X_validate_NZ2023_Firmness_encoder= np.concatenate((Braeburn_X_validate_NZ2023_Firmness_encoded, Cox_X_validate_NZ2023_Firmness_encoded, Fuji_X_validate_NZ2023_Firmness_encoded, Gala_X_validate_NZ2023_Firmness_encoded, GD_X_validate_NZ2023_Firmness_encoded), axis=0)
X_test_NZ2023_Firmness_encoder = np.concatenate((Braeburn_X_test_NZ2023_Firmness_encoded, Cox_X_test_NZ2023_Firmness_encoded, Fuji_X_test_NZ2023_Firmness_encoded, Gala_X_test_NZ2023_Firmness_encoded, GD_X_test_NZ2023_Firmness_encoded), axis=0)

# %%
# Shuffle the data

Y_train_NZ2023_Firmness_shuffled, X_train_NZ2023_Firmness_shuffled, X_train_NZ2023_Firmness_encoder = shuffle(Y_train_NZ2023_Firmness, X_train_NZ2023_Firmness, X_train_NZ2023_Firmness_encoder, random_state=775)
Y_validate_NZ2023_Firmness_shuffled, X_validate_NZ2023_Firmness_shuffled, X_validate_NZ2023_Firmness_encoder = shuffle(Y_validate_NZ2023_Firmness, X_validate_NZ2023_Firmness, X_validate_NZ2023_Firmness_encoder, random_state=775)
Y_test_NZ2023_Firmness_shuffled, X_test_NZ2023_Firmness_shuffled, X_test_NZ2023_Firmness_encoder = shuffle(Y_test_NZ2023_Firmness, X_test_NZ2023_Firmness, X_test_NZ2023_Firmness_encoder, random_state=775)

# %%
print(len(X_test_NZ2023_Firmness_encoder))
# Out:
# 1157

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'

np.save(f'{training_data_save_path}NZ2023/Y_train_NZ2023_Firmness_shuffled.npy', Y_train_NZ2023_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2023/Y_validate_NZ2023_Firmness_shuffled.npy', Y_validate_NZ2023_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2023/Y_test_NZ2023_Firmness_shuffled.npy', Y_test_NZ2023_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_train_NZ2023_Firmness_shuffled.npy', X_train_NZ2023_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_validate_NZ2023_Firmness_shuffled.npy', X_validate_NZ2023_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_test_NZ2023_Firmness_shuffled.npy', X_test_NZ2023_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2023/X_train_NZ2023_Firmness_encoder_shuffled.npy', X_train_NZ2023_Firmness_encoder)
np.save(f'{training_data_save_path}NZ2023/X_validate_NZ2023_Firmness_encoder_shuffled.npy', X_validate_NZ2023_Firmness_encoder)
np.save(f'{training_data_save_path}NZ2023/X_test_NZ2023_Firmness_encoder_shuffled.npy', X_test_NZ2023_Firmness_encoder)

# %%
print(Y_train_NZ2023_Firmness_shuffled[:3])
# Out:
# [8.195 7.715 8.56 ]

# %% [markdown]
# ## NZ2024 ##

# %%
# Brix only NZ2024

Braeburn_X_train_NZ2024_1_Brix, Braeburn_X_validate_NZ2024_Brix, Braeburn_Y_train_NZ2024_1_Brix, Braeburn_Y_validate_NZ2024_Brix = train_test_split(BB_NZ2024_x, BB_NZ2024_y_brix, test_size = 0.02, random_state = 42)
Fuji_X_train_NZ2024_1_Brix, Fuji_X_validate_NZ2024_Brix, Fuji_Y_train_NZ2024_1_Brix, Fuji_Y_validate_NZ2024_Brix = train_test_split(FJ_NZ2024_x, FJ_NZ2024_y_brix, test_size = 0.02, random_state = 42)
Gala_X_train_NZ2024_1_Brix, Gala_X_validate_NZ2024_Brix, Gala_Y_train_NZ2024_1_Brix, Gala_Y_validate_NZ2024_Brix = train_test_split(GL_NZ2024_x, GL_NZ2024_y_brix, test_size = 0.02, random_state = 42)
GD_X_train_NZ2024_1_Brix, GD_X_validate_NZ2024_Brix, GD_Y_train_NZ2024_1_Brix, GD_Y_validate_NZ2024_Brix = train_test_split(GD_NZ2024_x, GD_NZ2024_y_brix, test_size = 0.02, random_state = 42)

Braeburn_X_train_NZ2024_Brix, Braeburn_X_test_NZ2024_Brix, Braeburn_Y_train_NZ2024_Brix, Braeburn_Y_test_NZ2024_Brix = train_test_split(Braeburn_X_train_NZ2024_1_Brix, Braeburn_Y_train_NZ2024_1_Brix, test_size = 0.18, random_state = 42)
Fuji_X_train_NZ2024_Brix, Fuji_X_test_NZ2024_Brix, Fuji_Y_train_NZ2024_Brix, Fuji_Y_test_NZ2024_Brix = train_test_split(Fuji_X_train_NZ2024_1_Brix, Fuji_Y_train_NZ2024_1_Brix, test_size = 0.18, random_state = 42)
Gala_X_train_NZ2024_Brix, Gala_X_test_NZ2024_Brix, Gala_Y_train_NZ2024_Brix, Gala_Y_test_NZ2024_Brix = train_test_split(Gala_X_train_NZ2024_1_Brix, Gala_Y_train_NZ2024_1_Brix, test_size = 0.18, random_state = 42)
GD_X_train_NZ2024_Brix, GD_X_test_NZ2024_Brix, GD_Y_train_NZ2024_Brix, GD_Y_test_NZ2024_Brix = train_test_split(GD_X_train_NZ2024_1_Brix, GD_Y_train_NZ2024_1_Brix, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_NZ2024_Brix = np.concatenate((Braeburn_Y_train_NZ2024_Brix, Fuji_Y_train_NZ2024_Brix, Gala_Y_train_NZ2024_Brix, GD_Y_train_NZ2024_Brix), axis=0)
Y_validate_NZ2024_Brix = np.concatenate((Braeburn_Y_validate_NZ2024_Brix, Fuji_Y_validate_NZ2024_Brix, Gala_Y_validate_NZ2024_Brix, GD_Y_validate_NZ2024_Brix), axis=0)
Y_test_NZ2024_Brix = np.concatenate((Braeburn_Y_test_NZ2024_Brix, Fuji_Y_test_NZ2024_Brix, Gala_Y_test_NZ2024_Brix, GD_Y_test_NZ2024_Brix), axis=0)
X_train_NZ2024_Brix = np.concatenate((Braeburn_X_train_NZ2024_Brix, Fuji_X_train_NZ2024_Brix, Gala_X_train_NZ2024_Brix, GD_X_train_NZ2024_Brix), axis=0)
X_validate_NZ2024_Brix = np.concatenate((Braeburn_X_validate_NZ2024_Brix, Fuji_X_validate_NZ2024_Brix, Gala_X_validate_NZ2024_Brix, GD_X_validate_NZ2024_Brix), axis=0)
X_test_NZ2024_Brix = np.concatenate((Braeburn_X_test_NZ2024_Brix, Fuji_X_test_NZ2024_Brix, Gala_X_test_NZ2024_Brix, GD_X_test_NZ2024_Brix), axis=0)

# %%
# Hot encoding

Braeburn_X_train_NZ2024_Brix_labels = np.array(["BB"]*len(Braeburn_X_train_NZ2024_Brix))
Fuji_X_train_NZ2024_Brix_labels = np.array(["FJ"]*len(Fuji_X_train_NZ2024_Brix))
Gala_X_train_NZ2024_Brix_labels = np.array(["GL"]*len(Gala_X_train_NZ2024_Brix))
GD_X_train_NZ2024_Brix_labels = np.array(["GD"]*len(GD_X_train_NZ2024_Brix))
Braeburn_X_test_NZ2024_Brix_labels = np.array(["BB"]*len(Braeburn_X_test_NZ2024_Brix))
Fuji_X_test_NZ2024_Brix_labels = np.array(["FJ"]*len(Fuji_X_test_NZ2024_Brix))
Gala_X_test_NZ2024_Brix_labels = np.array(["GL"]*len(Gala_X_test_NZ2024_Brix))
GD_X_test_NZ2024_Brix_labels = np.array(["GD"]*len(GD_X_test_NZ2024_Brix))
Braeburn_X_validate_NZ2024_Brix_labels = np.array(["BB"]*len(Braeburn_X_validate_NZ2024_Brix))
Fuji_X_validate_NZ2024_Brix_labels = np.array(["FJ"]*len(Fuji_X_validate_NZ2024_Brix))
Gala_X_validate_NZ2024_Brix_labels = np.array(["GL"]*len(Gala_X_validate_NZ2024_Brix))
GD_X_validate_NZ2024_Brix_labels = np.array(["GD"]*len(GD_X_validate_NZ2024_Brix))



Braeburn_X_train_NZ2024_Brix_encoded = encoder.fit_transform(Braeburn_X_train_NZ2024_Brix_labels.reshape(-1, 1))
Fuji_X_train_NZ2024_Brix_encoded = encoder.fit_transform(Fuji_X_train_NZ2024_Brix_labels.reshape(-1, 1))
Gala_X_train_NZ2024_Brix_encoded = encoder.fit_transform(Gala_X_train_NZ2024_Brix_labels.reshape(-1, 1))
GD_X_train_NZ2024_Brix_encoded = encoder.fit_transform(GD_X_train_NZ2024_Brix_labels.reshape(-1, 1))
Braeburn_X_test_NZ2024_Brix_encoded = encoder.fit_transform(Braeburn_X_test_NZ2024_Brix_labels.reshape(-1, 1))
Fuji_X_test_NZ2024_Brix_encoded = encoder.fit_transform(Fuji_X_test_NZ2024_Brix_labels.reshape(-1, 1))
Gala_X_test_NZ2024_Brix_encoded = encoder.fit_transform(Gala_X_test_NZ2024_Brix_labels.reshape(-1, 1))
GD_X_test_NZ2024_Brix_encoded = encoder.fit_transform(GD_X_test_NZ2024_Brix_labels.reshape(-1, 1))
Braeburn_X_validate_NZ2024_Brix_encoded = encoder.fit_transform(Braeburn_X_validate_NZ2024_Brix_labels.reshape(-1, 1))
Fuji_X_validate_NZ2024_Brix_encoded = encoder.fit_transform(Fuji_X_validate_NZ2024_Brix_labels.reshape(-1, 1))
Gala_X_validate_NZ2024_Brix_encoded = encoder.fit_transform(Gala_X_validate_NZ2024_Brix_labels.reshape(-1, 1))
GD_X_validate_NZ2024_Brix_encoded = encoder.fit_transform(GD_X_validate_NZ2024_Brix_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_NZ2024_Brix_encoder = np.concatenate((Braeburn_X_train_NZ2024_Brix_encoded, Fuji_X_train_NZ2024_Brix_encoded, Gala_X_train_NZ2024_Brix_encoded, GD_X_train_NZ2024_Brix_encoded), axis=0)
X_validate_NZ2024_Brix_encoder= np.concatenate((Braeburn_X_validate_NZ2024_Brix_encoded, Fuji_X_validate_NZ2024_Brix_encoded, Gala_X_validate_NZ2024_Brix_encoded, GD_X_validate_NZ2024_Brix_encoded), axis=0)
X_test_NZ2024_Brix_encoder = np.concatenate((Braeburn_X_test_NZ2024_Brix_encoded, Fuji_X_test_NZ2024_Brix_encoded, Gala_X_test_NZ2024_Brix_encoded, GD_X_test_NZ2024_Brix_encoded), axis=0)


# Shuffle the data

Y_train_NZ2024_Brix_shuffled, X_train_NZ2024_Brix_shuffled, X_train_NZ2024_Brix_encoder = shuffle(Y_train_NZ2024_Brix, X_train_NZ2024_Brix, X_train_NZ2024_Brix_encoder, random_state=775)
Y_validate_NZ2024_Brix_shuffled, X_validate_NZ2024_Brix_shuffled, X_validate_NZ2024_Brix_encoder = shuffle(Y_validate_NZ2024_Brix, X_validate_NZ2024_Brix, X_validate_NZ2024_Brix_encoder, random_state=775)
Y_test_NZ2024_Brix_shuffled, X_test_NZ2024_Brix_shuffled, X_test_NZ2024_Brix_encoder = shuffle(Y_test_NZ2024_Brix, X_test_NZ2024_Brix, X_test_NZ2024_Brix_encoder, random_state=775)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}NZ2024/Y_train_NZ2024_Brix_shuffled.npy', Y_train_NZ2024_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2024/Y_validate_NZ2024_Brix_shuffled.npy', Y_validate_NZ2024_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2024/Y_test_NZ2024_Brix_shuffled.npy', Y_test_NZ2024_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_train_NZ2024_Brix_shuffled.npy', X_train_NZ2024_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_validate_NZ2024_Brix_shuffled.npy', X_validate_NZ2024_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_test_NZ2024_Brix_shuffled.npy', X_test_NZ2024_Brix_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_train_NZ2024_Brix_encoder_shuffled.npy', X_train_NZ2024_Brix_encoder)
np.save(f'{training_data_save_path}NZ2024/X_validate_NZ2024_Brix_encoder_shuffled.npy', X_validate_NZ2024_Brix_encoder)
np.save(f'{training_data_save_path}NZ2024/X_test_NZ2024_Brix_encoder_shuffled.npy', X_test_NZ2024_Brix_encoder)

# %%
# Starch only NZ2024

Braeburn_X_train_NZ2024_1_Starch, Braeburn_X_validate_NZ2024_Starch, Braeburn_Y_train_NZ2024_1_Starch, Braeburn_Y_validate_NZ2024_Starch = train_test_split(BB_NZ2024_x, BB_NZ2024_y_starch, test_size = 0.02, random_state = 42)
Fuji_X_train_NZ2024_1_Starch, Fuji_X_validate_NZ2024_Starch, Fuji_Y_train_NZ2024_1_Starch, Fuji_Y_validate_NZ2024_Starch = train_test_split(FJ_NZ2024_x, FJ_NZ2024_y_starch, test_size = 0.02, random_state = 42)
Gala_X_train_NZ2024_1_Starch, Gala_X_validate_NZ2024_Starch, Gala_Y_train_NZ2024_1_Starch, Gala_Y_validate_NZ2024_Starch = train_test_split(GL_NZ2024_x, GL_NZ2024_y_starch, test_size = 0.02, random_state = 42)
GD_X_train_NZ2024_1_Starch, GD_X_validate_NZ2024_Starch, GD_Y_train_NZ2024_1_Starch, GD_Y_validate_NZ2024_Starch = train_test_split(GD_NZ2024_x, GD_NZ2024_y_starch, test_size = 0.02, random_state = 42)

Braeburn_X_train_NZ2024_Starch, Braeburn_X_test_NZ2024_Starch, Braeburn_Y_train_NZ2024_Starch, Braeburn_Y_test_NZ2024_Starch = train_test_split(Braeburn_X_train_NZ2024_1_Starch, Braeburn_Y_train_NZ2024_1_Starch, test_size = 0.18, random_state = 42)
Fuji_X_train_NZ2024_Starch, Fuji_X_test_NZ2024_Starch, Fuji_Y_train_NZ2024_Starch, Fuji_Y_test_NZ2024_Starch = train_test_split(Fuji_X_train_NZ2024_1_Starch, Fuji_Y_train_NZ2024_1_Starch, test_size = 0.18, random_state = 42)
Gala_X_train_NZ2024_Starch, Gala_X_test_NZ2024_Starch, Gala_Y_train_NZ2024_Starch, Gala_Y_test_NZ2024_Starch = train_test_split(Gala_X_train_NZ2024_1_Starch, Gala_Y_train_NZ2024_1_Starch, test_size = 0.18, random_state = 42)
GD_X_train_NZ2024_Starch, GD_X_test_NZ2024_Starch, GD_Y_train_NZ2024_Starch, GD_Y_test_NZ2024_Starch = train_test_split(GD_X_train_NZ2024_1_Starch, GD_Y_train_NZ2024_1_Starch, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_NZ2024_Starch = np.concatenate((Braeburn_Y_train_NZ2024_Starch, Fuji_Y_train_NZ2024_Starch, Gala_Y_train_NZ2024_Starch, GD_Y_train_NZ2024_Starch), axis=0)
Y_validate_NZ2024_Starch = np.concatenate((Braeburn_Y_validate_NZ2024_Starch, Fuji_Y_validate_NZ2024_Starch, Gala_Y_validate_NZ2024_Starch, GD_Y_validate_NZ2024_Starch), axis=0)
Y_test_NZ2024_Starch = np.concatenate((Braeburn_Y_test_NZ2024_Starch, Fuji_Y_test_NZ2024_Starch, Gala_Y_test_NZ2024_Starch, GD_Y_test_NZ2024_Starch), axis=0)
X_train_NZ2024_Starch = np.concatenate((Braeburn_X_train_NZ2024_Starch, Fuji_X_train_NZ2024_Starch, Gala_X_train_NZ2024_Starch, GD_X_train_NZ2024_Starch), axis=0)
X_validate_NZ2024_Starch = np.concatenate((Braeburn_X_validate_NZ2024_Starch, Fuji_X_validate_NZ2024_Starch, Gala_X_validate_NZ2024_Starch, GD_X_validate_NZ2024_Starch), axis=0)
X_test_NZ2024_Starch = np.concatenate((Braeburn_X_test_NZ2024_Starch, Fuji_X_test_NZ2024_Starch, Gala_X_test_NZ2024_Starch, GD_X_test_NZ2024_Starch), axis=0)

# %%
print(X_train_NZ2024_Starch[1])
# Out:
# 30x/NZ2024/30px_Braeburn_1511_10563.npy

# %%
# Hot encoding

Braeburn_X_train_NZ2024_Starch_labels = np.array(["BB"]*len(Braeburn_X_train_NZ2024_Starch))
Fuji_X_train_NZ2024_Starch_labels = np.array(["FJ"]*len(Fuji_X_train_NZ2024_Starch))
Gala_X_train_NZ2024_Starch_labels = np.array(["GL"]*len(Gala_X_train_NZ2024_Starch))
GD_X_train_NZ2024_Starch_labels = np.array(["GD"]*len(GD_X_train_NZ2024_Starch))
Braeburn_X_test_NZ2024_Starch_labels = np.array(["BB"]*len(Braeburn_X_test_NZ2024_Starch))
Fuji_X_test_NZ2024_Starch_labels = np.array(["FJ"]*len(Fuji_X_test_NZ2024_Starch))
Gala_X_test_NZ2024_Starch_labels = np.array(["GL"]*len(Gala_X_test_NZ2024_Starch))
GD_X_test_NZ2024_Starch_labels = np.array(["GD"]*len(GD_X_test_NZ2024_Starch))
Braeburn_X_validate_NZ2024_Starch_labels = np.array(["BB"]*len(Braeburn_X_validate_NZ2024_Starch))
Fuji_X_validate_NZ2024_Starch_labels = np.array(["FJ"]*len(Fuji_X_validate_NZ2024_Starch))
Gala_X_validate_NZ2024_Starch_labels = np.array(["GL"]*len(Gala_X_validate_NZ2024_Starch))
GD_X_validate_NZ2024_Starch_labels = np.array(["GD"]*len(GD_X_validate_NZ2024_Starch))



Braeburn_X_train_NZ2024_Starch_encoded = encoder.fit_transform(Braeburn_X_train_NZ2024_Starch_labels.reshape(-1, 1))
Fuji_X_train_NZ2024_Starch_encoded = encoder.fit_transform(Fuji_X_train_NZ2024_Starch_labels.reshape(-1, 1))
Gala_X_train_NZ2024_Starch_encoded = encoder.fit_transform(Gala_X_train_NZ2024_Starch_labels.reshape(-1, 1))
GD_X_train_NZ2024_Starch_encoded = encoder.fit_transform(GD_X_train_NZ2024_Starch_labels.reshape(-1, 1))
Braeburn_X_test_NZ2024_Starch_encoded = encoder.fit_transform(Braeburn_X_test_NZ2024_Starch_labels.reshape(-1, 1))
Fuji_X_test_NZ2024_Starch_encoded = encoder.fit_transform(Fuji_X_test_NZ2024_Starch_labels.reshape(-1, 1))
Gala_X_test_NZ2024_Starch_encoded = encoder.fit_transform(Gala_X_test_NZ2024_Starch_labels.reshape(-1, 1))
GD_X_test_NZ2024_Starch_encoded = encoder.fit_transform(GD_X_test_NZ2024_Starch_labels.reshape(-1, 1))
Braeburn_X_validate_NZ2024_Starch_encoded = encoder.fit_transform(Braeburn_X_validate_NZ2024_Starch_labels.reshape(-1, 1))
Fuji_X_validate_NZ2024_Starch_encoded = encoder.fit_transform(Fuji_X_validate_NZ2024_Starch_labels.reshape(-1, 1))
Gala_X_validate_NZ2024_Starch_encoded = encoder.fit_transform(Gala_X_validate_NZ2024_Starch_labels.reshape(-1, 1))
GD_X_validate_NZ2024_Starch_encoded = encoder.fit_transform(GD_X_validate_NZ2024_Starch_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_NZ2024_Starch_encoder = np.concatenate((Braeburn_X_train_NZ2024_Starch_encoded, Fuji_X_train_NZ2024_Starch_encoded, Gala_X_train_NZ2024_Starch_encoded, GD_X_train_NZ2024_Starch_encoded), axis=0)
X_validate_NZ2024_Starch_encoder= np.concatenate((Braeburn_X_validate_NZ2024_Starch_encoded, Fuji_X_validate_NZ2024_Starch_encoded, Gala_X_validate_NZ2024_Starch_encoded, GD_X_validate_NZ2024_Starch_encoded), axis=0)
X_test_NZ2024_Starch_encoder = np.concatenate((Braeburn_X_test_NZ2024_Starch_encoded, Fuji_X_test_NZ2024_Starch_encoded, Gala_X_test_NZ2024_Starch_encoded, GD_X_test_NZ2024_Starch_encoded), axis=0)


# Shuffle the data

Y_train_NZ2024_Starch_shuffled, X_train_NZ2024_Starch_shuffled, X_train_NZ2024_Starch_encoder = shuffle(Y_train_NZ2024_Starch, X_train_NZ2024_Starch, X_train_NZ2024_Starch_encoder, random_state=775)
Y_validate_NZ2024_Starch_shuffled, X_validate_NZ2024_Starch_shuffled, X_validate_NZ2024_Starch_encoder = shuffle(Y_validate_NZ2024_Starch, X_validate_NZ2024_Starch, X_validate_NZ2024_Starch_encoder, random_state=775)
Y_test_NZ2024_Starch_shuffled, X_test_NZ2024_Starch_shuffled, X_test_NZ2024_Starch_encoder = shuffle(Y_test_NZ2024_Starch, X_test_NZ2024_Starch, X_test_NZ2024_Starch_encoder, random_state=775)

# %%
print(Y_train_NZ2024_Starch.max())
# Out:
# 100

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}NZ2024/Y_train_NZ2024_Starch_shuffled.npy', Y_train_NZ2024_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2024/Y_validate_NZ2024_Starch_shuffled.npy', Y_validate_NZ2024_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2024/Y_test_NZ2024_Starch_shuffled.npy', Y_test_NZ2024_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_train_NZ2024_Starch_shuffled.npy', X_train_NZ2024_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_validate_NZ2024_Starch_shuffled.npy', X_validate_NZ2024_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_test_NZ2024_Starch_shuffled.npy', X_test_NZ2024_Starch_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_train_NZ2024_Starch_encoder_shuffled.npy', X_train_NZ2024_Starch_encoder)
np.save(f'{training_data_save_path}NZ2024/X_validate_NZ2024_Starch_encoder_shuffled.npy', X_validate_NZ2024_Starch_encoder)
np.save(f'{training_data_save_path}NZ2024/X_test_NZ2024_Starch_encoder_shuffled.npy', X_test_NZ2024_Starch_encoder)

# %%
# Firmness only NZ2024

Braeburn_X_train_NZ2024_1_Firmness, Braeburn_X_validate_NZ2024_Firmness, Braeburn_Y_train_NZ2024_1_Firmness, Braeburn_Y_validate_NZ2024_Firmness = train_test_split(BB_NZ2024_x, BB_NZ2024_y_firmness, test_size = 0.02, random_state = 42)
Fuji_X_train_NZ2024_1_Firmness, Fuji_X_validate_NZ2024_Firmness, Fuji_Y_train_NZ2024_1_Firmness, Fuji_Y_validate_NZ2024_Firmness = train_test_split(FJ_NZ2024_x, FJ_NZ2024_y_firmness, test_size = 0.02, random_state = 42)
Gala_X_train_NZ2024_1_Firmness, Gala_X_validate_NZ2024_Firmness, Gala_Y_train_NZ2024_1_Firmness, Gala_Y_validate_NZ2024_Firmness = train_test_split(GL_NZ2024_x, GL_NZ2024_y_firmness, test_size = 0.02, random_state = 42)
GD_X_train_NZ2024_1_Firmness, GD_X_validate_NZ2024_Firmness, GD_Y_train_NZ2024_1_Firmness, GD_Y_validate_NZ2024_Firmness = train_test_split(GD_NZ2024_x, GD_NZ2024_y_firmness, test_size = 0.02, random_state = 42)

Braeburn_X_train_NZ2024_Firmness, Braeburn_X_test_NZ2024_Firmness, Braeburn_Y_train_NZ2024_Firmness, Braeburn_Y_test_NZ2024_Firmness = train_test_split(Braeburn_X_train_NZ2024_1_Firmness, Braeburn_Y_train_NZ2024_1_Firmness, test_size = 0.18, random_state = 42)
Fuji_X_train_NZ2024_Firmness, Fuji_X_test_NZ2024_Firmness, Fuji_Y_train_NZ2024_Firmness, Fuji_Y_test_NZ2024_Firmness = train_test_split(Fuji_X_train_NZ2024_1_Firmness, Fuji_Y_train_NZ2024_1_Firmness, test_size = 0.18, random_state = 42)
Gala_X_train_NZ2024_Firmness, Gala_X_test_NZ2024_Firmness, Gala_Y_train_NZ2024_Firmness, Gala_Y_test_NZ2024_Firmness = train_test_split(Gala_X_train_NZ2024_1_Firmness, Gala_Y_train_NZ2024_1_Firmness, test_size = 0.18, random_state = 42)
GD_X_train_NZ2024_Firmness, GD_X_test_NZ2024_Firmness, GD_Y_train_NZ2024_Firmness, GD_Y_test_NZ2024_Firmness = train_test_split(GD_X_train_NZ2024_1_Firmness, GD_Y_train_NZ2024_1_Firmness, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_NZ2024_Firmness = np.concatenate((Braeburn_Y_train_NZ2024_Firmness, Fuji_Y_train_NZ2024_Firmness, Gala_Y_train_NZ2024_Firmness, GD_Y_train_NZ2024_Firmness), axis=0)
Y_validate_NZ2024_Firmness = np.concatenate((Braeburn_Y_validate_NZ2024_Firmness, Fuji_Y_validate_NZ2024_Firmness, Gala_Y_validate_NZ2024_Firmness, GD_Y_validate_NZ2024_Firmness), axis=0)
Y_test_NZ2024_Firmness = np.concatenate((Braeburn_Y_test_NZ2024_Firmness, Fuji_Y_test_NZ2024_Firmness, Gala_Y_test_NZ2024_Firmness, GD_Y_test_NZ2024_Firmness), axis=0)
X_train_NZ2024_Firmness = np.concatenate((Braeburn_X_train_NZ2024_Firmness, Fuji_X_train_NZ2024_Firmness, Gala_X_train_NZ2024_Firmness, GD_X_train_NZ2024_Firmness), axis=0)
X_validate_NZ2024_Firmness = np.concatenate((Braeburn_X_validate_NZ2024_Firmness, Fuji_X_validate_NZ2024_Firmness, Gala_X_validate_NZ2024_Firmness, GD_X_validate_NZ2024_Firmness), axis=0)
X_test_NZ2024_Firmness = np.concatenate((Braeburn_X_test_NZ2024_Firmness, Fuji_X_test_NZ2024_Firmness, Gala_X_test_NZ2024_Firmness, GD_X_test_NZ2024_Firmness), axis=0)

# %%
# Hot encoding

Braeburn_X_train_NZ2024_Firmness_labels = np.array(["BB"]*len(Braeburn_X_train_NZ2024_Firmness))
Fuji_X_train_NZ2024_Firmness_labels = np.array(["FJ"]*len(Fuji_X_train_NZ2024_Firmness))
Gala_X_train_NZ2024_Firmness_labels = np.array(["GL"]*len(Gala_X_train_NZ2024_Firmness))
GD_X_train_NZ2024_Firmness_labels = np.array(["GD"]*len(GD_X_train_NZ2024_Firmness))
Braeburn_X_test_NZ2024_Firmness_labels = np.array(["BB"]*len(Braeburn_X_test_NZ2024_Firmness))
Fuji_X_test_NZ2024_Firmness_labels = np.array(["FJ"]*len(Fuji_X_test_NZ2024_Firmness))
Gala_X_test_NZ2024_Firmness_labels = np.array(["GL"]*len(Gala_X_test_NZ2024_Firmness))
GD_X_test_NZ2024_Firmness_labels = np.array(["GD"]*len(GD_X_test_NZ2024_Firmness))
Braeburn_X_validate_NZ2024_Firmness_labels = np.array(["BB"]*len(Braeburn_X_validate_NZ2024_Firmness))
Fuji_X_validate_NZ2024_Firmness_labels = np.array(["FJ"]*len(Fuji_X_validate_NZ2024_Firmness))
Gala_X_validate_NZ2024_Firmness_labels = np.array(["GL"]*len(Gala_X_validate_NZ2024_Firmness))
GD_X_validate_NZ2024_Firmness_labels = np.array(["GD"]*len(GD_X_validate_NZ2024_Firmness))



Braeburn_X_train_NZ2024_Firmness_encoded = encoder.fit_transform(Braeburn_X_train_NZ2024_Firmness_labels.reshape(-1, 1))
Fuji_X_train_NZ2024_Firmness_encoded = encoder.fit_transform(Fuji_X_train_NZ2024_Firmness_labels.reshape(-1, 1))
Gala_X_train_NZ2024_Firmness_encoded = encoder.fit_transform(Gala_X_train_NZ2024_Firmness_labels.reshape(-1, 1))
GD_X_train_NZ2024_Firmness_encoded = encoder.fit_transform(GD_X_train_NZ2024_Firmness_labels.reshape(-1, 1))
Braeburn_X_test_NZ2024_Firmness_encoded = encoder.fit_transform(Braeburn_X_test_NZ2024_Firmness_labels.reshape(-1, 1))
Fuji_X_test_NZ2024_Firmness_encoded = encoder.fit_transform(Fuji_X_test_NZ2024_Firmness_labels.reshape(-1, 1))
Gala_X_test_NZ2024_Firmness_encoded = encoder.fit_transform(Gala_X_test_NZ2024_Firmness_labels.reshape(-1, 1))
GD_X_test_NZ2024_Firmness_encoded = encoder.fit_transform(GD_X_test_NZ2024_Firmness_labels.reshape(-1, 1))
Braeburn_X_validate_NZ2024_Firmness_encoded = encoder.fit_transform(Braeburn_X_validate_NZ2024_Firmness_labels.reshape(-1, 1))
Fuji_X_validate_NZ2024_Firmness_encoded = encoder.fit_transform(Fuji_X_validate_NZ2024_Firmness_labels.reshape(-1, 1))
Gala_X_validate_NZ2024_Firmness_encoded = encoder.fit_transform(Gala_X_validate_NZ2024_Firmness_labels.reshape(-1, 1))
GD_X_validate_NZ2024_Firmness_encoded = encoder.fit_transform(GD_X_validate_NZ2024_Firmness_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_NZ2024_Firmness_encoder = np.concatenate((Braeburn_X_train_NZ2024_Firmness_encoded, Fuji_X_train_NZ2024_Firmness_encoded, Gala_X_train_NZ2024_Firmness_encoded, GD_X_train_NZ2024_Firmness_encoded), axis=0)
X_validate_NZ2024_Firmness_encoder= np.concatenate((Braeburn_X_validate_NZ2024_Firmness_encoded, Fuji_X_validate_NZ2024_Firmness_encoded, Gala_X_validate_NZ2024_Firmness_encoded, GD_X_validate_NZ2024_Firmness_encoded), axis=0)
X_test_NZ2024_Firmness_encoder = np.concatenate((Braeburn_X_test_NZ2024_Firmness_encoded, Fuji_X_test_NZ2024_Firmness_encoded, Gala_X_test_NZ2024_Firmness_encoded, GD_X_test_NZ2024_Firmness_encoded), axis=0)


# Shuffle the data

Y_train_NZ2024_Firmness_shuffled, X_train_NZ2024_Firmness_shuffled, X_train_NZ2024_Firmness_encoder = shuffle(Y_train_NZ2024_Firmness, X_train_NZ2024_Firmness, X_train_NZ2024_Firmness_encoder, random_state=775)
Y_validate_NZ2024_Firmness_shuffled, X_validate_NZ2024_Firmness_shuffled, X_validate_NZ2024_Firmness_encoder = shuffle(Y_validate_NZ2024_Firmness, X_validate_NZ2024_Firmness, X_validate_NZ2024_Firmness_encoder, random_state=775)
Y_test_NZ2024_Firmness_shuffled, X_test_NZ2024_Firmness_shuffled, X_test_NZ2024_Firmness_encoder = shuffle(Y_test_NZ2024_Firmness, X_test_NZ2024_Firmness, X_test_NZ2024_Firmness_encoder, random_state=775)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}NZ2024/Y_train_NZ2024_Firmness_shuffled.npy', Y_train_NZ2024_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2024/Y_validate_NZ2024_Firmness_shuffled.npy', Y_validate_NZ2024_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2024/Y_test_NZ2024_Firmness_shuffled.npy', Y_test_NZ2024_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_train_NZ2024_Firmness_shuffled.npy', X_train_NZ2024_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_validate_NZ2024_Firmness_shuffled.npy', X_validate_NZ2024_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_test_NZ2024_Firmness_shuffled.npy', X_test_NZ2024_Firmness_shuffled)
np.save(f'{training_data_save_path}NZ2024/X_train_NZ2024_Firmness_encoder_shuffled.npy', X_train_NZ2024_Firmness_encoder)
np.save(f'{training_data_save_path}NZ2024/X_validate_NZ2024_Firmness_encoder_shuffled.npy', X_validate_NZ2024_Firmness_encoder)
np.save(f'{training_data_save_path}NZ2024/X_test_NZ2024_Firmness_encoder_shuffled.npy', X_test_NZ2024_Firmness_encoder)

# %% [markdown]
# ## UK2024 ##

# %%
# Brix only UK2024

Braeburn_X_train_UK2024_1_Brix, Braeburn_X_validate_UK2024_Brix, Braeburn_Y_train_UK2024_1_Brix, Braeburn_Y_validate_UK2024_Brix = train_test_split(BB_UK2024_x, BB_UK2024_y_brix, test_size = 0.02, random_state = 42)
Cox_X_train_UK2024_1_Brix, Cox_X_validate_UK2024_Brix, Cox_Y_train_UK2024_1_Brix, Cox_Y_validate_UK2024_Brix = train_test_split(CX_UK2024_x, CX_UK2024_y_brix, test_size = 0.02, random_state = 42)
Fuji_X_train_UK2024_1_Brix, Fuji_X_validate_UK2024_Brix, Fuji_Y_train_UK2024_1_Brix, Fuji_Y_validate_UK2024_Brix = train_test_split(FJ_UK2024_x, FJ_UK2024_y_brix, test_size = 0.02, random_state = 42)
Gala_X_train_UK2024_1_Brix, Gala_X_validate_UK2024_Brix, Gala_Y_train_UK2024_1_Brix, Gala_Y_validate_UK2024_Brix = train_test_split(GL_UK2024_x, GL_UK2024_y_brix, test_size = 0.02, random_state = 42)
GD_X_train_UK2024_1_Brix, GD_X_validate_UK2024_Brix, GD_Y_train_UK2024_1_Brix, GD_Y_validate_UK2024_Brix = train_test_split(GD_UK2024_x, GD_UK2024_y_brix, test_size = 0.02, random_state = 42)
JZ_X_train_UK2024_1_Brix, JZ_X_validate_UK2024_Brix, JZ_Y_train_UK2024_1_Brix, JZ_Y_validate_UK2024_Brix = train_test_split(JZ_UK2024_x, JZ_UK2024_y_brix, test_size = 0.02, random_state = 42)


Braeburn_X_train_UK2024_Brix, Braeburn_X_test_UK2024_Brix, Braeburn_Y_train_UK2024_Brix, Braeburn_Y_test_UK2024_Brix = train_test_split(Braeburn_X_train_UK2024_1_Brix, Braeburn_Y_train_UK2024_1_Brix, test_size = 0.18, random_state = 42)
Cox_X_train_UK2024_Brix, Cox_X_test_UK2024_Brix, Cox_Y_train_UK2024_Brix, Cox_Y_test_UK2024_Brix = train_test_split(Cox_X_train_UK2024_1_Brix, Cox_Y_train_UK2024_1_Brix, test_size = 0.18, random_state = 42)
Fuji_X_train_UK2024_Brix, Fuji_X_test_UK2024_Brix, Fuji_Y_train_UK2024_Brix, Fuji_Y_test_UK2024_Brix = train_test_split(Fuji_X_train_UK2024_1_Brix, Fuji_Y_train_UK2024_1_Brix, test_size = 0.18, random_state = 42)
Gala_X_train_UK2024_Brix, Gala_X_test_UK2024_Brix, Gala_Y_train_UK2024_Brix, Gala_Y_test_UK2024_Brix = train_test_split(Gala_X_train_UK2024_1_Brix, Gala_Y_train_UK2024_1_Brix, test_size = 0.18, random_state = 42)
GD_X_train_UK2024_Brix, GD_X_test_UK2024_Brix, GD_Y_train_UK2024_Brix, GD_Y_test_UK2024_Brix = train_test_split(GD_X_train_UK2024_1_Brix, GD_Y_train_UK2024_1_Brix, test_size = 0.18, random_state = 42)
JZ_X_train_UK2024_Brix, JZ_X_test_UK2024_Brix, JZ_Y_train_UK2024_Brix, JZ_Y_test_UK2024_Brix = train_test_split(JZ_X_train_UK2024_1_Brix, JZ_Y_train_UK2024_1_Brix, test_size = 0.18, random_state = 42)


# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_UK2024_Brix = np.concatenate((Braeburn_Y_train_UK2024_Brix, Cox_Y_train_UK2024_Brix, Fuji_Y_train_UK2024_Brix, Gala_Y_train_UK2024_Brix, GD_Y_train_UK2024_Brix, JZ_Y_train_UK2024_Brix), axis=0)
Y_validate_UK2024_Brix = np.concatenate((Braeburn_Y_validate_UK2024_Brix, Cox_Y_validate_UK2024_Brix, Fuji_Y_validate_UK2024_Brix, Gala_Y_validate_UK2024_Brix, GD_Y_validate_UK2024_Brix, JZ_Y_validate_UK2024_Brix), axis=0)
Y_test_UK2024_Brix = np.concatenate((Braeburn_Y_test_UK2024_Brix, Cox_Y_test_UK2024_Brix, Fuji_Y_test_UK2024_Brix, Gala_Y_test_UK2024_Brix, GD_Y_test_UK2024_Brix, JZ_Y_test_UK2024_Brix), axis=0)
X_train_UK2024_Brix = np.concatenate((Braeburn_X_train_UK2024_Brix, Cox_X_train_UK2024_Brix, Fuji_X_train_UK2024_Brix, Gala_X_train_UK2024_Brix, GD_X_train_UK2024_Brix, JZ_X_train_UK2024_Brix), axis=0)
X_validate_UK2024_Brix = np.concatenate((Braeburn_X_validate_UK2024_Brix, Cox_X_validate_UK2024_Brix, Fuji_X_validate_UK2024_Brix, Gala_X_validate_UK2024_Brix, GD_X_validate_UK2024_Brix, JZ_X_validate_UK2024_Brix), axis=0)
X_test_UK2024_Brix = np.concatenate((Braeburn_X_test_UK2024_Brix, Cox_X_test_UK2024_Brix, Fuji_X_test_UK2024_Brix, Gala_X_test_UK2024_Brix, GD_X_test_UK2024_Brix, JZ_X_test_UK2024_Brix), axis=0)

# %%
# Hot encoding

Braeburn_X_train_UK2024_Brix_labels = np.array(["BB"]*len(Braeburn_X_train_UK2024_Brix))
Cox_X_train_UK2024_Brix_labels = np.array(["CX"]*len(Cox_X_train_UK2024_Brix))
Fuji_X_train_UK2024_Brix_labels = np.array(["FJ"]*len(Fuji_X_train_UK2024_Brix))
Gala_X_train_UK2024_Brix_labels = np.array(["GL"]*len(Gala_X_train_UK2024_Brix))
GD_X_train_UK2024_Brix_labels = np.array(["GD"]*len(GD_X_train_UK2024_Brix))
JZ_X_train_UK2024_Brix_labels = np.array(["JZ"]*len(JZ_X_train_UK2024_Brix))
Braeburn_X_test_UK2024_Brix_labels = np.array(["BB"]*len(Braeburn_X_test_UK2024_Brix))
Cox_X_test_UK2024_Brix_labels = np.array(["CX"]*len(Cox_X_test_UK2024_Brix))
Fuji_X_test_UK2024_Brix_labels = np.array(["FJ"]*len(Fuji_X_test_UK2024_Brix))
Gala_X_test_UK2024_Brix_labels = np.array(["GL"]*len(Gala_X_test_UK2024_Brix))
GD_X_test_UK2024_Brix_labels = np.array(["GD"]*len(GD_X_test_UK2024_Brix))
JZ_X_test_UK2024_Brix_labels = np.array(["JZ"]*len(JZ_X_test_UK2024_Brix))
Braeburn_X_validate_UK2024_Brix_labels = np.array(["BB"]*len(Braeburn_X_validate_UK2024_Brix))
Cox_X_validate_UK2024_Brix_labels = np.array(["CX"]*len(Cox_X_validate_UK2024_Brix))
Fuji_X_validate_UK2024_Brix_labels = np.array(["FJ"]*len(Fuji_X_validate_UK2024_Brix))
Gala_X_validate_UK2024_Brix_labels = np.array(["GL"]*len(Gala_X_validate_UK2024_Brix))
GD_X_validate_UK2024_Brix_labels = np.array(["GD"]*len(GD_X_validate_UK2024_Brix))
JZ_X_validate_UK2024_Brix_labels = np.array(["JZ"]*len(JZ_X_validate_UK2024_Brix))

Braeburn_X_train_UK2024_Brix_encoded = encoder.fit_transform(Braeburn_X_train_UK2024_Brix_labels.reshape(-1, 1))
Cox_X_train_UK2024_Brix_encoded = encoder.fit_transform(Cox_X_train_UK2024_Brix_labels.reshape(-1, 1))
Fuji_X_train_UK2024_Brix_encoded = encoder.fit_transform(Fuji_X_train_UK2024_Brix_labels.reshape(-1, 1))
Gala_X_train_UK2024_Brix_encoded = encoder.fit_transform(Gala_X_train_UK2024_Brix_labels.reshape(-1, 1))
GD_X_train_UK2024_Brix_encoded = encoder.fit_transform(GD_X_train_UK2024_Brix_labels.reshape(-1, 1))
JZ_X_train_UK2024_Brix_encoded = encoder.fit_transform(JZ_X_train_UK2024_Brix_labels.reshape(-1, 1))
Braeburn_X_test_UK2024_Brix_encoded = encoder.fit_transform(Braeburn_X_test_UK2024_Brix_labels.reshape(-1, 1))
Cox_X_test_UK2024_Brix_encoded = encoder.fit_transform(Cox_X_test_UK2024_Brix_labels.reshape(-1, 1))
Fuji_X_test_UK2024_Brix_encoded = encoder.fit_transform(Fuji_X_test_UK2024_Brix_labels.reshape(-1, 1))
Gala_X_test_UK2024_Brix_encoded = encoder.fit_transform(Gala_X_test_UK2024_Brix_labels.reshape(-1, 1))
GD_X_test_UK2024_Brix_encoded = encoder.fit_transform(GD_X_test_UK2024_Brix_labels.reshape(-1, 1))
JZ_X_test_UK2024_Brix_encoded = encoder.fit_transform(JZ_X_test_UK2024_Brix_labels.reshape(-1, 1))
Braeburn_X_validate_UK2024_Brix_encoded = encoder.fit_transform(Braeburn_X_validate_UK2024_Brix_labels.reshape(-1, 1))
Cox_X_validate_UK2024_Brix_encoded = encoder.fit_transform(Cox_X_validate_UK2024_Brix_labels.reshape(-1, 1))
Fuji_X_validate_UK2024_Brix_encoded = encoder.fit_transform(Fuji_X_validate_UK2024_Brix_labels.reshape(-1, 1))
Gala_X_validate_UK2024_Brix_encoded = encoder.fit_transform(Gala_X_validate_UK2024_Brix_labels.reshape(-1, 1))
GD_X_validate_UK2024_Brix_encoded = encoder.fit_transform(GD_X_validate_UK2024_Brix_labels.reshape(-1, 1))
JZ_X_validate_UK2024_Brix_encoded = encoder.fit_transform(JZ_X_validate_UK2024_Brix_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_UK2024_Brix_encoder = np.concatenate((Braeburn_X_train_UK2024_Brix_encoded, Cox_X_train_UK2024_Brix_encoded, Fuji_X_train_UK2024_Brix_encoded, Gala_X_train_UK2024_Brix_encoded, GD_X_train_UK2024_Brix_encoded, JZ_X_train_UK2024_Brix_encoded), axis=0)
X_validate_UK2024_Brix_encoder= np.concatenate((Braeburn_X_validate_UK2024_Brix_encoded, Cox_X_validate_UK2024_Brix_encoded, Fuji_X_validate_UK2024_Brix_encoded, Gala_X_validate_UK2024_Brix_encoded, GD_X_validate_UK2024_Brix_encoded, JZ_X_validate_UK2024_Brix_encoded), axis=0)
X_test_UK2024_Brix_encoder = np.concatenate((Braeburn_X_test_UK2024_Brix_encoded, Cox_X_test_UK2024_Brix_encoded, Fuji_X_test_UK2024_Brix_encoded, Gala_X_test_UK2024_Brix_encoded, GD_X_test_UK2024_Brix_encoded, JZ_X_test_UK2024_Brix_encoded), axis=0)



# Shuffle the data

Y_train_UK2024_Brix_shuffled, X_train_UK2024_Brix_shuffled, X_train_UK2024_Brix_encoder = shuffle(Y_train_UK2024_Brix, X_train_UK2024_Brix, X_train_UK2024_Brix_encoder, random_state=775)
Y_validate_UK2024_Brix_shuffled, X_validate_UK2024_Brix_shuffled, X_validate_UK2024_Brix_encoder = shuffle(Y_validate_UK2024_Brix, X_validate_UK2024_Brix, X_validate_UK2024_Brix_encoder, random_state=775)
Y_test_UK2024_Brix_shuffled, X_test_UK2024_Brix_shuffled, X_test_UK2024_Brix_encoder = shuffle(Y_test_UK2024_Brix, X_test_UK2024_Brix, X_test_UK2024_Brix_encoder, random_state=775)

Y_train_UK2024_Brix_shuffled = Y_train_UK2024_Brix_shuffled.astype(float)

# %%
print(type(Y_train_UK2024_Brix_shuffled[0]))
# Out:
# <class 'numpy.float64'>

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}UK2024/Y_train_UK2024_Brix_shuffled.npy', Y_train_UK2024_Brix_shuffled)
np.save(f'{training_data_save_path}UK2024/Y_validate_UK2024_Brix_shuffled.npy', Y_validate_UK2024_Brix_shuffled)
np.save(f'{training_data_save_path}UK2024/Y_test_UK2024_Brix_shuffled.npy', Y_test_UK2024_Brix_shuffled)
np.save(f'{training_data_save_path}UK2024/X_train_UK2024_Brix_shuffled.npy', X_train_UK2024_Brix_shuffled)
np.save(f'{training_data_save_path}UK2024/X_validate_UK2024_Brix_shuffled.npy', X_validate_UK2024_Brix_shuffled)
np.save(f'{training_data_save_path}UK2024/X_test_UK2024_Brix_shuffled.npy', X_test_UK2024_Brix_shuffled)
np.save(f'{training_data_save_path}UK2024/X_train_UK2024_Brix_encoder_shuffled.npy', X_train_UK2024_Brix_encoder)
np.save(f'{training_data_save_path}UK2024/X_validate_UK2024_Brix_encoder_shuffled.npy', X_validate_UK2024_Brix_encoder)
np.save(f'{training_data_save_path}UK2024/X_test_UK2024_Brix_encoder_shuffled.npy', X_test_UK2024_Brix_encoder)

# %%
# Starch only UK2024

Braeburn_X_train_UK2024_1_Starch, Braeburn_X_validate_UK2024_Starch, Braeburn_Y_train_UK2024_1_Starch, Braeburn_Y_validate_UK2024_Starch = train_test_split(BB_UK2024_x, BB_UK2024_y_starch, test_size = 0.02, random_state = 42)
Cox_X_train_UK2024_1_Starch, Cox_X_validate_UK2024_Starch, Cox_Y_train_UK2024_1_Starch, Cox_Y_validate_UK2024_Starch = train_test_split(CX_UK2024_x, CX_UK2024_y_starch, test_size = 0.02, random_state = 42)
Fuji_X_train_UK2024_1_Starch, Fuji_X_validate_UK2024_Starch, Fuji_Y_train_UK2024_1_Starch, Fuji_Y_validate_UK2024_Starch = train_test_split(FJ_UK2024_x, FJ_UK2024_y_starch, test_size = 0.02, random_state = 42)
Gala_X_train_UK2024_1_Starch, Gala_X_validate_UK2024_Starch, Gala_Y_train_UK2024_1_Starch, Gala_Y_validate_UK2024_Starch = train_test_split(GL_UK2024_x, GL_UK2024_y_starch, test_size = 0.02, random_state = 42)
GD_X_train_UK2024_1_Starch, GD_X_validate_UK2024_Starch, GD_Y_train_UK2024_1_Starch, GD_Y_validate_UK2024_Starch = train_test_split(GD_UK2024_x, GD_UK2024_y_starch, test_size = 0.02, random_state = 42)
JZ_X_train_UK2024_1_Starch, JZ_X_validate_UK2024_Starch, JZ_Y_train_UK2024_1_Starch, JZ_Y_validate_UK2024_Starch = train_test_split(JZ_UK2024_x, JZ_UK2024_y_starch, test_size = 0.02, random_state = 42)

Braeburn_X_train_UK2024_Starch, Braeburn_X_test_UK2024_Starch, Braeburn_Y_train_UK2024_Starch, Braeburn_Y_test_UK2024_Starch = train_test_split(Braeburn_X_train_UK2024_1_Starch, Braeburn_Y_train_UK2024_1_Starch, test_size = 0.18, random_state = 42)
Cox_X_train_UK2024_Starch, Cox_X_test_UK2024_Starch, Cox_Y_train_UK2024_Starch, Cox_Y_test_UK2024_Starch = train_test_split(Cox_X_train_UK2024_1_Starch, Cox_Y_train_UK2024_1_Starch, test_size = 0.18, random_state = 42)
Fuji_X_train_UK2024_Starch, Fuji_X_test_UK2024_Starch, Fuji_Y_train_UK2024_Starch, Fuji_Y_test_UK2024_Starch = train_test_split(Fuji_X_train_UK2024_1_Starch, Fuji_Y_train_UK2024_1_Starch, test_size = 0.18, random_state = 42)
Gala_X_train_UK2024_Starch, Gala_X_test_UK2024_Starch, Gala_Y_train_UK2024_Starch, Gala_Y_test_UK2024_Starch = train_test_split(Gala_X_train_UK2024_1_Starch, Gala_Y_train_UK2024_1_Starch, test_size = 0.18, random_state = 42)
GD_X_train_UK2024_Starch, GD_X_test_UK2024_Starch, GD_Y_train_UK2024_Starch, GD_Y_test_UK2024_Starch = train_test_split(GD_X_train_UK2024_1_Starch, GD_Y_train_UK2024_1_Starch, test_size = 0.18, random_state = 42)
JZ_X_train_UK2024_Starch, JZ_X_test_UK2024_Starch, JZ_Y_train_UK2024_Starch, JZ_Y_test_UK2024_Starch = train_test_split(JZ_X_train_UK2024_1_Starch, JZ_Y_train_UK2024_1_Starch, test_size = 0.18, random_state = 42)


# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_UK2024_Starch = np.concatenate((Braeburn_Y_train_UK2024_Starch, Cox_Y_train_UK2024_Starch, Fuji_Y_train_UK2024_Starch, Gala_Y_train_UK2024_Starch, GD_Y_train_UK2024_Starch, JZ_Y_train_UK2024_Starch), axis=0)
Y_validate_UK2024_Starch = np.concatenate((Braeburn_Y_validate_UK2024_Starch, Cox_Y_validate_UK2024_Starch, Fuji_Y_validate_UK2024_Starch, Gala_Y_validate_UK2024_Starch, GD_Y_validate_UK2024_Starch, JZ_Y_validate_UK2024_Starch), axis=0)
Y_test_UK2024_Starch = np.concatenate((Braeburn_Y_test_UK2024_Starch, Cox_Y_test_UK2024_Starch, Fuji_Y_test_UK2024_Starch, Gala_Y_test_UK2024_Starch, GD_Y_test_UK2024_Starch, JZ_Y_test_UK2024_Starch), axis=0)
X_train_UK2024_Starch = np.concatenate((Braeburn_X_train_UK2024_Starch, Cox_X_train_UK2024_Starch, Fuji_X_train_UK2024_Starch, Gala_X_train_UK2024_Starch, GD_X_train_UK2024_Starch, JZ_X_train_UK2024_Starch), axis=0)
X_validate_UK2024_Starch = np.concatenate((Braeburn_X_validate_UK2024_Starch, Cox_X_validate_UK2024_Starch, Fuji_X_validate_UK2024_Starch, Gala_X_validate_UK2024_Starch, GD_X_validate_UK2024_Starch, JZ_X_validate_UK2024_Starch), axis=0)
X_test_UK2024_Starch = np.concatenate((Braeburn_X_test_UK2024_Starch, Cox_X_test_UK2024_Starch, Fuji_X_test_UK2024_Starch, Gala_X_test_UK2024_Starch, GD_X_test_UK2024_Starch, JZ_X_test_UK2024_Starch), axis=0)

# %%
print(Braeburn_X_train_UK2024_Starch[:3])
# Out:
# ['50px/UK2024/50px_Braeburn_1816_21471.npy'
#  '50px/UK2024/50px_Braeburn_831_20537.npy'
#  '50px/UK2024/50px_Braeburn_1512_18622.npy']

# %%
# Hot encoding

Braeburn_X_train_UK2024_Starch_labels = np.array(["BB"]*len(Braeburn_X_train_UK2024_Starch))
Cox_X_train_UK2024_Starch_labels = np.array(["CX"]*len(Cox_X_train_UK2024_Starch))
Fuji_X_train_UK2024_Starch_labels = np.array(["FJ"]*len(Fuji_X_train_UK2024_Starch))
Gala_X_train_UK2024_Starch_labels = np.array(["GL"]*len(Gala_X_train_UK2024_Starch))
GD_X_train_UK2024_Starch_labels = np.array(["GD"]*len(GD_X_train_UK2024_Starch))
JZ_X_train_UK2024_Starch_labels = np.array(["JZ"]*len(JZ_X_train_UK2024_Starch))
Braeburn_X_test_UK2024_Starch_labels = np.array(["BB"]*len(Braeburn_X_test_UK2024_Starch))
Cox_X_test_UK2024_Starch_labels = np.array(["CX"]*len(Cox_X_test_UK2024_Starch))
Fuji_X_test_UK2024_Starch_labels = np.array(["FJ"]*len(Fuji_X_test_UK2024_Starch))
Gala_X_test_UK2024_Starch_labels = np.array(["GL"]*len(Gala_X_test_UK2024_Starch))
GD_X_test_UK2024_Starch_labels = np.array(["GD"]*len(GD_X_test_UK2024_Starch))
JZ_X_test_UK2024_Starch_labels = np.array(["JZ"]*len(JZ_X_test_UK2024_Starch))
Braeburn_X_validate_UK2024_Starch_labels = np.array(["BB"]*len(Braeburn_X_validate_UK2024_Starch))
Cox_X_validate_UK2024_Starch_labels = np.array(["CX"]*len(Cox_X_validate_UK2024_Starch))
Fuji_X_validate_UK2024_Starch_labels = np.array(["FJ"]*len(Fuji_X_validate_UK2024_Starch))
Gala_X_validate_UK2024_Starch_labels = np.array(["GL"]*len(Gala_X_validate_UK2024_Starch))
GD_X_validate_UK2024_Starch_labels = np.array(["GD"]*len(GD_X_validate_UK2024_Starch))
JZ_X_validate_UK2024_Starch_labels = np.array(["JZ"]*len(JZ_X_validate_UK2024_Starch))

Braeburn_X_train_UK2024_Starch_encoded = encoder.fit_transform(Braeburn_X_train_UK2024_Starch_labels.reshape(-1, 1))
Cox_X_train_UK2024_Starch_encoded = encoder.fit_transform(Cox_X_train_UK2024_Starch_labels.reshape(-1, 1))
Fuji_X_train_UK2024_Starch_encoded = encoder.fit_transform(Fuji_X_train_UK2024_Starch_labels.reshape(-1, 1))
Gala_X_train_UK2024_Starch_encoded = encoder.fit_transform(Gala_X_train_UK2024_Starch_labels.reshape(-1, 1))
GD_X_train_UK2024_Starch_encoded = encoder.fit_transform(GD_X_train_UK2024_Starch_labels.reshape(-1, 1))
JZ_X_train_UK2024_Starch_encoded = encoder.fit_transform(JZ_X_train_UK2024_Starch_labels.reshape(-1, 1))
Braeburn_X_test_UK2024_Starch_encoded = encoder.fit_transform(Braeburn_X_test_UK2024_Starch_labels.reshape(-1, 1))
Cox_X_test_UK2024_Starch_encoded = encoder.fit_transform(Cox_X_test_UK2024_Starch_labels.reshape(-1, 1))
Fuji_X_test_UK2024_Starch_encoded = encoder.fit_transform(Fuji_X_test_UK2024_Starch_labels.reshape(-1, 1))
Gala_X_test_UK2024_Starch_encoded = encoder.fit_transform(Gala_X_test_UK2024_Starch_labels.reshape(-1, 1))
GD_X_test_UK2024_Starch_encoded = encoder.fit_transform(GD_X_test_UK2024_Starch_labels.reshape(-1, 1))
JZ_X_test_UK2024_Starch_encoded = encoder.fit_transform(JZ_X_test_UK2024_Starch_labels.reshape(-1, 1))
Braeburn_X_validate_UK2024_Starch_encoded = encoder.fit_transform(Braeburn_X_validate_UK2024_Starch_labels.reshape(-1, 1))
Cox_X_validate_UK2024_Starch_encoded = encoder.fit_transform(Cox_X_validate_UK2024_Starch_labels.reshape(-1, 1))
Fuji_X_validate_UK2024_Starch_encoded = encoder.fit_transform(Fuji_X_validate_UK2024_Starch_labels.reshape(-1, 1))
Gala_X_validate_UK2024_Starch_encoded = encoder.fit_transform(Gala_X_validate_UK2024_Starch_labels.reshape(-1, 1))
GD_X_validate_UK2024_Starch_encoded = encoder.fit_transform(GD_X_validate_UK2024_Starch_labels.reshape(-1, 1))
JZ_X_validate_UK2024_Starch_encoded = encoder.fit_transform(JZ_X_validate_UK2024_Starch_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_UK2024_Starch_encoder = np.concatenate((Braeburn_X_train_UK2024_Starch_encoded, Cox_X_train_UK2024_Starch_encoded, Fuji_X_train_UK2024_Starch_encoded, Gala_X_train_UK2024_Starch_encoded, GD_X_train_UK2024_Starch_encoded, JZ_X_train_UK2024_Starch_encoded), axis=0)
X_validate_UK2024_Starch_encoder= np.concatenate((Braeburn_X_validate_UK2024_Starch_encoded, Cox_X_validate_UK2024_Starch_encoded, Fuji_X_validate_UK2024_Starch_encoded, Gala_X_validate_UK2024_Starch_encoded, GD_X_validate_UK2024_Starch_encoded, JZ_X_validate_UK2024_Starch_encoded), axis=0)
X_test_UK2024_Starch_encoder = np.concatenate((Braeburn_X_test_UK2024_Starch_encoded, Cox_X_test_UK2024_Starch_encoded, Fuji_X_test_UK2024_Starch_encoded, Gala_X_test_UK2024_Starch_encoded, GD_X_test_UK2024_Starch_encoded, JZ_X_test_UK2024_Starch_encoded), axis=0)



# Shuffle the data

Y_train_UK2024_Starch_shuffled, X_train_UK2024_Starch_shuffled, X_train_UK2024_Starch_encoder = shuffle(Y_train_UK2024_Starch, X_train_UK2024_Starch, X_train_UK2024_Starch_encoder, random_state=775)
Y_validate_UK2024_Starch_shuffled, X_validate_UK2024_Starch_shuffled, X_validate_UK2024_Starch_encoder = shuffle(Y_validate_UK2024_Starch, X_validate_UK2024_Starch, X_validate_UK2024_Starch_encoder, random_state=775)
Y_test_UK2024_Starch_shuffled, X_test_UK2024_Starch_shuffled, X_test_UK2024_Starch_encoder = shuffle(Y_test_UK2024_Starch, X_test_UK2024_Starch, X_test_UK2024_Starch_encoder, random_state=775)

# %%
print(X_train_UK2024_Starch_shuffled[:3])
# Out:
# ['50px/UK2024/50px_Gala_1341_15902.npy'
#  '50px/UK2024/50px_Braeburn_1445_15999.npy'
#  '50px/UK2024/50px_Gala_192_14805.npy']

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'

np.save(f'{training_data_save_path}UK2024/Y_train_UK2024_Starch_shuffled.npy', Y_train_UK2024_Starch_shuffled)
np.save(f'{training_data_save_path}UK2024/Y_validate_UK2024_Starch_shuffled.npy', Y_validate_UK2024_Starch_shuffled)
np.save(f'{training_data_save_path}UK2024/Y_test_UK2024_Starch_shuffled.npy', Y_test_UK2024_Starch_shuffled)
np.save(f'{training_data_save_path}UK2024/X_train_UK2024_Starch_shuffled.npy', X_train_UK2024_Starch_shuffled)
np.save(f'{training_data_save_path}UK2024/X_validate_UK2024_Starch_shuffled.npy', X_validate_UK2024_Starch_shuffled)
np.save(f'{training_data_save_path}UK2024/X_test_UK2024_Starch_shuffled.npy', X_test_UK2024_Starch_shuffled)
np.save(f'{training_data_save_path}UK2024/X_train_UK2024_Starch_encoder_shuffled.npy', X_train_UK2024_Starch_encoder)
np.save(f'{training_data_save_path}UK2024/X_validate_UK2024_Starch_encoder_shuffled.npy', X_validate_UK2024_Starch_encoder)
np.save(f'{training_data_save_path}UK2024/X_test_UK2024_Starch_encoder_shuffled.npy', X_test_UK2024_Starch_encoder)

# %%
# Firmness only UK2024

Braeburn_X_train_UK2024_1_Firmness, Braeburn_X_validate_UK2024_Firmness, Braeburn_Y_train_UK2024_1_Firmness, Braeburn_Y_validate_UK2024_Firmness = train_test_split(BB_UK2024_x, BB_UK2024_y_firmness, test_size = 0.02, random_state = 42)
Cox_X_train_UK2024_1_Firmness, Cox_X_validate_UK2024_Firmness, Cox_Y_train_UK2024_1_Firmness, Cox_Y_validate_UK2024_Firmness = train_test_split(CX_UK2024_x, CX_UK2024_y_firmness, test_size = 0.02, random_state = 42)
Fuji_X_train_UK2024_1_Firmness, Fuji_X_validate_UK2024_Firmness, Fuji_Y_train_UK2024_1_Firmness, Fuji_Y_validate_UK2024_Firmness = train_test_split(FJ_UK2024_x, FJ_UK2024_y_firmness, test_size = 0.02, random_state = 42)
Gala_X_train_UK2024_1_Firmness, Gala_X_validate_UK2024_Firmness, Gala_Y_train_UK2024_1_Firmness, Gala_Y_validate_UK2024_Firmness = train_test_split(GL_UK2024_x, GL_UK2024_y_firmness, test_size = 0.02, random_state = 42)
GD_X_train_UK2024_1_Firmness, GD_X_validate_UK2024_Firmness, GD_Y_train_UK2024_1_Firmness, GD_Y_validate_UK2024_Firmness = train_test_split(GD_UK2024_x, GD_UK2024_y_firmness, test_size = 0.02, random_state = 42)
JZ_X_train_UK2024_1_Firmness, JZ_X_validate_UK2024_Firmness, JZ_Y_train_UK2024_1_Firmness, JZ_Y_validate_UK2024_Firmness = train_test_split(JZ_UK2024_x, JZ_UK2024_y_firmness, test_size = 0.02, random_state = 42)

Braeburn_X_train_UK2024_Firmness, Braeburn_X_test_UK2024_Firmness, Braeburn_Y_train_UK2024_Firmness, Braeburn_Y_test_UK2024_Firmness = train_test_split(Braeburn_X_train_UK2024_1_Firmness, Braeburn_Y_train_UK2024_1_Firmness, test_size = 0.18, random_state = 42)
Cox_X_train_UK2024_Firmness, Cox_X_test_UK2024_Firmness, Cox_Y_train_UK2024_Firmness, Cox_Y_test_UK2024_Firmness = train_test_split(Cox_X_train_UK2024_1_Firmness, Cox_Y_train_UK2024_1_Firmness, test_size = 0.18, random_state = 42)
Fuji_X_train_UK2024_Firmness, Fuji_X_test_UK2024_Firmness, Fuji_Y_train_UK2024_Firmness, Fuji_Y_test_UK2024_Firmness = train_test_split(Fuji_X_train_UK2024_1_Firmness, Fuji_Y_train_UK2024_1_Firmness, test_size = 0.18, random_state = 42)
Gala_X_train_UK2024_Firmness, Gala_X_test_UK2024_Firmness, Gala_Y_train_UK2024_Firmness, Gala_Y_test_UK2024_Firmness = train_test_split(Gala_X_train_UK2024_1_Firmness, Gala_Y_train_UK2024_1_Firmness, test_size = 0.18, random_state = 42)
GD_X_train_UK2024_Firmness, GD_X_test_UK2024_Firmness, GD_Y_train_UK2024_Firmness, GD_Y_test_UK2024_Firmness = train_test_split(GD_X_train_UK2024_1_Firmness, GD_Y_train_UK2024_1_Firmness, test_size = 0.18, random_state = 42)
JZ_X_train_UK2024_Firmness, JZ_X_test_UK2024_Firmness, JZ_Y_train_UK2024_Firmness, JZ_Y_test_UK2024_Firmness = train_test_split(JZ_X_train_UK2024_1_Firmness, JZ_Y_train_UK2024_1_Firmness, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_UK2024_Firmness = np.concatenate((Braeburn_Y_train_UK2024_Firmness, Cox_Y_train_UK2024_Firmness, Fuji_Y_train_UK2024_Firmness, Gala_Y_train_UK2024_Firmness, GD_Y_train_UK2024_Firmness, JZ_Y_train_UK2024_Firmness), axis=0)
Y_validate_UK2024_Firmness = np.concatenate((Braeburn_Y_validate_UK2024_Firmness, Cox_Y_validate_UK2024_Firmness, Fuji_Y_validate_UK2024_Firmness, Gala_Y_validate_UK2024_Firmness, GD_Y_validate_UK2024_Firmness, JZ_Y_validate_UK2024_Firmness), axis=0)
Y_test_UK2024_Firmness = np.concatenate((Braeburn_Y_test_UK2024_Firmness, Cox_Y_test_UK2024_Firmness, Fuji_Y_test_UK2024_Firmness, Gala_Y_test_UK2024_Firmness, GD_Y_test_UK2024_Firmness, JZ_Y_test_UK2024_Firmness), axis=0)
X_train_UK2024_Firmness = np.concatenate((Braeburn_X_train_UK2024_Firmness, Cox_X_train_UK2024_Firmness, Fuji_X_train_UK2024_Firmness, Gala_X_train_UK2024_Firmness, GD_X_train_UK2024_Firmness, JZ_X_train_UK2024_Firmness), axis=0)
X_validate_UK2024_Firmness = np.concatenate((Braeburn_X_validate_UK2024_Firmness, Cox_X_validate_UK2024_Firmness, Fuji_X_validate_UK2024_Firmness, Gala_X_validate_UK2024_Firmness, GD_X_validate_UK2024_Firmness, JZ_X_validate_UK2024_Firmness), axis=0)
X_test_UK2024_Firmness = np.concatenate((Braeburn_X_test_UK2024_Firmness, Cox_X_test_UK2024_Firmness, Fuji_X_test_UK2024_Firmness, Gala_X_test_UK2024_Firmness, GD_X_test_UK2024_Firmness, JZ_X_test_UK2024_Firmness), axis=0)

# %%
# Hot encoding

Braeburn_X_train_UK2024_Firmness_labels = np.array(["BB"]*len(Braeburn_X_train_UK2024_Firmness))
Cox_X_train_UK2024_Firmness_labels = np.array(["CX"]*len(Cox_X_train_UK2024_Firmness))
Fuji_X_train_UK2024_Firmness_labels = np.array(["FJ"]*len(Fuji_X_train_UK2024_Firmness))
Gala_X_train_UK2024_Firmness_labels = np.array(["GL"]*len(Gala_X_train_UK2024_Firmness))
GD_X_train_UK2024_Firmness_labels = np.array(["GD"]*len(GD_X_train_UK2024_Firmness))
JZ_X_train_UK2024_Firmness_labels = np.array(["JZ"]*len(JZ_X_train_UK2024_Firmness))
Braeburn_X_test_UK2024_Firmness_labels = np.array(["BB"]*len(Braeburn_X_test_UK2024_Firmness))
Cox_X_test_UK2024_Firmness_labels = np.array(["CX"]*len(Cox_X_test_UK2024_Firmness))
Fuji_X_test_UK2024_Firmness_labels = np.array(["FJ"]*len(Fuji_X_test_UK2024_Firmness))
Gala_X_test_UK2024_Firmness_labels = np.array(["GL"]*len(Gala_X_test_UK2024_Firmness))
GD_X_test_UK2024_Firmness_labels = np.array(["GD"]*len(GD_X_test_UK2024_Firmness))
JZ_X_test_UK2024_Firmness_labels = np.array(["JZ"]*len(JZ_X_test_UK2024_Firmness))
Braeburn_X_validate_UK2024_Firmness_labels = np.array(["BB"]*len(Braeburn_X_validate_UK2024_Firmness))
Cox_X_validate_UK2024_Firmness_labels = np.array(["CX"]*len(Cox_X_validate_UK2024_Firmness))
Fuji_X_validate_UK2024_Firmness_labels = np.array(["FJ"]*len(Fuji_X_validate_UK2024_Firmness))
Gala_X_validate_UK2024_Firmness_labels = np.array(["GL"]*len(Gala_X_validate_UK2024_Firmness))
GD_X_validate_UK2024_Firmness_labels = np.array(["GD"]*len(GD_X_validate_UK2024_Firmness))
JZ_X_validate_UK2024_Firmness_labels = np.array(["JZ"]*len(JZ_X_validate_UK2024_Firmness))

Braeburn_X_train_UK2024_Firmness_encoded = encoder.fit_transform(Braeburn_X_train_UK2024_Firmness_labels.reshape(-1, 1))
Cox_X_train_UK2024_Firmness_encoded = encoder.fit_transform(Cox_X_train_UK2024_Firmness_labels.reshape(-1, 1))
Fuji_X_train_UK2024_Firmness_encoded = encoder.fit_transform(Fuji_X_train_UK2024_Firmness_labels.reshape(-1, 1))
Gala_X_train_UK2024_Firmness_encoded = encoder.fit_transform(Gala_X_train_UK2024_Firmness_labels.reshape(-1, 1))
GD_X_train_UK2024_Firmness_encoded = encoder.fit_transform(GD_X_train_UK2024_Firmness_labels.reshape(-1, 1))
JZ_X_train_UK2024_Firmness_encoded = encoder.fit_transform(JZ_X_train_UK2024_Firmness_labels.reshape(-1, 1))
Braeburn_X_test_UK2024_Firmness_encoded = encoder.fit_transform(Braeburn_X_test_UK2024_Firmness_labels.reshape(-1, 1))
Cox_X_test_UK2024_Firmness_encoded = encoder.fit_transform(Cox_X_test_UK2024_Firmness_labels.reshape(-1, 1))
Fuji_X_test_UK2024_Firmness_encoded = encoder.fit_transform(Fuji_X_test_UK2024_Firmness_labels.reshape(-1, 1))
Gala_X_test_UK2024_Firmness_encoded = encoder.fit_transform(Gala_X_test_UK2024_Firmness_labels.reshape(-1, 1))
GD_X_test_UK2024_Firmness_encoded = encoder.fit_transform(GD_X_test_UK2024_Firmness_labels.reshape(-1, 1))
JZ_X_test_UK2024_Firmness_encoded = encoder.fit_transform(JZ_X_test_UK2024_Firmness_labels.reshape(-1, 1))
Braeburn_X_validate_UK2024_Firmness_encoded = encoder.fit_transform(Braeburn_X_validate_UK2024_Firmness_labels.reshape(-1, 1))
Cox_X_validate_UK2024_Firmness_encoded = encoder.fit_transform(Cox_X_validate_UK2024_Firmness_labels.reshape(-1, 1))
Fuji_X_validate_UK2024_Firmness_encoded = encoder.fit_transform(Fuji_X_validate_UK2024_Firmness_labels.reshape(-1, 1))
Gala_X_validate_UK2024_Firmness_encoded = encoder.fit_transform(Gala_X_validate_UK2024_Firmness_labels.reshape(-1, 1))
GD_X_validate_UK2024_Firmness_encoded = encoder.fit_transform(GD_X_validate_UK2024_Firmness_labels.reshape(-1, 1))
JZ_X_validate_UK2024_Firmness_encoded = encoder.fit_transform(JZ_X_validate_UK2024_Firmness_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_UK2024_Firmness_encoder = np.concatenate((Braeburn_X_train_UK2024_Firmness_encoded, Cox_X_train_UK2024_Firmness_encoded, Fuji_X_train_UK2024_Firmness_encoded, Gala_X_train_UK2024_Firmness_encoded, GD_X_train_UK2024_Firmness_encoded, JZ_X_train_UK2024_Firmness_encoded), axis=0)
X_validate_UK2024_Firmness_encoder= np.concatenate((Braeburn_X_validate_UK2024_Firmness_encoded, Cox_X_validate_UK2024_Firmness_encoded, Fuji_X_validate_UK2024_Firmness_encoded, Gala_X_validate_UK2024_Firmness_encoded, GD_X_validate_UK2024_Firmness_encoded, JZ_X_validate_UK2024_Firmness_encoded), axis=0)
X_test_UK2024_Firmness_encoder = np.concatenate((Braeburn_X_test_UK2024_Firmness_encoded, Cox_X_test_UK2024_Firmness_encoded, Fuji_X_test_UK2024_Firmness_encoded, Gala_X_test_UK2024_Firmness_encoded, GD_X_test_UK2024_Firmness_encoded, JZ_X_test_UK2024_Firmness_encoded), axis=0)



# Shuffle the data

Y_train_UK2024_Firmness_shuffled, X_train_UK2024_Firmness_shuffled, X_train_UK2024_Firmness_encoder = shuffle(Y_train_UK2024_Firmness, X_train_UK2024_Firmness, X_train_UK2024_Firmness_encoder, random_state=775)
Y_validate_UK2024_Firmness_shuffled, X_validate_UK2024_Firmness_shuffled, X_validate_UK2024_Firmness_encoder = shuffle(Y_validate_UK2024_Firmness, X_validate_UK2024_Firmness, X_validate_UK2024_Firmness_encoder, random_state=775)
Y_test_UK2024_Firmness_shuffled, X_test_UK2024_Firmness_shuffled, X_test_UK2024_Firmness_encoder = shuffle(Y_test_UK2024_Firmness, X_test_UK2024_Firmness, X_test_UK2024_Firmness_encoder, random_state=775)

# %%
print(len(Y_train_UK2024_Firmness_shuffled))
print(len(Y_validate_UK2024_Firmness_shuffled))
print(len(Y_test_UK2024_Firmness_shuffled))
# Out:
# 8227
# 209
# 1809

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}UK2024/Y_train_UK2024_Firmness_shuffled.npy', Y_train_UK2024_Firmness_shuffled)
np.save(f'{training_data_save_path}UK2024/Y_validate_UK2024_Firmness_shuffled.npy', Y_validate_UK2024_Firmness_shuffled)
np.save(f'{training_data_save_path}UK2024/Y_test_UK2024_Firmness_shuffled.npy', Y_test_UK2024_Firmness_shuffled)
np.save(f'{training_data_save_path}UK2024/X_train_UK2024_Firmness_shuffled.npy', X_train_UK2024_Firmness_shuffled)
np.save(f'{training_data_save_path}UK2024/X_validate_UK2024_Firmness_shuffled.npy', X_validate_UK2024_Firmness_shuffled)
np.save(f'{training_data_save_path}UK2024/X_test_UK2024_Firmness_shuffled.npy', X_test_UK2024_Firmness_shuffled)
np.save(f'{training_data_save_path}UK2024/X_train_UK2024_Firmness_encoder_shuffled.npy', X_train_UK2024_Firmness_encoder)
np.save(f'{training_data_save_path}UK2024/X_validate_UK2024_Firmness_encoder_shuffled.npy', X_validate_UK2024_Firmness_encoder)
np.save(f'{training_data_save_path}UK2024/X_test_UK2024_Firmness_encoder_shuffled.npy', X_test_UK2024_Firmness_encoder)

# %% [markdown]
# ### All data combined

# %%
# Combine data from each year together

# y data 
BB_all_years_y_brix = np.concatenate((BB_NZ2023_y_brix, BB_NZ2024_y_brix, BB_UK2024_y_brix), axis=0)
CX_all_years_y_brix = np.concatenate((CX_NZ2023_y_brix, CX_UK2024_y_brix), axis=0)
FJ_all_years_y_brix = np.concatenate((FJ_NZ2023_y_brix, FJ_NZ2024_y_brix, FJ_UK2024_y_brix), axis=0)
GL_all_years_y_brix = np.concatenate((GL_NZ2023_y_brix, GL_NZ2024_y_brix, GL_UK2024_y_brix), axis=0)
GD_all_years_y_brix = np.concatenate((GD_NZ2023_y_brix, GD_NZ2024_y_brix, GD_UK2024_y_brix), axis=0)
JZ_all_years_y_brix = JZ_UK2024_y_brix

BB_all_years_y_firmness = np.concatenate((BB_NZ2023_y_firmness, BB_NZ2024_y_firmness, BB_UK2024_y_firmness), axis=0)
CX_all_years_y_firmness = np.concatenate((CX_NZ2023_y_firmness, CX_UK2024_y_firmness), axis=0)
FJ_all_years_y_firmness = np.concatenate((FJ_NZ2023_y_firmness, FJ_NZ2024_y_firmness, FJ_UK2024_y_firmness), axis=0)
GL_all_years_y_firmness = np.concatenate((GL_NZ2023_y_firmness, GL_NZ2024_y_firmness, GL_UK2024_y_firmness), axis=0)
GD_all_years_y_firmness = np.concatenate((GD_NZ2023_y_firmness, GD_NZ2024_y_firmness, GD_UK2024_y_firmness), axis=0)
JZ_all_years_y_firmness = JZ_UK2024_y_firmness

BB_all_years_y_starch = np.concatenate((BB_NZ2023_y_starch, BB_NZ2024_y_starch, BB_UK2024_y_starch), axis=0)
CX_all_years_y_starch = np.concatenate((CX_NZ2023_y_starch, CX_UK2024_y_starch), axis=0)
FJ_all_years_y_starch = np.concatenate((FJ_NZ2023_y_starch, FJ_NZ2024_y_starch, FJ_UK2024_y_starch), axis=0)
GL_all_years_y_starch = np.concatenate((GL_NZ2023_y_starch, GL_NZ2024_y_starch, GL_UK2024_y_starch), axis=0)
GD_all_years_y_starch = np.concatenate((GD_NZ2023_y_starch, GD_NZ2024_y_starch, GD_UK2024_y_starch), axis=0)
JZ_all_years_y_starch = JZ_UK2024_y_starch

# x data

BB_all_years_x = np.concatenate((BB_NZ2023_x, BB_NZ2024_x, BB_UK2024_x), axis=0)
CX_all_years_x = np.concatenate((CX_NZ2023_x, CX_UK2024_x), axis=0)
FJ_all_years_x = np.concatenate((FJ_NZ2023_x, FJ_NZ2024_x, FJ_UK2024_x), axis=0)
GL_all_years_x = np.concatenate((GL_NZ2023_x, GL_NZ2024_x, GL_UK2024_x), axis=0)
GD_all_years_x = np.concatenate((GD_NZ2023_x, GD_NZ2024_x, GD_UK2024_x), axis=0)
JZ_all_years_x = JZ_UK2024_x

# %%
# Brix only all_data

Braeburn_X_train_all_years_1_Brix, Braeburn_X_validate_all_years_Brix, Braeburn_Y_train_all_years_1_Brix, Braeburn_Y_validate_all_years_Brix = train_test_split(BB_all_years_x, BB_all_years_y_brix, test_size = 0.02, random_state = 42)
Cox_X_train_all_years_1_Brix, Cox_X_validate_all_years_Brix, Cox_Y_train_all_years_1_Brix, Cox_Y_validate_all_years_Brix = train_test_split(CX_all_years_x, CX_all_years_y_brix, test_size = 0.02, random_state = 42)
Fuji_X_train_all_years_1_Brix, Fuji_X_validate_all_years_Brix, Fuji_Y_train_all_years_1_Brix, Fuji_Y_validate_all_years_Brix = train_test_split(FJ_all_years_x, FJ_all_years_y_brix, test_size = 0.02, random_state = 42)
Gala_X_train_all_years_1_Brix, Gala_X_validate_all_years_Brix, Gala_Y_train_all_years_1_Brix, Gala_Y_validate_all_years_Brix = train_test_split(GL_all_years_x, GL_all_years_y_brix, test_size = 0.02, random_state = 42)
GD_X_train_all_years_1_Brix, GD_X_validate_all_years_Brix, GD_Y_train_all_years_1_Brix, GD_Y_validate_all_years_Brix = train_test_split(GD_all_years_x, GD_all_years_y_brix, test_size = 0.02, random_state = 42)
JZ_X_train_all_years_1_Brix, JZ_X_validate_all_years_Brix, JZ_Y_train_all_years_1_Brix, JZ_Y_validate_all_years_Brix = train_test_split(JZ_all_years_x, JZ_all_years_y_brix, test_size = 0.02, random_state = 42)




Braeburn_X_train_all_years_Brix, Braeburn_X_test_all_years_Brix, Braeburn_Y_train_all_years_Brix, Braeburn_Y_test_all_years_Brix = train_test_split(Braeburn_X_train_all_years_1_Brix, Braeburn_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
Cox_X_train_all_years_Brix, Cox_X_test_all_years_Brix, Cox_Y_train_all_years_Brix, Cox_Y_test_all_years_Brix = train_test_split(Cox_X_train_all_years_1_Brix, Cox_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
Fuji_X_train_all_years_Brix, Fuji_X_test_all_years_Brix, Fuji_Y_train_all_years_Brix, Fuji_Y_test_all_years_Brix = train_test_split(Fuji_X_train_all_years_1_Brix, Fuji_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
Gala_X_train_all_years_Brix, Gala_X_test_all_years_Brix, Gala_Y_train_all_years_Brix, Gala_Y_test_all_years_Brix = train_test_split(Gala_X_train_all_years_1_Brix, Gala_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
GD_X_train_all_years_Brix, GD_X_test_all_years_Brix, GD_Y_train_all_years_Brix, GD_Y_test_all_years_Brix = train_test_split(GD_X_train_all_years_1_Brix, GD_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
JZ_X_train_all_years_Brix, JZ_X_test_all_years_Brix, JZ_Y_train_all_years_Brix, JZ_Y_test_all_years_Brix = train_test_split(JZ_X_train_all_years_1_Brix, JZ_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)


# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_all_years_Brix = np.concatenate((Braeburn_Y_train_all_years_Brix, Cox_Y_train_all_years_Brix, Fuji_Y_train_all_years_Brix, Gala_Y_train_all_years_Brix, GD_Y_train_all_years_Brix, JZ_Y_train_all_years_Brix), axis=0)
Y_validate_all_years_Brix = np.concatenate((Braeburn_Y_validate_all_years_Brix, Cox_Y_validate_all_years_Brix, Fuji_Y_validate_all_years_Brix, Gala_Y_validate_all_years_Brix, GD_Y_validate_all_years_Brix, JZ_Y_validate_all_years_Brix), axis=0)
Y_test_all_years_Brix = np.concatenate((Braeburn_Y_test_all_years_Brix, Cox_Y_test_all_years_Brix, Fuji_Y_test_all_years_Brix, Gala_Y_test_all_years_Brix, GD_Y_test_all_years_Brix, JZ_Y_test_all_years_Brix), axis=0)
X_train_all_years_Brix = np.concatenate((Braeburn_X_train_all_years_Brix, Cox_X_train_all_years_Brix, Fuji_X_train_all_years_Brix, Gala_X_train_all_years_Brix, GD_X_train_all_years_Brix, JZ_X_train_all_years_Brix), axis=0)
X_validate_all_years_Brix = np.concatenate((Braeburn_X_validate_all_years_Brix, Cox_X_validate_all_years_Brix, Fuji_X_validate_all_years_Brix, Gala_X_validate_all_years_Brix, GD_X_validate_all_years_Brix, JZ_X_validate_all_years_Brix), axis=0)
X_test_all_years_Brix = np.concatenate((Braeburn_X_test_all_years_Brix, Cox_X_test_all_years_Brix, Fuji_X_test_all_years_Brix, Gala_X_test_all_years_Brix, GD_X_test_all_years_Brix, JZ_X_test_all_years_Brix), axis=0)


### Side A only

BB_Side_A_X_train_all_years_1_Brix, BB_Side_A_X_validate_all_years_Brix, BB_Side_A_Y_train_all_years_1_Brix, BB_Side_A_Y_validate_all_years_Brix = train_test_split(Side_A_BB_x, BB_side_A_y_brix_df, test_size = 0.02, random_state = 42)
CX_Side_A_X_train_all_years_1_Brix, CX_Side_A_X_validate_all_years_Brix, CX_Side_A_Y_train_all_years_1_Brix, CX_Side_A_Y_validate_all_years_Brix = train_test_split(Side_A_CX_x, CX_side_A_y_brix_df, test_size = 0.02, random_state = 42)
FJ_Side_A_X_train_all_years_1_Brix, FJ_Side_A_X_validate_all_years_Brix, FJ_Side_A_Y_train_all_years_1_Brix, FJ_Side_A_Y_validate_all_years_Brix = train_test_split(Side_A_FJ_x, FJ_side_A_y_brix_df, test_size = 0.02, random_state = 42)
GL_Side_A_X_train_all_years_1_Brix, GL_Side_A_X_validate_all_years_Brix, GL_Side_A_Y_train_all_years_1_Brix, GL_Side_A_Y_validate_all_years_Brix = train_test_split(Side_A_GL_x, GL_side_A_y_brix_df, test_size = 0.02, random_state = 42)
GD_Side_A_X_train_all_years_1_Brix, GD_Side_A_X_validate_all_years_Brix, GD_Side_A_Y_train_all_years_1_Brix, GD_Side_A_Y_validate_all_years_Brix = train_test_split(Side_A_GD_x, GD_side_A_y_brix_df, test_size = 0.02, random_state = 42)
JZ_Side_A_X_train_all_years_1_Brix, JZ_Side_A_X_validate_all_years_Brix, JZ_Side_A_Y_train_all_years_1_Brix, JZ_Side_A_Y_validate_all_years_Brix = train_test_split(Side_A_JZ_x, JZ_side_A_y_brix_df, test_size = 0.02, random_state = 42)

BB_Side_A_X_train_all_years_Brix, BB_Side_A_X_test_all_years_Brix, BB_Side_A_Y_train_all_years_Brix, BB_Side_A_Y_test_all_years_Brix = train_test_split(BB_Side_A_X_train_all_years_1_Brix, BB_Side_A_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
CX_Side_A_X_train_all_years_Brix, CX_Side_A_X_test_all_years_Brix, CX_Side_A_Y_train_all_years_Brix, CX_Side_A_Y_test_all_years_Brix = train_test_split(CX_Side_A_X_train_all_years_1_Brix, CX_Side_A_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
FJ_Side_A_X_train_all_years_Brix, FJ_Side_A_X_test_all_years_Brix, FJ_Side_A_Y_train_all_years_Brix, FJ_Side_A_Y_test_all_years_Brix = train_test_split(FJ_Side_A_X_train_all_years_1_Brix, FJ_Side_A_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
GL_Side_A_X_train_all_years_Brix, GL_Side_A_X_test_all_years_Brix, GL_Side_A_Y_train_all_years_Brix, GL_Side_A_Y_test_all_years_Brix = train_test_split(GL_Side_A_X_train_all_years_1_Brix, GL_Side_A_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
GD_Side_A_X_train_all_years_Brix, GD_Side_A_X_test_all_years_Brix, GD_Side_A_Y_train_all_years_Brix, GD_Side_A_Y_test_all_years_Brix = train_test_split(GD_Side_A_X_train_all_years_1_Brix, GD_Side_A_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)
JZ_Side_A_X_train_all_years_Brix, JZ_Side_A_X_test_all_years_Brix, JZ_Side_A_Y_train_all_years_Brix, JZ_Side_A_Y_test_all_years_Brix = train_test_split(JZ_Side_A_X_train_all_years_1_Brix, JZ_Side_A_Y_train_all_years_1_Brix, test_size = 0.18, random_state = 42)

Side_A_Y_train_all_years_Brix = np.concatenate((BB_Side_A_Y_train_all_years_Brix, CX_Side_A_Y_train_all_years_Brix, FJ_Side_A_Y_train_all_years_Brix, GL_Side_A_Y_train_all_years_Brix, GD_Side_A_Y_train_all_years_Brix, JZ_Side_A_Y_train_all_years_Brix), axis=0)
Side_A_Y_validate_all_years_Brix = np.concatenate((BB_Side_A_Y_validate_all_years_Brix, CX_Side_A_Y_validate_all_years_Brix, FJ_Side_A_Y_validate_all_years_Brix, GL_Side_A_Y_validate_all_years_Brix, GD_Side_A_Y_validate_all_years_Brix, JZ_Side_A_Y_validate_all_years_Brix), axis=0)
Side_A_Y_test_all_years_Brix = np.concatenate((BB_Side_A_Y_test_all_years_Brix, CX_Side_A_Y_test_all_years_Brix, FJ_Side_A_Y_test_all_years_Brix, GL_Side_A_Y_test_all_years_Brix, GD_Side_A_Y_test_all_years_Brix, JZ_Side_A_Y_test_all_years_Brix), axis=0)
Side_A_X_train_all_years_Brix = np.concatenate((BB_Side_A_X_train_all_years_Brix, CX_Side_A_X_train_all_years_Brix, FJ_Side_A_X_train_all_years_Brix, GL_Side_A_X_train_all_years_Brix, GD_Side_A_X_train_all_years_Brix, JZ_Side_A_X_train_all_years_Brix), axis=0)
Side_A_X_validate_all_years_Brix = np.concatenate((BB_Side_A_X_validate_all_years_Brix, CX_Side_A_X_validate_all_years_Brix, FJ_Side_A_X_validate_all_years_Brix, GL_Side_A_X_validate_all_years_Brix, GD_Side_A_X_validate_all_years_Brix, JZ_Side_A_X_validate_all_years_Brix), axis=0)
Side_A_X_test_all_years_Brix = np.concatenate((BB_Side_A_X_test_all_years_Brix, CX_Side_A_X_test_all_years_Brix, FJ_Side_A_X_test_all_years_Brix, GL_Side_A_X_test_all_years_Brix, GD_Side_A_X_test_all_years_Brix, JZ_Side_A_X_test_all_years_Brix), axis=0)

# %%
# Hot encoding

Braeburn_X_train_all_years_Brix_labels = np.array(["BB"]*len(Braeburn_X_train_all_years_Brix))
Cox_X_train_all_years_Brix_labels = np.array(["CX"]*len(Cox_X_train_all_years_Brix))
Fuji_X_train_all_years_Brix_labels = np.array(["FJ"]*len(Fuji_X_train_all_years_Brix))
Gala_X_train_all_years_Brix_labels = np.array(["GL"]*len(Gala_X_train_all_years_Brix))
GD_X_train_all_years_Brix_labels = np.array(["GD"]*len(GD_X_train_all_years_Brix))
JZ_X_train_all_years_Brix_labels = np.array(["JZ"]*len(JZ_X_train_all_years_Brix))
Braeburn_X_test_all_years_Brix_labels = np.array(["BB"]*len(Braeburn_X_test_all_years_Brix))
Cox_X_test_all_years_Brix_labels = np.array(["CX"]*len(Cox_X_test_all_years_Brix))
Fuji_X_test_all_years_Brix_labels = np.array(["FJ"]*len(Fuji_X_test_all_years_Brix))
Gala_X_test_all_years_Brix_labels = np.array(["GL"]*len(Gala_X_test_all_years_Brix))
GD_X_test_all_years_Brix_labels = np.array(["GD"]*len(GD_X_test_all_years_Brix))
JZ_X_test_all_years_Brix_labels = np.array(["JZ"]*len(JZ_X_test_all_years_Brix))
Braeburn_X_validate_all_years_Brix_labels = np.array(["BB"]*len(Braeburn_X_validate_all_years_Brix))
Cox_X_validate_all_years_Brix_labels = np.array(["CX"]*len(Cox_X_validate_all_years_Brix))
Fuji_X_validate_all_years_Brix_labels = np.array(["FJ"]*len(Fuji_X_validate_all_years_Brix))
Gala_X_validate_all_years_Brix_labels = np.array(["GL"]*len(Gala_X_validate_all_years_Brix))
GD_X_validate_all_years_Brix_labels = np.array(["GD"]*len(GD_X_validate_all_years_Brix))
JZ_X_validate_all_years_Brix_labels = np.array(["JZ"]*len(JZ_X_validate_all_years_Brix))

Braeburn_X_train_all_years_Brix_encoded = encoder.fit_transform(Braeburn_X_train_all_years_Brix_labels.reshape(-1, 1))
Cox_X_train_all_years_Brix_encoded = encoder.fit_transform(Cox_X_train_all_years_Brix_labels.reshape(-1, 1))
Fuji_X_train_all_years_Brix_encoded = encoder.fit_transform(Fuji_X_train_all_years_Brix_labels.reshape(-1, 1))
Gala_X_train_all_years_Brix_encoded = encoder.fit_transform(Gala_X_train_all_years_Brix_labels.reshape(-1, 1))
GD_X_train_all_years_Brix_encoded = encoder.fit_transform(GD_X_train_all_years_Brix_labels.reshape(-1, 1))
JZ_X_train_all_years_Brix_encoded = encoder.fit_transform(JZ_X_train_all_years_Brix_labels.reshape(-1, 1))
Braeburn_X_test_all_years_Brix_encoded = encoder.fit_transform(Braeburn_X_test_all_years_Brix_labels.reshape(-1, 1))
Cox_X_test_all_years_Brix_encoded = encoder.fit_transform(Cox_X_test_all_years_Brix_labels.reshape(-1, 1))
Fuji_X_test_all_years_Brix_encoded = encoder.fit_transform(Fuji_X_test_all_years_Brix_labels.reshape(-1, 1))
Gala_X_test_all_years_Brix_encoded = encoder.fit_transform(Gala_X_test_all_years_Brix_labels.reshape(-1, 1))
GD_X_test_all_years_Brix_encoded = encoder.fit_transform(GD_X_test_all_years_Brix_labels.reshape(-1, 1))
JZ_X_test_all_years_Brix_encoded = encoder.fit_transform(JZ_X_test_all_years_Brix_labels.reshape(-1, 1))
Braeburn_X_validate_all_years_Brix_encoded = encoder.fit_transform(Braeburn_X_validate_all_years_Brix_labels.reshape(-1, 1))
Cox_X_validate_all_years_Brix_encoded = encoder.fit_transform(Cox_X_validate_all_years_Brix_labels.reshape(-1, 1))
Fuji_X_validate_all_years_Brix_encoded = encoder.fit_transform(Fuji_X_validate_all_years_Brix_labels.reshape(-1, 1))
Gala_X_validate_all_years_Brix_encoded = encoder.fit_transform(Gala_X_validate_all_years_Brix_labels.reshape(-1, 1))
GD_X_validate_all_years_Brix_encoded = encoder.fit_transform(GD_X_validate_all_years_Brix_labels.reshape(-1, 1))
JZ_X_validate_all_years_Brix_encoded = encoder.fit_transform(JZ_X_validate_all_years_Brix_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_all_years_Brix_encoder = np.concatenate((Braeburn_X_train_all_years_Brix_encoded, Cox_X_train_all_years_Brix_encoded, Fuji_X_train_all_years_Brix_encoded, Gala_X_train_all_years_Brix_encoded, GD_X_train_all_years_Brix_encoded, JZ_X_train_all_years_Brix_encoded), axis=0)
X_validate_all_years_Brix_encoder= np.concatenate((Braeburn_X_validate_all_years_Brix_encoded, Cox_X_validate_all_years_Brix_encoded, Fuji_X_validate_all_years_Brix_encoded, Gala_X_validate_all_years_Brix_encoded, GD_X_validate_all_years_Brix_encoded, JZ_X_validate_all_years_Brix_encoded), axis=0)
X_test_all_years_Brix_encoder = np.concatenate((Braeburn_X_test_all_years_Brix_encoded, Cox_X_test_all_years_Brix_encoded, Fuji_X_test_all_years_Brix_encoded, Gala_X_test_all_years_Brix_encoded, GD_X_test_all_years_Brix_encoded, JZ_X_test_all_years_Brix_encoded), axis=0)



# Shuffle the data

Y_train_all_years_Brix_shuffled, X_train_all_years_Brix_shuffled, X_train_all_years_Brix_encoder = shuffle(Y_train_all_years_Brix, X_train_all_years_Brix, X_train_all_years_Brix_encoder, random_state=775)
Y_validate_all_years_Brix_shuffled, X_validate_all_years_Brix_shuffled, X_validate_all_years_Brix_encoder = shuffle(Y_validate_all_years_Brix, X_validate_all_years_Brix, X_validate_all_years_Brix_encoder, random_state=775)
Y_test_all_years_Brix_shuffled, X_test_all_years_Brix_shuffled, X_test_all_years_Brix_encoder = shuffle(Y_test_all_years_Brix, X_test_all_years_Brix, X_test_all_years_Brix_encoder, random_state=775)




# Hot encoding for side A

# Hot encoding

BB_Side_A_X_train_all_years_Brix_labels = np.array(["BB"]*len(BB_Side_A_X_train_all_years_Brix))
CX_Side_A_X_train_all_years_Brix_labels = np.array(["CX"]*len(CX_Side_A_X_train_all_years_Brix))
FJ_Side_A_X_train_all_years_Brix_labels = np.array(["FJ"]*len(FJ_Side_A_X_train_all_years_Brix))
GL_Side_A_X_train_all_years_Brix_labels = np.array(["GL"]*len(GL_Side_A_X_train_all_years_Brix))
GD_Side_A_X_train_all_years_Brix_labels = np.array(["GD"]*len(GD_Side_A_X_train_all_years_Brix))
JZ_Side_A_X_train_all_years_Brix_labels = np.array(["JZ"]*len(JZ_Side_A_X_train_all_years_Brix))
BB_Side_A_X_test_all_years_Brix_labels = np.array(["BB"]*len(BB_Side_A_X_test_all_years_Brix))
CX_Side_A_X_test_all_years_Brix_labels = np.array(["CX"]*len(CX_Side_A_X_test_all_years_Brix))
FJ_Side_A_X_test_all_years_Brix_labels = np.array(["FJ"]*len(FJ_Side_A_X_test_all_years_Brix))
GL_Side_A_X_test_all_years_Brix_labels = np.array(["GL"]*len(GL_Side_A_X_test_all_years_Brix))
GD_Side_A_X_test_all_years_Brix_labels = np.array(["GD"]*len(GD_Side_A_X_test_all_years_Brix))
JZ_Side_A_X_test_all_years_Brix_labels = np.array(["JZ"]*len(JZ_Side_A_X_test_all_years_Brix))
BB_Side_A_X_validate_all_years_Brix_labels = np.array(["BB"]*len(BB_Side_A_X_validate_all_years_Brix))
CX_Side_A_X_validate_all_years_Brix_labels = np.array(["CX"]*len(CX_Side_A_X_validate_all_years_Brix))
FJ_Side_A_X_validate_all_years_Brix_labels = np.array(["FJ"]*len(FJ_Side_A_X_validate_all_years_Brix))
GL_Side_A_X_validate_all_years_Brix_labels = np.array(["GL"]*len(GL_Side_A_X_validate_all_years_Brix))
GD_Side_A_X_validate_all_years_Brix_labels = np.array(["GD"]*len(GD_Side_A_X_validate_all_years_Brix))
JZ_Side_A_X_validate_all_years_Brix_labels = np.array(["JZ"]*len(JZ_Side_A_X_validate_all_years_Brix))


BB_Side_A_X_train_all_years_Brix_encoded = encoder.fit_transform(BB_Side_A_X_train_all_years_Brix_labels.reshape(-1, 1))
CX_A_X_train_all_years_Brix_encoded = encoder.fit_transform(CX_Side_A_X_train_all_years_Brix_labels.reshape(-1, 1))
FJ_A_X_train_all_years_Brix_encoded = encoder.fit_transform(FJ_Side_A_X_train_all_years_Brix_labels.reshape(-1, 1))
GL_A_X_train_all_years_Brix_encoded = encoder.fit_transform(GL_Side_A_X_train_all_years_Brix_labels.reshape(-1, 1))
GD_A_train_all_years_Brix_encoded = encoder.fit_transform(GD_Side_A_X_train_all_years_Brix_labels.reshape(-1, 1))
JZ_A_train_all_years_Brix_encoded = encoder.fit_transform(JZ_Side_A_X_train_all_years_Brix_labels.reshape(-1, 1))
BB_A_X_test_all_years_Brix_encoded = encoder.fit_transform(BB_Side_A_X_test_all_years_Brix_labels.reshape(-1, 1))
CX_A_test_all_years_Brix_encoded = encoder.fit_transform(CX_Side_A_X_test_all_years_Brix_labels.reshape(-1, 1))
FJ_A_X_test_all_years_Brix_encoded = encoder.fit_transform(FJ_Side_A_X_test_all_years_Brix_labels.reshape(-1, 1))
GL_A_X_test_all_years_Brix_encoded = encoder.fit_transform(GL_Side_A_X_test_all_years_Brix_labels.reshape(-1, 1))
GD_A_X_test_all_years_Brix_encoded = encoder.fit_transform(GD_Side_A_X_test_all_years_Brix_labels.reshape(-1, 1))
JZ_A_X_test_all_years_Brix_encoded = encoder.fit_transform(JZ_Side_A_X_test_all_years_Brix_labels.reshape(-1, 1))
BB_A_X_validate_all_years_Brix_encoded = encoder.fit_transform(BB_Side_A_X_validate_all_years_Brix_labels.reshape(-1, 1))
CX_A_validate_all_years_Brix_encoded = encoder.fit_transform(CX_Side_A_X_validate_all_years_Brix_labels.reshape(-1, 1))
FJ_A_X_validate_all_years_Brix_encoded = encoder.fit_transform(FJ_Side_A_X_validate_all_years_Brix_labels.reshape(-1, 1))
GL_A_X_validate_all_years_Brix_encoded = encoder.fit_transform(GL_Side_A_X_validate_all_years_Brix_labels.reshape(-1, 1))
GD_A_X_validate_all_years_Brix_encoded = encoder.fit_transform(GD_Side_A_X_validate_all_years_Brix_labels.reshape(-1, 1))
JZ_A_X_validate_all_years_Brix_encoded = encoder.fit_transform(JZ_Side_A_X_validate_all_years_Brix_labels.reshape(-1, 1))


# Combined all cultivar labels together
Side_A_X_train_all_years_Brix_encoder = np.concatenate((BB_Side_A_X_train_all_years_Brix_encoded, CX_A_X_train_all_years_Brix_encoded, FJ_A_X_train_all_years_Brix_encoded, GL_A_X_train_all_years_Brix_encoded, GD_A_train_all_years_Brix_encoded, JZ_A_train_all_years_Brix_encoded), axis=0)
Side_A_X_validate_all_years_Brix_encoder = np.concatenate((BB_A_X_validate_all_years_Brix_encoded, CX_A_validate_all_years_Brix_encoded, FJ_A_X_validate_all_years_Brix_encoded, GL_A_X_validate_all_years_Brix_encoded, GD_A_X_validate_all_years_Brix_encoded, JZ_A_X_validate_all_years_Brix_encoded), axis=0)
Side_A_X_test_all_years_Brix_encoder = np.concatenate((BB_A_X_test_all_years_Brix_encoded, CX_A_test_all_years_Brix_encoded, FJ_A_X_test_all_years_Brix_encoded, GL_A_X_test_all_years_Brix_encoded, GD_A_X_test_all_years_Brix_encoded, JZ_A_X_test_all_years_Brix_encoded), axis=0)



# Shuffle the data

Side_A_Y_train_all_years_Brix_shuffled, Side_A_X_train_all_years_Brix_shuffled, Side_A_X_train_all_years_Brix_encoder = shuffle(Side_A_Y_train_all_years_Brix, Side_A_X_train_all_years_Brix, Side_A_X_train_all_years_Brix_encoder, random_state=775)
Side_A_Y_validate_all_years_Brix_shuffled, Side_A_X_validate_all_years_Brix_shuffled, Side_A_X_validate_all_years_Brix_encoder = shuffle(Side_A_Y_validate_all_years_Brix, Side_A_X_validate_all_years_Brix, Side_A_X_validate_all_years_Brix_encoder, random_state=775)
Side_A_Y_test_all_years_Brix_shuffled, Side_A_X_test_all_years_Brix_shuffled, Side_A_X_test_all_years_Brix_encoder = shuffle(Side_A_Y_test_all_years_Brix, Side_A_X_test_all_years_Brix, Side_A_X_test_all_years_Brix_encoder, random_state=775)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'
np.save(f'{training_data_save_path}all_years/Braeburn_X_train_all_years_Brix_encoded.npy', Braeburn_X_train_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Cox_X_train_all_years_Brix_encoded.npy', Cox_X_train_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Fuji_X_train_all_years_Brix_encoded.npy', Fuji_X_train_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Gala_X_train_all_years_Brix_encoded.npy', Gala_X_train_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/GD_X_train_all_years_Brix_encoded.npy', GD_X_train_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/JZ_X_train_all_years_Brix_encoded.npy', JZ_X_train_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Braeburn_X_test_all_years_Brix_encoded.npy', Braeburn_X_test_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Cox_X_test_all_years_Brix_encoded.npy', Cox_X_test_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Fuji_X_test_all_years_Brix_encoded.npy', Fuji_X_test_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/Gala_X_test_all_years_Brix_encoded.npy', Gala_X_test_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/GD_X_test_all_years_Brix_encoded.npy', GD_X_test_all_years_Brix_encoded)
np.save(f'{training_data_save_path}all_years/JZ_X_test_all_years_Brix_encoded.npy', JZ_X_test_all_years_Brix_encoded)


# Side A
np.save(f'{training_data_save_path}Side_A_Y_train_all_years_Brix_shuffled.npy', Side_A_Y_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}Side_A_X_train_all_years_Brix_shuffled.npy', Side_A_X_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}Side_A_X_train_all_years_Brix_encoder.npy', Side_A_X_train_all_years_Brix_encoder)

np.save(f'{training_data_save_path}Side_A_Y_validate_all_years_Brix_shuffled.npy', Side_A_Y_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}Side_A_X_validate_all_years_Brix_shuffled.npy', Side_A_X_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}Side_A_X_validate_all_years_Brix_encoder.npy', Side_A_X_validate_all_years_Brix_encoder)

np.save(f'{training_data_save_path}Side_A_Y_test_all_years_Brix_shuffled.npy', Side_A_Y_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}Side_A_X_test_all_years_Brix_shuffled.npy', Side_A_X_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}Side_A_X_test_all_years_Brix_encoder.npy', Side_A_X_test_all_years_Brix_encoder)

# %%
# Cultivar separated and not one hot encoded

Braeburn_X_train_all_years_Brix_shuffled, Braeburn_Y_train_all_years_Brix_shuffled = shuffle(Braeburn_X_train_all_years_Brix, Braeburn_Y_train_all_years_Brix, random_state=775)
Braeburn_X_validate_all_years_Brix_shuffled, Braeburn_Y_validate_all_years_Brix_shuffled = shuffle(Braeburn_X_validate_all_years_Brix, Braeburn_Y_validate_all_years_Brix, random_state=775)
Braeburn_X_test_all_years_Brix_shuffled, Braeburn_Y_test_all_years_Brix_shuffled = shuffle(Braeburn_X_test_all_years_Brix, Braeburn_Y_test_all_years_Brix, random_state=775)

Fuji_X_train_all_years_Brix_shuffled, Fuji_Y_train_all_years_Brix_shuffled = shuffle(Fuji_X_train_all_years_Brix, Fuji_Y_train_all_years_Brix, random_state=775)
Fuji_X_validate_all_years_Brix_shuffled, Fuji_Y_validate_all_years_Brix_shuffled = shuffle(Fuji_X_validate_all_years_Brix, Fuji_Y_validate_all_years_Brix, random_state=775)
Fuji_X_test_all_years_Brix_shuffled, Fuji_Y_test_all_years_Brix_shuffled = shuffle(Fuji_X_test_all_years_Brix, Fuji_Y_test_all_years_Brix, random_state=775)

Gala_X_train_all_years_Brix_shuffled, Gala_Y_train_all_years_Brix_shuffled = shuffle(Gala_X_train_all_years_Brix, Gala_Y_train_all_years_Brix, random_state=775)
Gala_X_validate_all_years_Brix_shuffled, Gala_Y_validate_all_years_Brix_shuffled = shuffle(Gala_X_validate_all_years_Brix, Gala_Y_validate_all_years_Brix, random_state=775)
Gala_X_test_all_years_Brix_shuffled, Gala_Y_test_all_years_Brix_shuffled = shuffle(Gala_X_test_all_years_Brix, Gala_Y_test_all_years_Brix, random_state=775)

GD_X_train_all_years_Brix_shuffled, GD_Y_train_all_years_Brix_shuffled = shuffle(GD_X_train_all_years_Brix, GD_Y_train_all_years_Brix, random_state=775)
GD_X_validate_all_years_Brix_shuffled, GD_Y_validate_all_years_Brix_shuffled = shuffle(GD_X_validate_all_years_Brix, GD_Y_validate_all_years_Brix, random_state=775)
GD_X_test_all_years_Brix_shuffled, GD_Y_test_all_years_Brix_shuffled = shuffle(GD_X_test_all_years_Brix, GD_Y_test_all_years_Brix, random_state=775)



if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}all_years/Braeburn_X_train_all_years_Brix_shuffled.npy', Braeburn_X_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_train_all_years_Brix_shuffled.npy', Braeburn_Y_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_X_test_all_years_Brix_shuffled.npy', Braeburn_X_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_test_all_years_Brix_shuffled.npy', Braeburn_Y_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_X_validate_all_years_Brix_shuffled.npy', Braeburn_X_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_validate_all_years_Brix_shuffled.npy', Braeburn_Y_validate_all_years_Brix_shuffled)

np.save(f'{training_data_save_path}all_years/Fuji_X_train_all_years_Brix_shuffled.npy', Fuji_X_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_train_all_years_Brix_shuffled.npy', Fuji_Y_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_X_test_all_years_Brix_shuffled.npy', Fuji_X_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_test_all_years_Brix_shuffled.npy', Fuji_Y_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_X_validate_all_years_Brix_shuffled.npy', Fuji_X_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_validate_all_years_Brix_shuffled.npy', Fuji_Y_validate_all_years_Brix_shuffled)

np.save(f'{training_data_save_path}all_years/Gala_X_train_all_years_Brix_shuffled.npy', Gala_X_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_train_all_years_Brix_shuffled.npy', Gala_Y_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_X_test_all_years_Brix_shuffled.npy', Gala_X_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_test_all_years_Brix_shuffled.npy', Gala_Y_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_X_validate_all_years_Brix_shuffled.npy', Gala_X_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_validate_all_years_Brix_shuffled.npy', Gala_Y_validate_all_years_Brix_shuffled)

np.save(f'{training_data_save_path}all_years/GD_X_train_all_years_Brix_shuffled.npy', GD_X_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_train_all_years_Brix_shuffled.npy', GD_Y_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/GD_X_test_all_years_Brix_shuffled.npy', GD_X_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_test_all_years_Brix_shuffled.npy', GD_Y_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/GD_X_validate_all_years_Brix_shuffled.npy', GD_X_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_validate_all_years_Brix_shuffled.npy', GD_Y_validate_all_years_Brix_shuffled)

# %%
print(len(Y_train_all_years_Brix_shuffled))
print(len(Y_validate_all_years_Brix_shuffled))
print(len(Y_test_all_years_Brix_shuffled))
# Out:
# 17907
# 448
# 3934

# %%
print(Y_train_all_years_Brix_shuffled)
# Out:
# [10.89 13.76 12.13 ... 11.71 10.3  10.9 ]

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}all_years/Y_train_all_years_Brix_shuffled.npy', Y_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Y_validate_all_years_Brix_shuffled.npy', Y_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/Y_test_all_years_Brix_shuffled.npy', Y_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/X_train_all_years_Brix_shuffled.npy', X_train_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/X_validate_all_years_Brix_shuffled.npy', X_validate_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/X_test_all_years_Brix_shuffled.npy', X_test_all_years_Brix_shuffled)
np.save(f'{training_data_save_path}all_years/X_train_all_years_Brix_encoder_shuffled.npy', X_train_all_years_Brix_encoder)
np.save(f'{training_data_save_path}all_years/X_validate_all_years_Brix_encoder_shuffled.npy', X_validate_all_years_Brix_encoder)
np.save(f'{training_data_save_path}all_years/X_test_all_years_Brix_encoder_shuffled.npy', X_test_all_years_Brix_encoder)

# %%
# Firmness only all_data

Braeburn_X_train_all_years_1_Firmness, Braeburn_X_validate_all_years_Firmness, Braeburn_Y_train_all_years_1_Firmness, Braeburn_Y_validate_all_years_Firmness = train_test_split(BB_all_years_x, BB_all_years_y_firmness, test_size = 0.02, random_state = 42)
Cox_X_train_all_years_1_Firmness, Cox_X_validate_all_years_Firmness, Cox_Y_train_all_years_1_Firmness, Cox_Y_validate_all_years_Firmness = train_test_split(CX_all_years_x, CX_all_years_y_firmness, test_size = 0.02, random_state = 42)
Fuji_X_train_all_years_1_Firmness, Fuji_X_validate_all_years_Firmness, Fuji_Y_train_all_years_1_Firmness, Fuji_Y_validate_all_years_Firmness = train_test_split(FJ_all_years_x, FJ_all_years_y_firmness, test_size = 0.02, random_state = 42)
Gala_X_train_all_years_1_Firmness, Gala_X_validate_all_years_Firmness, Gala_Y_train_all_years_1_Firmness, Gala_Y_validate_all_years_Firmness = train_test_split(GL_all_years_x, GL_all_years_y_firmness, test_size = 0.02, random_state = 42)
GD_X_train_all_years_1_Firmness, GD_X_validate_all_years_Firmness, GD_Y_train_all_years_1_Firmness, GD_Y_validate_all_years_Firmness = train_test_split(GD_all_years_x, GD_all_years_y_firmness, test_size = 0.02, random_state = 42)
JZ_X_train_all_years_1_Firmness, JZ_X_validate_all_years_Firmness, JZ_Y_train_all_years_1_Firmness, JZ_Y_validate_all_years_Firmness = train_test_split(JZ_all_years_x, JZ_all_years_y_firmness, test_size = 0.02, random_state = 42)

Braeburn_X_train_all_years_Firmness, Braeburn_X_test_all_years_Firmness, Braeburn_Y_train_all_years_Firmness, Braeburn_Y_test_all_years_Firmness = train_test_split(Braeburn_X_train_all_years_1_Firmness, Braeburn_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
Cox_X_train_all_years_Firmness, Cox_X_test_all_years_Firmness, Cox_Y_train_all_years_Firmness, Cox_Y_test_all_years_Firmness = train_test_split(Cox_X_train_all_years_1_Firmness, Cox_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
Fuji_X_train_all_years_Firmness, Fuji_X_test_all_years_Firmness, Fuji_Y_train_all_years_Firmness, Fuji_Y_test_all_years_Firmness = train_test_split(Fuji_X_train_all_years_1_Firmness, Fuji_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
Gala_X_train_all_years_Firmness, Gala_X_test_all_years_Firmness, Gala_Y_train_all_years_Firmness, Gala_Y_test_all_years_Firmness = train_test_split(Gala_X_train_all_years_1_Firmness, Gala_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
GD_X_train_all_years_Firmness, GD_X_test_all_years_Firmness, GD_Y_train_all_years_Firmness, GD_Y_test_all_years_Firmness = train_test_split(GD_X_train_all_years_1_Firmness, GD_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
JZ_X_train_all_years_Firmness, JZ_X_test_all_years_Firmness, JZ_Y_train_all_years_Firmness, JZ_Y_test_all_years_Firmness = train_test_split(JZ_X_train_all_years_1_Firmness, JZ_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)

# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_all_years_Firmness = np.concatenate((Braeburn_Y_train_all_years_Firmness, Cox_Y_train_all_years_Firmness, Fuji_Y_train_all_years_Firmness, Gala_Y_train_all_years_Firmness, GD_Y_train_all_years_Firmness, JZ_Y_train_all_years_Firmness), axis=0)
Y_validate_all_years_Firmness = np.concatenate((Braeburn_Y_validate_all_years_Firmness, Cox_Y_validate_all_years_Firmness, Fuji_Y_validate_all_years_Firmness, Gala_Y_validate_all_years_Firmness, GD_Y_validate_all_years_Firmness, JZ_Y_validate_all_years_Firmness), axis=0)
Y_test_all_years_Firmness = np.concatenate((Braeburn_Y_test_all_years_Firmness, Cox_Y_test_all_years_Firmness, Fuji_Y_test_all_years_Firmness, Gala_Y_test_all_years_Firmness, GD_Y_test_all_years_Firmness, JZ_Y_test_all_years_Firmness), axis=0)
X_train_all_years_Firmness = np.concatenate((Braeburn_X_train_all_years_Firmness, Cox_X_train_all_years_Firmness, Fuji_X_train_all_years_Firmness, Gala_X_train_all_years_Firmness, GD_X_train_all_years_Firmness, JZ_X_train_all_years_Firmness), axis=0)
X_validate_all_years_Firmness = np.concatenate((Braeburn_X_validate_all_years_Firmness, Cox_X_validate_all_years_Firmness, Fuji_X_validate_all_years_Firmness, Gala_X_validate_all_years_Firmness, GD_X_validate_all_years_Firmness, JZ_X_validate_all_years_Firmness), axis=0)
X_test_all_years_Firmness = np.concatenate((Braeburn_X_test_all_years_Firmness, Cox_X_test_all_years_Firmness, Fuji_X_test_all_years_Firmness, Gala_X_test_all_years_Firmness, GD_X_test_all_years_Firmness, JZ_X_test_all_years_Firmness), axis=0)


### Side A only
BB_Side_A_X_train_all_years_1_Firmness, BB_Side_A_X_validate_all_years_Firmness, BB_Side_A_Y_train_all_years_1_Firmness, BB_Side_A_Y_validate_all_years_Firmness = train_test_split(Side_A_BB_x, BB_side_A_y_firmness_df, test_size = 0.02, random_state = 42)
CX_Side_A_X_train_all_years_1_Firmness, CX_Side_A_X_validate_all_years_Firmness, CX_Side_A_Y_train_all_years_1_Firmness, CX_Side_A_Y_validate_all_years_Firmness = train_test_split(Side_A_CX_x, CX_side_A_y_firmness_df, test_size = 0.02, random_state = 42)
FJ_Side_A_X_train_all_years_1_Firmness, FJ_Side_A_X_validate_all_years_Firmness, FJ_Side_A_Y_train_all_years_1_Firmness, FJ_Side_A_Y_validate_all_years_Firmness = train_test_split(Side_A_FJ_x, FJ_side_A_y_firmness_df, test_size = 0.02, random_state = 42)
GL_Side_A_X_train_all_years_1_Firmness, GL_Side_A_X_validate_all_years_Firmness, GL_Side_A_Y_train_all_years_1_Firmness, GL_Side_A_Y_validate_all_years_Firmness = train_test_split(Side_A_GL_x, GL_side_A_y_firmness_df, test_size = 0.02, random_state = 42)
GD_Side_A_X_train_all_years_1_Firmness, GD_Side_A_X_validate_all_years_Firmness, GD_Side_A_Y_train_all_years_1_Firmness, GD_Side_A_Y_validate_all_years_Firmness = train_test_split(Side_A_GD_x, GD_side_A_y_firmness_df, test_size = 0.02, random_state = 42)
JZ_Side_A_X_train_all_years_1_Firmness, JZ_Side_A_X_validate_all_years_Firmness, JZ_Side_A_Y_train_all_years_1_Firmness, JZ_Side_A_Y_validate_all_years_Firmness = train_test_split(Side_A_JZ_x, JZ_side_A_y_firmness_df, test_size = 0.02, random_state = 42)

BB_Side_A_X_train_all_years_Firmness, BB_Side_A_X_test_all_years_Firmness, BB_Side_A_Y_train_all_years_Firmness, BB_Side_A_Y_test_all_years_Firmness = train_test_split(BB_Side_A_X_train_all_years_1_Firmness, BB_Side_A_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
CX_Side_A_X_train_all_years_Firmness, CX_Side_A_X_test_all_years_Firmness, CX_Side_A_Y_train_all_years_Firmness, CX_Side_A_Y_test_all_years_Firmness = train_test_split(CX_Side_A_X_train_all_years_1_Firmness, CX_Side_A_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
FJ_Side_A_X_train_all_years_Firmness, FJ_Side_A_X_test_all_years_Firmness, FJ_Side_A_Y_train_all_years_Firmness, FJ_Side_A_Y_test_all_years_Firmness = train_test_split(FJ_Side_A_X_train_all_years_1_Firmness, FJ_Side_A_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
GL_Side_A_X_train_all_years_Firmness, GL_Side_A_X_test_all_years_Firmness, GL_Side_A_Y_train_all_years_Firmness, GL_Side_A_Y_test_all_years_Firmness = train_test_split(GL_Side_A_X_train_all_years_1_Firmness, GL_Side_A_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
GD_Side_A_X_train_all_years_Firmness, GD_Side_A_X_test_all_years_Firmness, GD_Side_A_Y_train_all_years_Firmness, GD_Side_A_Y_test_all_years_Firmness = train_test_split(GD_Side_A_X_train_all_years_1_Firmness, GD_Side_A_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)
JZ_Side_A_X_train_all_years_Firmness, JZ_Side_A_X_test_all_years_Firmness, JZ_Side_A_Y_train_all_years_Firmness, JZ_Side_A_Y_test_all_years_Firmness = train_test_split(JZ_Side_A_X_train_all_years_1_Firmness, JZ_Side_A_Y_train_all_years_1_Firmness, test_size = 0.18, random_state = 42)

Side_A_Y_train_all_years_Firmness = np.concatenate((BB_Side_A_Y_train_all_years_Firmness, CX_Side_A_Y_train_all_years_Firmness, FJ_Side_A_Y_train_all_years_Firmness, GL_Side_A_Y_train_all_years_Firmness, GD_Side_A_Y_train_all_years_Firmness, JZ_Side_A_Y_train_all_years_Firmness), axis=0)
Side_A_Y_validate_all_years_Firmness = np.concatenate((BB_Side_A_Y_validate_all_years_Firmness, CX_Side_A_Y_validate_all_years_Firmness, FJ_Side_A_Y_validate_all_years_Firmness, GL_Side_A_Y_validate_all_years_Firmness, GD_Side_A_Y_validate_all_years_Firmness, JZ_Side_A_Y_validate_all_years_Firmness), axis=0)
Side_A_Y_test_all_years_Firmness = np.concatenate((BB_Side_A_Y_test_all_years_Firmness, CX_Side_A_Y_test_all_years_Firmness, FJ_Side_A_Y_test_all_years_Firmness, GL_Side_A_Y_test_all_years_Firmness, GD_Side_A_Y_test_all_years_Firmness, JZ_Side_A_Y_test_all_years_Firmness), axis=0)
Side_A_X_train_all_years_Firmness = np.concatenate((BB_Side_A_X_train_all_years_Firmness, CX_Side_A_X_train_all_years_Firmness, FJ_Side_A_X_train_all_years_Firmness, GL_Side_A_X_train_all_years_Firmness, GD_Side_A_X_train_all_years_Firmness, JZ_Side_A_X_train_all_years_Firmness), axis=0)
Side_A_X_validate_all_years_Firmness = np.concatenate((BB_Side_A_X_validate_all_years_Firmness, CX_Side_A_X_validate_all_years_Firmness, FJ_Side_A_X_validate_all_years_Firmness, GL_Side_A_X_validate_all_years_Firmness, GD_Side_A_X_validate_all_years_Firmness, JZ_Side_A_X_validate_all_years_Firmness), axis=0)
Side_A_X_test_all_years_Firmness = np.concatenate((BB_Side_A_X_test_all_years_Firmness, CX_Side_A_X_test_all_years_Firmness, FJ_Side_A_X_test_all_years_Firmness, GL_Side_A_X_test_all_years_Firmness, GD_Side_A_X_test_all_years_Firmness, JZ_Side_A_X_test_all_years_Firmness), axis=0)

# %%
print(min(Y_train_all_years_Firmness))
print(max(Y_train_all_years_Firmness))
# Out:
# 2.967170236523176
# 14.548291210556105

# %%
# # Cultivar separated and not one hot encoded

Braeburn_X_train_all_years_Firmness_shuffled, Braeburn_Y_train_all_years_Firmness_shuffled = shuffle(Braeburn_X_train_all_years_Firmness, Braeburn_Y_train_all_years_Firmness, random_state=775)
Braeburn_X_validate_all_years_Firmness_shuffled, Braeburn_Y_validate_all_years_Firmness_shuffled = shuffle(Braeburn_X_validate_all_years_Firmness, Braeburn_Y_validate_all_years_Firmness, random_state=775)
Braeburn_X_test_all_years_Firmness_shuffled, Braeburn_Y_test_all_years_Firmness_shuffled = shuffle(Braeburn_X_test_all_years_Firmness, Braeburn_Y_test_all_years_Firmness, random_state=775)

Fuji_X_train_all_years_Firmness_shuffled, Fuji_Y_train_all_years_Firmness_shuffled = shuffle(Fuji_X_train_all_years_Firmness, Fuji_Y_train_all_years_Firmness, random_state=775)
Fuji_X_validate_all_years_Firmness_shuffled, Fuji_Y_validate_all_years_Firmness_shuffled = shuffle(Fuji_X_validate_all_years_Firmness, Fuji_Y_validate_all_years_Firmness, random_state=775)
Fuji_X_test_all_years_Firmness_shuffled, Fuji_Y_test_all_years_Firmness_shuffled = shuffle(Fuji_X_test_all_years_Firmness, Fuji_Y_test_all_years_Firmness, random_state=775)

Gala_X_train_all_years_Firmness_shuffled, Gala_Y_train_all_years_Firmness_shuffled = shuffle(Gala_X_train_all_years_Firmness, Gala_Y_train_all_years_Firmness, random_state=775)
Gala_X_validate_all_years_Firmness_shuffled, Gala_Y_validate_all_years_Firmness_shuffled = shuffle(Gala_X_validate_all_years_Firmness, Gala_Y_validate_all_years_Firmness, random_state=775)
Gala_X_test_all_years_Firmness_shuffled, Gala_Y_test_all_years_Firmness_shuffled = shuffle(Gala_X_test_all_years_Firmness, Gala_Y_test_all_years_Firmness, random_state=775)

GD_X_train_all_years_Firmness_shuffled, GD_Y_train_all_years_Firmness_shuffled = shuffle(GD_X_train_all_years_Firmness, GD_Y_train_all_years_Firmness, random_state=775)
GD_X_validate_all_years_Firmness_shuffled, GD_Y_validate_all_years_Firmness_shuffled = shuffle(GD_X_validate_all_years_Firmness, GD_Y_validate_all_years_Firmness, random_state=775)
GD_X_test_all_years_Firmness_shuffled, GD_Y_test_all_years_Firmness_shuffled = shuffle(GD_X_test_all_years_Firmness, GD_Y_test_all_years_Firmness, random_state=775)



if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}all_years/Braeburn_X_train_all_years_Firmness_shuffled.npy', Braeburn_X_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_train_all_years_Firmness_shuffled.npy', Braeburn_Y_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_X_test_all_years_Firmness_shuffled.npy', Braeburn_X_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_test_all_years_Firmness_shuffled.npy', Braeburn_Y_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_X_validate_all_years_Firmness_shuffled.npy', Braeburn_X_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_validate_all_years_Firmness_shuffled.npy', Braeburn_Y_validate_all_years_Firmness_shuffled)

np.save(f'{training_data_save_path}all_years/Fuji_X_train_all_years_Firmness_shuffled.npy', Fuji_X_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_train_all_years_Firmness_shuffled.npy', Fuji_Y_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_X_test_all_years_Firmness_shuffled.npy', Fuji_X_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_test_all_years_Firmness_shuffled.npy', Fuji_Y_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_X_validate_all_years_Firmness_shuffled.npy', Fuji_X_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_validate_all_years_Firmness_shuffled.npy', Fuji_Y_validate_all_years_Firmness_shuffled)

np.save(f'{training_data_save_path}all_years/Gala_X_train_all_years_Firmness_shuffled.npy', Gala_X_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_train_all_years_Firmness_shuffled.npy', Gala_Y_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_X_test_all_years_Firmness_shuffled.npy', Gala_X_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_test_all_years_Firmness_shuffled.npy', Gala_Y_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_X_validate_all_years_Firmness_shuffled.npy', Gala_X_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_validate_all_years_Firmness_shuffled.npy', Gala_Y_validate_all_years_Firmness_shuffled)

np.save(f'{training_data_save_path}all_years/GD_X_train_all_years_Firmness_shuffled.npy', GD_X_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_train_all_years_Firmness_shuffled.npy', GD_Y_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/GD_X_test_all_years_Firmness_shuffled.npy', GD_X_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_test_all_years_Firmness_shuffled.npy', GD_Y_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/GD_X_validate_all_years_Firmness_shuffled.npy', GD_X_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_validate_all_years_Firmness_shuffled.npy', GD_Y_validate_all_years_Firmness_shuffled)

# %%
# # Hot encoding

Braeburn_X_train_all_years_Firmness_labels = np.array(["BB"]*len(Braeburn_X_train_all_years_Firmness))
Cox_X_train_all_years_Firmness_labels = np.array(["CX"]*len(Cox_X_train_all_years_Firmness))
Fuji_X_train_all_years_Firmness_labels = np.array(["FJ"]*len(Fuji_X_train_all_years_Firmness))
Gala_X_train_all_years_Firmness_labels = np.array(["GL"]*len(Gala_X_train_all_years_Firmness))
GD_X_train_all_years_Firmness_labels = np.array(["GD"]*len(GD_X_train_all_years_Firmness))
JZ_X_train_all_years_Firmness_labels = np.array(["JZ"]*len(JZ_X_train_all_years_Firmness))
Braeburn_X_test_all_years_Firmness_labels = np.array(["BB"]*len(Braeburn_X_test_all_years_Firmness))
Cox_X_test_all_years_Firmness_labels = np.array(["CX"]*len(Cox_X_test_all_years_Firmness))
Fuji_X_test_all_years_Firmness_labels = np.array(["FJ"]*len(Fuji_X_test_all_years_Firmness))
Gala_X_test_all_years_Firmness_labels = np.array(["GL"]*len(Gala_X_test_all_years_Firmness))
GD_X_test_all_years_Firmness_labels = np.array(["GD"]*len(GD_X_test_all_years_Firmness))
JZ_X_test_all_years_Firmness_labels = np.array(["JZ"]*len(JZ_X_test_all_years_Firmness))
Braeburn_X_validate_all_years_Firmness_labels = np.array(["BB"]*len(Braeburn_X_validate_all_years_Firmness))
Cox_X_validate_all_years_Firmness_labels = np.array(["CX"]*len(Cox_X_validate_all_years_Firmness))
Fuji_X_validate_all_years_Firmness_labels = np.array(["FJ"]*len(Fuji_X_validate_all_years_Firmness))
Gala_X_validate_all_years_Firmness_labels = np.array(["GL"]*len(Gala_X_validate_all_years_Firmness))
GD_X_validate_all_years_Firmness_labels = np.array(["GD"]*len(GD_X_validate_all_years_Firmness))
JZ_X_validate_all_years_Firmness_labels = np.array(["JZ"]*len(JZ_X_validate_all_years_Firmness))

Braeburn_X_train_all_years_Firmness_encoded = encoder.fit_transform(Braeburn_X_train_all_years_Firmness_labels.reshape(-1, 1))
Cox_X_train_all_years_Firmness_encoded = encoder.fit_transform(Cox_X_train_all_years_Firmness_labels.reshape(-1, 1))
Fuji_X_train_all_years_Firmness_encoded = encoder.fit_transform(Fuji_X_train_all_years_Firmness_labels.reshape(-1, 1))
Gala_X_train_all_years_Firmness_encoded = encoder.fit_transform(Gala_X_train_all_years_Firmness_labels.reshape(-1, 1))
GD_X_train_all_years_Firmness_encoded = encoder.fit_transform(GD_X_train_all_years_Firmness_labels.reshape(-1, 1))
JZ_X_train_all_years_Firmness_encoded = encoder.fit_transform(JZ_X_train_all_years_Firmness_labels.reshape(-1, 1))
Braeburn_X_test_all_years_Firmness_encoded = encoder.fit_transform(Braeburn_X_test_all_years_Firmness_labels.reshape(-1, 1))
Cox_X_test_all_years_Firmness_encoded = encoder.fit_transform(Cox_X_test_all_years_Firmness_labels.reshape(-1, 1))
Fuji_X_test_all_years_Firmness_encoded = encoder.fit_transform(Fuji_X_test_all_years_Firmness_labels.reshape(-1, 1))
Gala_X_test_all_years_Firmness_encoded = encoder.fit_transform(Gala_X_test_all_years_Firmness_labels.reshape(-1, 1))
GD_X_test_all_years_Firmness_encoded = encoder.fit_transform(GD_X_test_all_years_Firmness_labels.reshape(-1, 1))
JZ_X_test_all_years_Firmness_encoded = encoder.fit_transform(JZ_X_test_all_years_Firmness_labels.reshape(-1, 1))
Braeburn_X_validate_all_years_Firmness_encoded = encoder.fit_transform(Braeburn_X_validate_all_years_Firmness_labels.reshape(-1, 1))
Cox_X_validate_all_years_Firmness_encoded = encoder.fit_transform(Cox_X_validate_all_years_Firmness_labels.reshape(-1, 1))
Fuji_X_validate_all_years_Firmness_encoded = encoder.fit_transform(Fuji_X_validate_all_years_Firmness_labels.reshape(-1, 1))
Gala_X_validate_all_years_Firmness_encoded = encoder.fit_transform(Gala_X_validate_all_years_Firmness_labels.reshape(-1, 1))
GD_X_validate_all_years_Firmness_encoded = encoder.fit_transform(GD_X_validate_all_years_Firmness_labels.reshape(-1, 1))
JZ_X_validate_all_years_Firmness_encoded = encoder.fit_transform(JZ_X_validate_all_years_Firmness_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_all_years_Firmness_encoder = np.concatenate((Braeburn_X_train_all_years_Firmness_encoded, Cox_X_train_all_years_Firmness_encoded, Fuji_X_train_all_years_Firmness_encoded, Gala_X_train_all_years_Firmness_encoded, GD_X_train_all_years_Firmness_encoded, JZ_X_train_all_years_Firmness_encoded), axis=0)
X_validate_all_years_Firmness_encoder= np.concatenate((Braeburn_X_validate_all_years_Firmness_encoded, Cox_X_validate_all_years_Firmness_encoded, Fuji_X_validate_all_years_Firmness_encoded, Gala_X_validate_all_years_Firmness_encoded, GD_X_validate_all_years_Firmness_encoded, JZ_X_validate_all_years_Firmness_encoded), axis=0)
X_test_all_years_Firmness_encoder = np.concatenate((Braeburn_X_test_all_years_Firmness_encoded, Cox_X_test_all_years_Firmness_encoded, Fuji_X_test_all_years_Firmness_encoded, Gala_X_test_all_years_Firmness_encoded, GD_X_test_all_years_Firmness_encoded, JZ_X_test_all_years_Firmness_encoded), axis=0)



# Shuffle the data

Y_train_all_years_Firmness_shuffled, X_train_all_years_Firmness_shuffled, X_train_all_years_Firmness_encoder = shuffle(Y_train_all_years_Firmness, X_train_all_years_Firmness, X_train_all_years_Firmness_encoder, random_state=775)
Y_validate_all_years_Firmness_shuffled, X_validate_all_years_Firmness_shuffled, X_validate_all_years_Firmness_encoder = shuffle(Y_validate_all_years_Firmness, X_validate_all_years_Firmness, X_validate_all_years_Firmness_encoder, random_state=775)
Y_test_all_years_Firmness_shuffled, X_test_all_years_Firmness_shuffled, X_test_all_years_Firmness_encoder = shuffle(Y_test_all_years_Firmness, X_test_all_years_Firmness, X_test_all_years_Firmness_encoder, random_state=775)



# Hot encoding for side A

# Hot encoding

BB_Side_A_X_train_all_years_Firmness_labels = np.array(["BB"]*len(BB_Side_A_X_train_all_years_Firmness))
CX_Side_A_X_train_all_years_Firmness_labels = np.array(["CX"]*len(CX_Side_A_X_train_all_years_Firmness))
FJ_Side_A_X_train_all_years_Firmness_labels = np.array(["FJ"]*len(FJ_Side_A_X_train_all_years_Firmness))
GL_Side_A_X_train_all_years_Firmness_labels = np.array(["GL"]*len(GL_Side_A_X_train_all_years_Firmness))
GD_Side_A_X_train_all_years_Firmness_labels = np.array(["GD"]*len(GD_Side_A_X_train_all_years_Firmness))
JZ_Side_A_X_train_all_years_Firmness_labels = np.array(["JZ"]*len(JZ_Side_A_X_train_all_years_Firmness))
BB_Side_A_X_test_all_years_Firmness_labels = np.array(["BB"]*len(BB_Side_A_X_test_all_years_Firmness))
CX_Side_A_X_test_all_years_Firmness_labels = np.array(["CX"]*len(CX_Side_A_X_test_all_years_Firmness))
FJ_Side_A_X_test_all_years_Firmness_labels = np.array(["FJ"]*len(FJ_Side_A_X_test_all_years_Firmness))
GL_Side_A_X_test_all_years_Firmness_labels = np.array(["GL"]*len(GL_Side_A_X_test_all_years_Firmness))
GD_Side_A_X_test_all_years_Firmness_labels = np.array(["GD"]*len(GD_Side_A_X_test_all_years_Firmness))
JZ_Side_A_X_test_all_years_Firmness_labels = np.array(["JZ"]*len(JZ_Side_A_X_test_all_years_Firmness))
BB_Side_A_X_validate_all_years_Firmness_labels = np.array(["BB"]*len(BB_Side_A_X_validate_all_years_Firmness))
CX_Side_A_X_validate_all_years_Firmness_labels = np.array(["CX"]*len(CX_Side_A_X_validate_all_years_Firmness))
FJ_Side_A_X_validate_all_years_Firmness_labels = np.array(["FJ"]*len(FJ_Side_A_X_validate_all_years_Firmness))
GL_Side_A_X_validate_all_years_Firmness_labels = np.array(["GL"]*len(GL_Side_A_X_validate_all_years_Firmness))
GD_Side_A_X_validate_all_years_Firmness_labels = np.array(["GD"]*len(GD_Side_A_X_validate_all_years_Firmness))
JZ_Side_A_X_validate_all_years_Firmness_labels = np.array(["JZ"]*len(JZ_Side_A_X_validate_all_years_Firmness))


BB_Side_A_X_train_all_years_Firmness_encoded = encoder.fit_transform(BB_Side_A_X_train_all_years_Firmness_labels.reshape(-1, 1))
CX_A_X_train_all_years_Firmness_encoded = encoder.fit_transform(CX_Side_A_X_train_all_years_Firmness_labels.reshape(-1, 1))
FJ_A_X_train_all_years_Firmness_encoded = encoder.fit_transform(FJ_Side_A_X_train_all_years_Firmness_labels.reshape(-1, 1))
GL_A_X_train_all_years_Firmness_encoded = encoder.fit_transform(GL_Side_A_X_train_all_years_Firmness_labels.reshape(-1, 1))
GD_A_train_all_years_Firmness_encoded = encoder.fit_transform(GD_Side_A_X_train_all_years_Firmness_labels.reshape(-1, 1))
JZ_A_train_all_years_Firmness_encoded = encoder.fit_transform(JZ_Side_A_X_train_all_years_Firmness_labels.reshape(-1, 1))
BB_A_X_test_all_years_Firmness_encoded = encoder.fit_transform(BB_Side_A_X_test_all_years_Firmness_labels.reshape(-1, 1))
CX_A_test_all_years_Firmness_encoded = encoder.fit_transform(CX_Side_A_X_test_all_years_Firmness_labels.reshape(-1, 1))
FJ_A_X_test_all_years_Firmness_encoded = encoder.fit_transform(FJ_Side_A_X_test_all_years_Firmness_labels.reshape(-1, 1))
GL_A_X_test_all_years_Firmness_encoded = encoder.fit_transform(GL_Side_A_X_test_all_years_Firmness_labels.reshape(-1, 1))
GD_A_X_test_all_years_Firmness_encoded = encoder.fit_transform(GD_Side_A_X_test_all_years_Firmness_labels.reshape(-1, 1))
JZ_A_X_test_all_years_Firmness_encoded = encoder.fit_transform(JZ_Side_A_X_test_all_years_Firmness_labels.reshape(-1, 1))
BB_A_X_validate_all_years_Firmness_encoded = encoder.fit_transform(BB_Side_A_X_validate_all_years_Firmness_labels.reshape(-1, 1))
CX_A_validate_all_years_Firmness_encoded = encoder.fit_transform(CX_Side_A_X_validate_all_years_Firmness_labels.reshape(-1, 1))
FJ_A_X_validate_all_years_Firmness_encoded = encoder.fit_transform(FJ_Side_A_X_validate_all_years_Firmness_labels.reshape(-1, 1))
GL_A_X_validate_all_years_Firmness_encoded = encoder.fit_transform(GL_Side_A_X_validate_all_years_Firmness_labels.reshape(-1, 1))
GD_A_X_validate_all_years_Firmness_encoded = encoder.fit_transform(GD_Side_A_X_validate_all_years_Firmness_labels.reshape(-1, 1))
JZ_A_X_validate_all_years_Firmness_encoded = encoder.fit_transform(JZ_Side_A_X_validate_all_years_Firmness_labels.reshape(-1, 1))


# Combined all cultivar labels together
Side_A_X_train_all_years_Firmness_encoder = np.concatenate((BB_Side_A_X_train_all_years_Firmness_encoded, CX_A_X_train_all_years_Firmness_encoded, FJ_A_X_train_all_years_Firmness_encoded, GL_A_X_train_all_years_Firmness_encoded, GD_A_train_all_years_Firmness_encoded, JZ_A_train_all_years_Firmness_encoded), axis=0)
Side_A_X_validate_all_years_Firmness_encoder = np.concatenate((BB_A_X_validate_all_years_Firmness_encoded, CX_A_validate_all_years_Firmness_encoded, FJ_A_X_validate_all_years_Firmness_encoded, GL_A_X_validate_all_years_Firmness_encoded, GD_A_X_validate_all_years_Firmness_encoded, JZ_A_X_validate_all_years_Firmness_encoded), axis=0)
Side_A_X_test_all_years_Firmness_encoder = np.concatenate((BB_A_X_test_all_years_Firmness_encoded, CX_A_test_all_years_Firmness_encoded, FJ_A_X_test_all_years_Firmness_encoded, GL_A_X_test_all_years_Firmness_encoded, GD_A_X_test_all_years_Firmness_encoded, JZ_A_X_test_all_years_Firmness_encoded), axis=0)



# Shuffle the data

Side_A_Y_train_all_years_Firmness_shuffled, Side_A_X_train_all_years_Firmness_shuffled, Side_A_X_train_all_years_Firmness_encoder = shuffle(Side_A_Y_train_all_years_Firmness, Side_A_X_train_all_years_Firmness, Side_A_X_train_all_years_Firmness_encoder, random_state=775)
Side_A_Y_validate_all_years_Firmness_shuffled, Side_A_X_validate_all_years_Firmness_shuffled, Side_A_X_validate_all_years_Firmness_encoder = shuffle(Side_A_Y_validate_all_years_Firmness, Side_A_X_validate_all_years_Firmness, Side_A_X_validate_all_years_Firmness_encoder, random_state=775)
Side_A_Y_test_all_years_Firmness_shuffled, Side_A_X_test_all_years_Firmness_shuffled, Side_A_X_test_all_years_Firmness_encoder = shuffle(Side_A_Y_test_all_years_Firmness, Side_A_X_test_all_years_Firmness, Side_A_X_test_all_years_Firmness_encoder, random_state=775)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}all_years/Y_train_all_years_Firmness_shuffled.npy', Y_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Y_validate_all_years_Firmness_shuffled.npy', Y_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/Y_test_all_years_Firmness_shuffled.npy', Y_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/X_train_all_years_Firmness_shuffled.npy', X_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/X_validate_all_years_Firmness_shuffled.npy', X_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/X_test_all_years_Firmness_shuffled.npy', X_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}all_years/X_train_all_years_Firmness_encoder_shuffled.npy', X_train_all_years_Firmness_encoder)
np.save(f'{training_data_save_path}all_years/X_validate_all_years_Firmness_encoder_shuffled.npy', X_validate_all_years_Firmness_encoder)
np.save(f'{training_data_save_path}all_years/X_test_all_years_Firmness_encoder_shuffled.npy', X_test_all_years_Firmness_encoder)

# Side A

np.save(f'{training_data_save_path}Side_A_Y_train_all_years_Firmness_shuffled.npy', Side_A_Y_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}Side_A_X_train_all_years_Firmness_shuffled.npy', Side_A_X_train_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}Side_A_X_train_all_years_Firmness_encoder.npy', Side_A_X_train_all_years_Firmness_encoder)

np.save(f'{training_data_save_path}Side_A_Y_validate_all_years_Firmness_shuffled.npy', Side_A_Y_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}Side_A_X_validate_all_years_Firmness_shuffled.npy', Side_A_X_validate_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}Side_A_X_validate_all_years_Firmness_encoder.npy', Side_A_X_validate_all_years_Firmness_encoder)

np.save(f'{training_data_save_path}Side_A_Y_test_all_years_Firmness_shuffled.npy', Side_A_Y_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}Side_A_X_test_all_years_Firmness_shuffled.npy', Side_A_X_test_all_years_Firmness_shuffled)
np.save(f'{training_data_save_path}Side_A_X_test_all_years_Firmness_encoder.npy', Side_A_X_test_all_years_Firmness_encoder)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'
np.save(f'{training_data_save_path}all_years/Braeburn_X_train_all_years_Firmness_encoded.npy', Braeburn_X_train_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Cox_X_train_all_years_Firmness_encoded.npy', Cox_X_train_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Fuji_X_train_all_years_Firmness_encoded.npy', Fuji_X_train_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Gala_X_train_all_years_Firmness_encoded.npy', Gala_X_train_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/GD_X_train_all_years_Firmness_encoded.npy', GD_X_train_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/JZ_X_train_all_years_Firmness_encoded.npy', JZ_X_train_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Braeburn_X_test_all_years_Firmness_encoded.npy', Braeburn_X_test_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Cox_X_test_all_years_Firmness_encoded.npy', Cox_X_test_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Fuji_X_test_all_years_Firmness_encoded.npy', Fuji_X_test_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/Gala_X_test_all_years_Firmness_encoded.npy', Gala_X_test_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/GD_X_test_all_years_Firmness_encoded.npy', GD_X_test_all_years_Firmness_encoded)
np.save(f'{training_data_save_path}all_years/JZ_X_test_all_years_Firmness_encoded.npy', JZ_X_test_all_years_Firmness_encoded)

# %%
# Starch only all_data

Braeburn_X_train_all_years_1_Starch, Braeburn_X_validate_all_years_Starch, Braeburn_Y_train_all_years_1_Starch, Braeburn_Y_validate_all_years_Starch = train_test_split(BB_all_years_x, BB_all_years_y_starch, test_size = 0.02, random_state = 42)
Cox_X_train_all_years_1_Starch, Cox_X_validate_all_years_Starch, Cox_Y_train_all_years_1_Starch, Cox_Y_validate_all_years_Starch = train_test_split(CX_all_years_x, CX_all_years_y_starch, test_size = 0.02, random_state = 42)
Fuji_X_train_all_years_1_Starch, Fuji_X_validate_all_years_Starch, Fuji_Y_train_all_years_1_Starch, Fuji_Y_validate_all_years_Starch = train_test_split(FJ_all_years_x, FJ_all_years_y_starch, test_size = 0.02, random_state = 42)
Gala_X_train_all_years_1_Starch, Gala_X_validate_all_years_Starch, Gala_Y_train_all_years_1_Starch, Gala_Y_validate_all_years_Starch = train_test_split(GL_all_years_x, GL_all_years_y_starch, test_size = 0.02, random_state = 42)
GD_X_train_all_years_1_Starch, GD_X_validate_all_years_Starch, GD_Y_train_all_years_1_Starch, GD_Y_validate_all_years_Starch = train_test_split(GD_all_years_x, GD_all_years_y_starch, test_size = 0.02, random_state = 42)
JZ_X_train_all_years_1_Starch, JZ_X_validate_all_years_Starch, JZ_Y_train_all_years_1_Starch, JZ_Y_validate_all_years_Starch = train_test_split(JZ_all_years_x, JZ_all_years_y_starch, test_size = 0.02, random_state = 42)

Braeburn_X_train_all_years_Starch, Braeburn_X_test_all_years_Starch, Braeburn_Y_train_all_years_Starch, Braeburn_Y_test_all_years_Starch = train_test_split(Braeburn_X_train_all_years_1_Starch, Braeburn_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
Cox_X_train_all_years_Starch, Cox_X_test_all_years_Starch, Cox_Y_train_all_years_Starch, Cox_Y_test_all_years_Starch = train_test_split(Cox_X_train_all_years_1_Starch, Cox_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
Fuji_X_train_all_years_Starch, Fuji_X_test_all_years_Starch, Fuji_Y_train_all_years_Starch, Fuji_Y_test_all_years_Starch = train_test_split(Fuji_X_train_all_years_1_Starch, Fuji_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
Gala_X_train_all_years_Starch, Gala_X_test_all_years_Starch, Gala_Y_train_all_years_Starch, Gala_Y_test_all_years_Starch = train_test_split(Gala_X_train_all_years_1_Starch, Gala_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
GD_X_train_all_years_Starch, GD_X_test_all_years_Starch, GD_Y_train_all_years_Starch, GD_Y_test_all_years_Starch = train_test_split(GD_X_train_all_years_1_Starch, GD_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
JZ_X_train_all_years_Starch, JZ_X_test_all_years_Starch, JZ_Y_train_all_years_Starch, JZ_Y_test_all_years_Starch = train_test_split(JZ_X_train_all_years_1_Starch, JZ_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)


# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_all_years_Starch = np.concatenate((Braeburn_Y_train_all_years_Starch, Cox_Y_train_all_years_Starch, Fuji_Y_train_all_years_Starch, Gala_Y_train_all_years_Starch, GD_Y_train_all_years_Starch, JZ_Y_train_all_years_Starch), axis=0)
Y_validate_all_years_Starch = np.concatenate((Braeburn_Y_validate_all_years_Starch, Cox_Y_validate_all_years_Starch, Fuji_Y_validate_all_years_Starch, Gala_Y_validate_all_years_Starch, GD_Y_validate_all_years_Starch, JZ_Y_validate_all_years_Starch), axis=0)
Y_test_all_years_Starch = np.concatenate((Braeburn_Y_test_all_years_Starch, Cox_Y_test_all_years_Starch, Fuji_Y_test_all_years_Starch, Gala_Y_test_all_years_Starch, GD_Y_test_all_years_Starch, JZ_Y_test_all_years_Starch), axis=0)
X_train_all_years_Starch = np.concatenate((Braeburn_X_train_all_years_Starch, Cox_X_train_all_years_Starch, Fuji_X_train_all_years_Starch, Gala_X_train_all_years_Starch, GD_X_train_all_years_Starch, JZ_X_train_all_years_Starch), axis=0)
X_validate_all_years_Starch = np.concatenate((Braeburn_X_validate_all_years_Starch, Cox_X_validate_all_years_Starch, Fuji_X_validate_all_years_Starch, Gala_X_validate_all_years_Starch, GD_X_validate_all_years_Starch, JZ_X_validate_all_years_Starch), axis=0)
X_test_all_years_Starch = np.concatenate((Braeburn_X_test_all_years_Starch, Cox_X_test_all_years_Starch, Fuji_X_test_all_years_Starch, Gala_X_test_all_years_Starch, GD_X_test_all_years_Starch, JZ_X_test_all_years_Starch), axis=0)



### Side A only
BB_Side_A_X_train_all_years_1_Starch, BB_Side_A_X_validate_all_years_Starch, BB_Side_A_Y_train_all_years_1_Starch, BB_Side_A_Y_validate_all_years_Starch = train_test_split(Side_A_BB_x, BB_side_A_y_starch_df, test_size = 0.02, random_state = 42)
CX_Side_A_X_train_all_years_1_Starch, CX_Side_A_X_validate_all_years_Starch, CX_Side_A_Y_train_all_years_1_Starch, CX_Side_A_Y_validate_all_years_Starch = train_test_split(Side_A_CX_x, CX_side_A_y_starch_df, test_size = 0.02, random_state = 42)
FJ_Side_A_X_train_all_years_1_Starch, FJ_Side_A_X_validate_all_years_Starch, FJ_Side_A_Y_train_all_years_1_Starch, FJ_Side_A_Y_validate_all_years_Starch = train_test_split(Side_A_FJ_x, FJ_side_A_y_starch_df, test_size = 0.02, random_state = 42)
GL_Side_A_X_train_all_years_1_Starch, GL_Side_A_X_validate_all_years_Starch, GL_Side_A_Y_train_all_years_1_Starch, GL_Side_A_Y_validate_all_years_Starch = train_test_split(Side_A_GL_x, GL_side_A_y_starch_df, test_size = 0.02, random_state = 42)
GD_Side_A_X_train_all_years_1_Starch, GD_Side_A_X_validate_all_years_Starch, GD_Side_A_Y_train_all_years_1_Starch, GD_Side_A_Y_validate_all_years_Starch = train_test_split(Side_A_GD_x, GD_side_A_y_starch_df, test_size = 0.02, random_state = 42)
JZ_Side_A_X_train_all_years_1_Starch, JZ_Side_A_X_validate_all_years_Starch, JZ_Side_A_Y_train_all_years_1_Starch, JZ_Side_A_Y_validate_all_years_Starch = train_test_split(Side_A_JZ_x, JZ_side_A_y_starch_df, test_size = 0.02, random_state = 42)

BB_Side_A_X_train_all_years_Starch, BB_Side_A_X_test_all_years_Starch, BB_Side_A_Y_train_all_years_Starch, BB_Side_A_Y_test_all_years_Starch = train_test_split(BB_Side_A_X_train_all_years_1_Starch, BB_Side_A_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
CX_Side_A_X_train_all_years_Starch, CX_Side_A_X_test_all_years_Starch, CX_Side_A_Y_train_all_years_Starch, CX_Side_A_Y_test_all_years_Starch = train_test_split(CX_Side_A_X_train_all_years_1_Starch, CX_Side_A_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
FJ_Side_A_X_train_all_years_Starch, FJ_Side_A_X_test_all_years_Starch, FJ_Side_A_Y_train_all_years_Starch, FJ_Side_A_Y_test_all_years_Starch = train_test_split(FJ_Side_A_X_train_all_years_1_Starch, FJ_Side_A_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
GL_Side_A_X_train_all_years_Starch, GL_Side_A_X_test_all_years_Starch, GL_Side_A_Y_train_all_years_Starch, GL_Side_A_Y_test_all_years_Starch = train_test_split(GL_Side_A_X_train_all_years_1_Starch, GL_Side_A_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
GD_Side_A_X_train_all_years_Starch, GD_Side_A_X_test_all_years_Starch, GD_Side_A_Y_train_all_years_Starch, GD_Side_A_Y_test_all_years_Starch = train_test_split(GD_Side_A_X_train_all_years_1_Starch, GD_Side_A_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)
JZ_Side_A_X_train_all_years_Starch, JZ_Side_A_X_test_all_years_Starch, JZ_Side_A_Y_train_all_years_Starch, JZ_Side_A_Y_test_all_years_Starch = train_test_split(JZ_Side_A_X_train_all_years_1_Starch, JZ_Side_A_Y_train_all_years_1_Starch, test_size = 0.18, random_state = 42)

Side_A_Y_train_all_years_Starch = np.concatenate((BB_Side_A_Y_train_all_years_Starch, CX_Side_A_Y_train_all_years_Starch, FJ_Side_A_Y_train_all_years_Starch, GL_Side_A_Y_train_all_years_Starch, GD_Side_A_Y_train_all_years_Starch, JZ_Side_A_Y_train_all_years_Starch), axis=0)
Side_A_Y_validate_all_years_Starch = np.concatenate((BB_Side_A_Y_validate_all_years_Starch, CX_Side_A_Y_validate_all_years_Starch, FJ_Side_A_Y_validate_all_years_Starch, GL_Side_A_Y_validate_all_years_Starch, GD_Side_A_Y_validate_all_years_Starch, JZ_Side_A_Y_validate_all_years_Starch), axis=0)
Side_A_Y_test_all_years_Starch = np.concatenate((BB_Side_A_Y_test_all_years_Starch, CX_Side_A_Y_test_all_years_Starch, FJ_Side_A_Y_test_all_years_Starch, GL_Side_A_Y_test_all_years_Starch, GD_Side_A_Y_test_all_years_Starch, JZ_Side_A_Y_test_all_years_Starch), axis=0)
Side_A_X_train_all_years_Starch = np.concatenate((BB_Side_A_X_train_all_years_Starch, CX_Side_A_X_train_all_years_Starch, FJ_Side_A_X_train_all_years_Starch, GL_Side_A_X_train_all_years_Starch, GD_Side_A_X_train_all_years_Starch, JZ_Side_A_X_train_all_years_Starch), axis=0)
Side_A_X_validate_all_years_Starch = np.concatenate((BB_Side_A_X_validate_all_years_Starch, CX_Side_A_X_validate_all_years_Starch, FJ_Side_A_X_validate_all_years_Starch, GL_Side_A_X_validate_all_years_Starch, GD_Side_A_X_validate_all_years_Starch, JZ_Side_A_X_validate_all_years_Starch), axis=0)
Side_A_X_test_all_years_Starch = np.concatenate((BB_Side_A_X_test_all_years_Starch, CX_Side_A_X_test_all_years_Starch, FJ_Side_A_X_test_all_years_Starch, GL_Side_A_X_test_all_years_Starch, GD_Side_A_X_test_all_years_Starch, JZ_Side_A_X_test_all_years_Starch), axis=0)

# %%
# # Hot encoding

Braeburn_X_train_all_years_Starch_labels = np.array(["BB"]*len(Braeburn_X_train_all_years_Starch))
Cox_X_train_all_years_Starch_labels = np.array(["CX"]*len(Cox_X_train_all_years_Starch))
Fuji_X_train_all_years_Starch_labels = np.array(["FJ"]*len(Fuji_X_train_all_years_Starch))
Gala_X_train_all_years_Starch_labels = np.array(["GL"]*len(Gala_X_train_all_years_Starch))
GD_X_train_all_years_Starch_labels = np.array(["GD"]*len(GD_X_train_all_years_Starch))
JZ_X_train_all_years_Starch_labels = np.array(["JZ"]*len(JZ_X_train_all_years_Starch))
Braeburn_X_test_all_years_Starch_labels = np.array(["BB"]*len(Braeburn_X_test_all_years_Starch))
Cox_X_test_all_years_Starch_labels = np.array(["CX"]*len(Cox_X_test_all_years_Starch))
Fuji_X_test_all_years_Starch_labels = np.array(["FJ"]*len(Fuji_X_test_all_years_Starch))
Gala_X_test_all_years_Starch_labels = np.array(["GL"]*len(Gala_X_test_all_years_Starch))
GD_X_test_all_years_Starch_labels = np.array(["GD"]*len(GD_X_test_all_years_Starch))
JZ_X_test_all_years_Starch_labels = np.array(["JZ"]*len(JZ_X_test_all_years_Starch))
Braeburn_X_validate_all_years_Starch_labels = np.array(["BB"]*len(Braeburn_X_validate_all_years_Starch))
Cox_X_validate_all_years_Starch_labels = np.array(["CX"]*len(Cox_X_validate_all_years_Starch))
Fuji_X_validate_all_years_Starch_labels = np.array(["FJ"]*len(Fuji_X_validate_all_years_Starch))
Gala_X_validate_all_years_Starch_labels = np.array(["GL"]*len(Gala_X_validate_all_years_Starch))
GD_X_validate_all_years_Starch_labels = np.array(["GD"]*len(GD_X_validate_all_years_Starch))
JZ_X_validate_all_years_Starch_labels = np.array(["JZ"]*len(JZ_X_validate_all_years_Starch))

Braeburn_X_train_all_years_Starch_encoded = encoder.fit_transform(Braeburn_X_train_all_years_Starch_labels.reshape(-1, 1))
Cox_X_train_all_years_Starch_encoded = encoder.fit_transform(Cox_X_train_all_years_Starch_labels.reshape(-1, 1))
Fuji_X_train_all_years_Starch_encoded = encoder.fit_transform(Fuji_X_train_all_years_Starch_labels.reshape(-1, 1))
Gala_X_train_all_years_Starch_encoded = encoder.fit_transform(Gala_X_train_all_years_Starch_labels.reshape(-1, 1))
GD_X_train_all_years_Starch_encoded = encoder.fit_transform(GD_X_train_all_years_Starch_labels.reshape(-1, 1))
JZ_X_train_all_years_Starch_encoded = encoder.fit_transform(JZ_X_train_all_years_Starch_labels.reshape(-1, 1))
Braeburn_X_test_all_years_Starch_encoded = encoder.fit_transform(Braeburn_X_test_all_years_Starch_labels.reshape(-1, 1))
Cox_X_test_all_years_Starch_encoded = encoder.fit_transform(Cox_X_test_all_years_Starch_labels.reshape(-1, 1))
Fuji_X_test_all_years_Starch_encoded = encoder.fit_transform(Fuji_X_test_all_years_Starch_labels.reshape(-1, 1))
Gala_X_test_all_years_Starch_encoded = encoder.fit_transform(Gala_X_test_all_years_Starch_labels.reshape(-1, 1))
GD_X_test_all_years_Starch_encoded = encoder.fit_transform(GD_X_test_all_years_Starch_labels.reshape(-1, 1))
JZ_X_test_all_years_Starch_encoded = encoder.fit_transform(JZ_X_test_all_years_Starch_labels.reshape(-1, 1))
Braeburn_X_validate_all_years_Starch_encoded = encoder.fit_transform(Braeburn_X_validate_all_years_Starch_labels.reshape(-1, 1))
Cox_X_validate_all_years_Starch_encoded = encoder.fit_transform(Cox_X_validate_all_years_Starch_labels.reshape(-1, 1))
Fuji_X_validate_all_years_Starch_encoded = encoder.fit_transform(Fuji_X_validate_all_years_Starch_labels.reshape(-1, 1))
Gala_X_validate_all_years_Starch_encoded = encoder.fit_transform(Gala_X_validate_all_years_Starch_labels.reshape(-1, 1))
GD_X_validate_all_years_Starch_encoded = encoder.fit_transform(GD_X_validate_all_years_Starch_labels.reshape(-1, 1))
JZ_X_validate_all_years_Starch_encoded = encoder.fit_transform(JZ_X_validate_all_years_Starch_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_all_years_Starch_encoder = np.concatenate((Braeburn_X_train_all_years_Starch_encoded, Cox_X_train_all_years_Starch_encoded, Fuji_X_train_all_years_Starch_encoded, Gala_X_train_all_years_Starch_encoded, GD_X_train_all_years_Starch_encoded, JZ_X_train_all_years_Starch_encoded), axis=0)
X_validate_all_years_Starch_encoder= np.concatenate((Braeburn_X_validate_all_years_Starch_encoded, Cox_X_validate_all_years_Starch_encoded, Fuji_X_validate_all_years_Starch_encoded, Gala_X_validate_all_years_Starch_encoded, GD_X_validate_all_years_Starch_encoded, JZ_X_validate_all_years_Starch_encoded), axis=0)
X_test_all_years_Starch_encoder = np.concatenate((Braeburn_X_test_all_years_Starch_encoded, Cox_X_test_all_years_Starch_encoded, Fuji_X_test_all_years_Starch_encoded, Gala_X_test_all_years_Starch_encoded, GD_X_test_all_years_Starch_encoded, JZ_X_test_all_years_Starch_encoded), axis=0)



# Shuffle the data

Y_train_all_years_Starch_shuffled, X_train_all_years_Starch_shuffled, X_train_all_years_Starch_encoder = shuffle(Y_train_all_years_Starch, X_train_all_years_Starch, X_train_all_years_Starch_encoder, random_state=775)
Y_validate_all_years_Starch_shuffled, X_validate_all_years_Starch_shuffled, X_validate_all_years_Starch_encoder = shuffle(Y_validate_all_years_Starch, X_validate_all_years_Starch, X_validate_all_years_Starch_encoder, random_state=775)
Y_test_all_years_Starch_shuffled, X_test_all_years_Starch_shuffled, X_test_all_years_Starch_encoder = shuffle(Y_test_all_years_Starch, X_test_all_years_Starch, X_test_all_years_Starch_encoder, random_state=775)


# Hot encoding for side A

# Hot encoding

BB_Side_A_X_train_all_years_Starch_labels = np.array(["BB"]*len(BB_Side_A_X_train_all_years_Starch))
CX_Side_A_X_train_all_years_Starch_labels = np.array(["CX"]*len(CX_Side_A_X_train_all_years_Starch))
FJ_Side_A_X_train_all_years_Starch_labels = np.array(["FJ"]*len(FJ_Side_A_X_train_all_years_Starch))
GL_Side_A_X_train_all_years_Starch_labels = np.array(["GL"]*len(GL_Side_A_X_train_all_years_Starch))
GD_Side_A_X_train_all_years_Starch_labels = np.array(["GD"]*len(GD_Side_A_X_train_all_years_Starch))
JZ_Side_A_X_train_all_years_Starch_labels = np.array(["JZ"]*len(JZ_Side_A_X_train_all_years_Starch))
BB_Side_A_X_test_all_years_Starch_labels = np.array(["BB"]*len(BB_Side_A_X_test_all_years_Starch))
CX_Side_A_X_test_all_years_Starch_labels = np.array(["CX"]*len(CX_Side_A_X_test_all_years_Starch))
FJ_Side_A_X_test_all_years_Starch_labels = np.array(["FJ"]*len(FJ_Side_A_X_test_all_years_Starch))
GL_Side_A_X_test_all_years_Starch_labels = np.array(["GL"]*len(GL_Side_A_X_test_all_years_Starch))
GD_Side_A_X_test_all_years_Starch_labels = np.array(["GD"]*len(GD_Side_A_X_test_all_years_Starch))
JZ_Side_A_X_test_all_years_Starch_labels = np.array(["JZ"]*len(JZ_Side_A_X_test_all_years_Starch))
BB_Side_A_X_validate_all_years_Starch_labels = np.array(["BB"]*len(BB_Side_A_X_validate_all_years_Starch))
CX_Side_A_X_validate_all_years_Starch_labels = np.array(["CX"]*len(CX_Side_A_X_validate_all_years_Starch))
FJ_Side_A_X_validate_all_years_Starch_labels = np.array(["FJ"]*len(FJ_Side_A_X_validate_all_years_Starch))
GL_Side_A_X_validate_all_years_Starch_labels = np.array(["GL"]*len(GL_Side_A_X_validate_all_years_Starch))
GD_Side_A_X_validate_all_years_Starch_labels = np.array(["GD"]*len(GD_Side_A_X_validate_all_years_Starch))
JZ_Side_A_X_validate_all_years_Starch_labels = np.array(["JZ"]*len(JZ_Side_A_X_validate_all_years_Starch))


BB_Side_A_X_train_all_years_Starch_encoded = encoder.fit_transform(BB_Side_A_X_train_all_years_Starch_labels.reshape(-1, 1))
CX_A_X_train_all_years_Starch_encoded = encoder.fit_transform(CX_Side_A_X_train_all_years_Starch_labels.reshape(-1, 1))
FJ_A_X_train_all_years_Starch_encoded = encoder.fit_transform(FJ_Side_A_X_train_all_years_Starch_labels.reshape(-1, 1))
GL_A_X_train_all_years_Starch_encoded = encoder.fit_transform(GL_Side_A_X_train_all_years_Starch_labels.reshape(-1, 1))
GD_A_train_all_years_Starch_encoded = encoder.fit_transform(GD_Side_A_X_train_all_years_Starch_labels.reshape(-1, 1))
JZ_A_train_all_years_Starch_encoded = encoder.fit_transform(JZ_Side_A_X_train_all_years_Starch_labels.reshape(-1, 1))
BB_A_X_test_all_years_Starch_encoded = encoder.fit_transform(BB_Side_A_X_test_all_years_Starch_labels.reshape(-1, 1))
CX_A_test_all_years_Starch_encoded = encoder.fit_transform(CX_Side_A_X_test_all_years_Starch_labels.reshape(-1, 1))
FJ_A_X_test_all_years_Starch_encoded = encoder.fit_transform(FJ_Side_A_X_test_all_years_Starch_labels.reshape(-1, 1))
GL_A_X_test_all_years_Starch_encoded = encoder.fit_transform(GL_Side_A_X_test_all_years_Starch_labels.reshape(-1, 1))
GD_A_X_test_all_years_Starch_encoded = encoder.fit_transform(GD_Side_A_X_test_all_years_Starch_labels.reshape(-1, 1))
JZ_A_X_test_all_years_Starch_encoded = encoder.fit_transform(JZ_Side_A_X_test_all_years_Starch_labels.reshape(-1, 1))
BB_A_X_validate_all_years_Starch_encoded = encoder.fit_transform(BB_Side_A_X_validate_all_years_Starch_labels.reshape(-1, 1))
CX_A_validate_all_years_Starch_encoded = encoder.fit_transform(CX_Side_A_X_validate_all_years_Starch_labels.reshape(-1, 1))
FJ_A_X_validate_all_years_Starch_encoded = encoder.fit_transform(FJ_Side_A_X_validate_all_years_Starch_labels.reshape(-1, 1))
GL_A_X_validate_all_years_Starch_encoded = encoder.fit_transform(GL_Side_A_X_validate_all_years_Starch_labels.reshape(-1, 1))
GD_A_X_validate_all_years_Starch_encoded = encoder.fit_transform(GD_Side_A_X_validate_all_years_Starch_labels.reshape(-1, 1))
JZ_A_X_validate_all_years_Starch_encoded = encoder.fit_transform(JZ_Side_A_X_validate_all_years_Starch_labels.reshape(-1, 1))


# Combined all cultivar labels together
Side_A_X_train_all_years_Starch_encoder = np.concatenate((BB_Side_A_X_train_all_years_Starch_encoded, CX_A_X_train_all_years_Starch_encoded, FJ_A_X_train_all_years_Starch_encoded, GL_A_X_train_all_years_Starch_encoded, GD_A_train_all_years_Starch_encoded, JZ_A_train_all_years_Starch_encoded), axis=0)
Side_A_X_validate_all_years_Starch_encoder = np.concatenate((BB_A_X_validate_all_years_Starch_encoded, CX_A_validate_all_years_Starch_encoded, FJ_A_X_validate_all_years_Starch_encoded, GL_A_X_validate_all_years_Starch_encoded, GD_A_X_validate_all_years_Starch_encoded, JZ_A_X_validate_all_years_Starch_encoded), axis=0)
Side_A_X_test_all_years_Starch_encoder = np.concatenate((BB_A_X_test_all_years_Starch_encoded, CX_A_test_all_years_Starch_encoded, FJ_A_X_test_all_years_Starch_encoded, GL_A_X_test_all_years_Starch_encoded, GD_A_X_test_all_years_Starch_encoded, JZ_A_X_test_all_years_Starch_encoded), axis=0)



# Shuffle the data

Side_A_Y_train_all_years_Starch_shuffled, Side_A_X_train_all_years_Starch_shuffled, Side_A_X_train_all_years_Starch_encoder = shuffle(Side_A_Y_train_all_years_Starch, Side_A_X_train_all_years_Starch, Side_A_X_train_all_years_Starch_encoder, random_state=775)
Side_A_Y_validate_all_years_Starch_shuffled, Side_A_X_validate_all_years_Starch_shuffled, Side_A_X_validate_all_years_Starch_encoder = shuffle(Side_A_Y_validate_all_years_Starch, Side_A_X_validate_all_years_Starch, Side_A_X_validate_all_years_Starch_encoder, random_state=775)
Side_A_Y_test_all_years_Starch_shuffled, Side_A_X_test_all_years_Starch_shuffled, Side_A_X_test_all_years_Starch_encoder = shuffle(Side_A_Y_test_all_years_Starch, Side_A_X_test_all_years_Starch, Side_A_X_test_all_years_Starch_encoder, random_state=775)

# %%
# Cultivar separated and not one hot encoded

Braeburn_X_train_all_years_Starch_shuffled, Braeburn_Y_train_all_years_Starch_shuffled = shuffle(Braeburn_X_train_all_years_Starch, Braeburn_Y_train_all_years_Starch, random_state=775)
Braeburn_X_validate_all_years_Starch_shuffled, Braeburn_Y_validate_all_years_Starch_shuffled = shuffle(Braeburn_X_validate_all_years_Starch, Braeburn_Y_validate_all_years_Starch, random_state=775)
Braeburn_X_test_all_years_Starch_shuffled, Braeburn_Y_test_all_years_Starch_shuffled = shuffle(Braeburn_X_test_all_years_Starch, Braeburn_Y_test_all_years_Starch, random_state=775)

Fuji_X_train_all_years_Starch_shuffled, Fuji_Y_train_all_years_Starch_shuffled = shuffle(Fuji_X_train_all_years_Starch, Fuji_Y_train_all_years_Starch, random_state=775)
Fuji_X_validate_all_years_Starch_shuffled, Fuji_Y_validate_all_years_Starch_shuffled = shuffle(Fuji_X_validate_all_years_Starch, Fuji_Y_validate_all_years_Starch, random_state=775)
Fuji_X_test_all_years_Starch_shuffled, Fuji_Y_test_all_years_Starch_shuffled = shuffle(Fuji_X_test_all_years_Starch, Fuji_Y_test_all_years_Starch, random_state=775)

Gala_X_train_all_years_Starch_shuffled, Gala_Y_train_all_years_Starch_shuffled = shuffle(Gala_X_train_all_years_Starch, Gala_Y_train_all_years_Starch, random_state=775)
Gala_X_validate_all_years_Starch_shuffled, Gala_Y_validate_all_years_Starch_shuffled = shuffle(Gala_X_validate_all_years_Starch, Gala_Y_validate_all_years_Starch, random_state=775)
Gala_X_test_all_years_Starch_shuffled, Gala_Y_test_all_years_Starch_shuffled = shuffle(Gala_X_test_all_years_Starch, Gala_Y_test_all_years_Starch, random_state=775)

GD_X_train_all_years_Starch_shuffled, GD_Y_train_all_years_Starch_shuffled = shuffle(GD_X_train_all_years_Starch, GD_Y_train_all_years_Starch, random_state=775)
GD_X_validate_all_years_Starch_shuffled, GD_Y_validate_all_years_Starch_shuffled = shuffle(GD_X_validate_all_years_Starch, GD_Y_validate_all_years_Starch, random_state=775)
GD_X_test_all_years_Starch_shuffled, GD_Y_test_all_years_Starch_shuffled = shuffle(GD_X_test_all_years_Starch, GD_Y_test_all_years_Starch, random_state=775)



if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}all_years/Braeburn_X_train_all_years_Starch_shuffled.npy', Braeburn_X_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_train_all_years_Starch_shuffled.npy', Braeburn_Y_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_X_test_all_years_Starch_shuffled.npy', Braeburn_X_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_test_all_years_Starch_shuffled.npy', Braeburn_Y_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_X_validate_all_years_Starch_shuffled.npy', Braeburn_X_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Braeburn_Y_validate_all_years_Starch_shuffled.npy', Braeburn_Y_validate_all_years_Starch_shuffled)

np.save(f'{training_data_save_path}all_years/Fuji_X_train_all_years_Starch_shuffled.npy', Fuji_X_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_train_all_years_Starch_shuffled.npy', Fuji_Y_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_X_test_all_years_Starch_shuffled.npy', Fuji_X_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_test_all_years_Starch_shuffled.npy', Fuji_Y_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_X_validate_all_years_Starch_shuffled.npy', Fuji_X_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Fuji_Y_validate_all_years_Starch_shuffled.npy', Fuji_Y_validate_all_years_Starch_shuffled)

np.save(f'{training_data_save_path}all_years/Gala_X_train_all_years_Starch_shuffled.npy', Gala_X_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_train_all_years_Starch_shuffled.npy', Gala_Y_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_X_test_all_years_Starch_shuffled.npy', Gala_X_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_test_all_years_Starch_shuffled.npy', Gala_Y_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_X_validate_all_years_Starch_shuffled.npy', Gala_X_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Gala_Y_validate_all_years_Starch_shuffled.npy', Gala_Y_validate_all_years_Starch_shuffled)

np.save(f'{training_data_save_path}all_years/GD_X_train_all_years_Starch_shuffled.npy', GD_X_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_train_all_years_Starch_shuffled.npy', GD_Y_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/GD_X_test_all_years_Starch_shuffled.npy', GD_X_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_test_all_years_Starch_shuffled.npy', GD_Y_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/GD_X_validate_all_years_Starch_shuffled.npy', GD_X_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/GD_Y_validate_all_years_Starch_shuffled.npy', GD_Y_validate_all_years_Starch_shuffled)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'


np.save(f'{training_data_save_path}all_years/Y_train_all_years_Starch_shuffled.npy', Y_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Y_validate_all_years_Starch_shuffled.npy', Y_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/Y_test_all_years_Starch_shuffled.npy', Y_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/X_train_all_years_Starch_shuffled.npy', X_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/X_validate_all_years_Starch_shuffled.npy', X_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/X_test_all_years_Starch_shuffled.npy', X_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}all_years/X_train_all_years_Starch_encoder_shuffled.npy', X_train_all_years_Starch_encoder)
np.save(f'{training_data_save_path}all_years/X_validate_all_years_Starch_encoder_shuffled.npy', X_validate_all_years_Starch_encoder)
np.save(f'{training_data_save_path}all_years/X_test_all_years_Starch_encoder_shuffled.npy', X_test_all_years_Starch_encoder)


# Side A

np.save(f'{training_data_save_path}Side_A_Y_train_all_years_Starch_shuffled.npy', Side_A_Y_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}Side_A_X_train_all_years_Starch_shuffled.npy', Side_A_X_train_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}Side_A_X_train_all_years_Starch_encoder.npy', Side_A_X_train_all_years_Starch_encoder)

np.save(f'{training_data_save_path}Side_A_Y_validate_all_years_Starch_shuffled.npy', Side_A_Y_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}Side_A_X_validate_all_years_Starch_shuffled.npy', Side_A_X_validate_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}Side_A_X_validate_all_years_Starch_encoder.npy', Side_A_X_validate_all_years_Starch_encoder)

np.save(f'{training_data_save_path}Side_A_Y_test_all_years_Starch_shuffled.npy', Side_A_Y_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}Side_A_X_test_all_years_Starch_shuffled.npy', Side_A_X_test_all_years_Starch_shuffled)
np.save(f'{training_data_save_path}Side_A_X_test_all_years_Starch_encoder.npy', Side_A_X_test_all_years_Starch_encoder)

# %%
if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'
np.save(f'{training_data_save_path}all_years/Braeburn_X_train_all_years_Starch_encoded.npy', Braeburn_X_train_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Cox_X_train_all_years_Starch_encoded.npy', Cox_X_train_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Fuji_X_train_all_years_Starch_encoded.npy', Fuji_X_train_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Gala_X_train_all_years_Starch_encoded.npy', Gala_X_train_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/GD_X_train_all_years_Starch_encoded.npy', GD_X_train_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/JZ_X_train_all_years_Starch_encoded.npy', JZ_X_train_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Braeburn_X_test_all_years_Starch_encoded.npy', Braeburn_X_test_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Cox_X_test_all_years_Starch_encoded.npy', Cox_X_test_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Fuji_X_test_all_years_Starch_encoded.npy', Fuji_X_test_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/Gala_X_test_all_years_Starch_encoded.npy', Gala_X_test_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/GD_X_test_all_years_Starch_encoded.npy', GD_X_test_all_years_Starch_encoded)
np.save(f'{training_data_save_path}all_years/JZ_X_test_all_years_Starch_encoded.npy', JZ_X_test_all_years_Starch_encoded)

# %%
# Combine data from each year together - all variables


# y data 
BB_all_years_y_var3 = np.concatenate((BB_NZ2023_y_3_var, BB_NZ2024_y_3_var, BB_UK2024_y_3_var), axis=0)
CX_all_years_y_var3 = np.concatenate((CX_NZ2023_y_3_var, CX_UK2024_y_3_var), axis=0)
FJ_all_years_y_var3 = np.concatenate((FJ_NZ2023_y_3_var, FJ_NZ2024_y_3_var, FJ_UK2024_y_3_var), axis=0)
GL_all_years_y_var3 = np.concatenate((GL_NZ2023_y_3_var, GL_NZ2024_y_3_var, GL_UK2024_y_3_var), axis=0)
GD_all_years_y_var3 = np.concatenate((GD_NZ2023_y_3_var, GD_NZ2024_y_3_var, GD_UK2024_y_3_var), axis=0)
JZ_all_years_y_var3 = JZ_UK2024_y_3_var


# x data

BB_all_years_x = np.concatenate((BB_NZ2023_x, BB_NZ2024_x, BB_UK2024_x), axis=0)
CX_all_years_x = np.concatenate((CX_NZ2023_x, CX_UK2024_x), axis=0)
FJ_all_years_x = np.concatenate((FJ_NZ2023_x, FJ_NZ2024_x, FJ_UK2024_x), axis=0)
GL_all_years_x = np.concatenate((GL_NZ2023_x, GL_NZ2024_x, GL_UK2024_x), axis=0)
GD_all_years_x = np.concatenate((GD_NZ2023_x, GD_NZ2024_x, GD_UK2024_x), axis=0)
JZ_all_years_x = JZ_UK2024_x



Braeburn_X_train_all_years_1_var3, Braeburn_X_validate_all_years_var3, Braeburn_Y_train_all_years_1_var3, Braeburn_Y_validate_all_years_var3 = train_test_split(BB_all_years_x, BB_all_years_y_var3, test_size = 0.02, random_state = 42)
Cox_X_train_all_years_1_var3, Cox_X_validate_all_years_var3, Cox_Y_train_all_years_1_var3, Cox_Y_validate_all_years_var3 = train_test_split(CX_all_years_x, CX_all_years_y_var3, test_size = 0.02, random_state = 42)
Fuji_X_train_all_years_1_var3, Fuji_X_validate_all_years_var3, Fuji_Y_train_all_years_1_var3, Fuji_Y_validate_all_years_var3 = train_test_split(FJ_all_years_x, FJ_all_years_y_var3, test_size = 0.02, random_state = 42)
Gala_X_train_all_years_1_var3, Gala_X_validate_all_years_var3, Gala_Y_train_all_years_1_var3, Gala_Y_validate_all_years_var3 = train_test_split(GL_all_years_x, GL_all_years_y_var3, test_size = 0.02, random_state = 42)
GD_X_train_all_years_1_var3, GD_X_validate_all_years_var3, GD_Y_train_all_years_1_var3, GD_Y_validate_all_years_var3 = train_test_split(GD_all_years_x, GD_all_years_y_var3, test_size = 0.02, random_state = 42)
JZ_X_train_all_years_1_var3, JZ_X_validate_all_years_var3, JZ_Y_train_all_years_1_var3, JZ_Y_validate_all_years_var3 = train_test_split(JZ_all_years_x, JZ_all_years_y_var3, test_size = 0.02, random_state = 42)




Braeburn_X_train_all_years_var3, Braeburn_X_test_all_years_var3, Braeburn_Y_train_all_years_var3, Braeburn_Y_test_all_years_var3 = train_test_split(Braeburn_X_train_all_years_1_var3, Braeburn_Y_train_all_years_1_var3, test_size = 0.18, random_state = 42)
Cox_X_train_all_years_var3, Cox_X_test_all_years_var3, Cox_Y_train_all_years_var3, Cox_Y_test_all_years_var3 = train_test_split(Cox_X_train_all_years_1_var3, Cox_Y_train_all_years_1_var3, test_size = 0.18, random_state = 42)
Fuji_X_train_all_years_var3, Fuji_X_test_all_years_var3, Fuji_Y_train_all_years_var3, Fuji_Y_test_all_years_var3 = train_test_split(Fuji_X_train_all_years_1_var3, Fuji_Y_train_all_years_1_var3, test_size = 0.18, random_state = 42)
Gala_X_train_all_years_var3, Gala_X_test_all_years_var3, Gala_Y_train_all_years_var3, Gala_Y_test_all_years_var3 = train_test_split(Gala_X_train_all_years_1_var3, Gala_Y_train_all_years_1_var3, test_size = 0.18, random_state = 42)
GD_X_train_all_years_var3, GD_X_test_all_years_var3, GD_Y_train_all_years_var3, GD_Y_test_all_years_var3 = train_test_split(GD_X_train_all_years_1_var3, GD_Y_train_all_years_1_var3, test_size = 0.18, random_state = 42)
JZ_X_train_all_years_var3, JZ_X_test_all_years_var3, JZ_Y_train_all_years_var3, JZ_Y_test_all_years_var3 = train_test_split(JZ_X_train_all_years_1_var3, JZ_Y_train_all_years_1_var3, test_size = 0.18, random_state = 42)


# Combined all cultivars back together, thus ensuring all cultivars are evenly spread across training and testing 
Y_train_all_years_var3 = np.concatenate((Braeburn_Y_train_all_years_var3, Cox_Y_train_all_years_var3, Fuji_Y_train_all_years_var3, Gala_Y_train_all_years_var3, GD_Y_train_all_years_var3, JZ_Y_train_all_years_var3), axis=0)
Y_validate_all_years_var3 = np.concatenate((Braeburn_Y_validate_all_years_var3, Cox_Y_validate_all_years_var3, Fuji_Y_validate_all_years_var3, Gala_Y_validate_all_years_var3, GD_Y_validate_all_years_var3, JZ_Y_validate_all_years_var3), axis=0)
Y_test_all_years_var3 = np.concatenate((Braeburn_Y_test_all_years_var3, Cox_Y_test_all_years_var3, Fuji_Y_test_all_years_var3, Gala_Y_test_all_years_var3, GD_Y_test_all_years_var3, JZ_Y_test_all_years_var3), axis=0)
X_train_all_years_var3 = np.concatenate((Braeburn_X_train_all_years_var3, Cox_X_train_all_years_var3, Fuji_X_train_all_years_var3, Gala_X_train_all_years_var3, GD_X_train_all_years_var3, JZ_X_train_all_years_var3), axis=0)
X_validate_all_years_var3 = np.concatenate((Braeburn_X_validate_all_years_var3, Cox_X_validate_all_years_var3, Fuji_X_validate_all_years_var3, Gala_X_validate_all_years_var3, GD_X_validate_all_years_var3, JZ_X_validate_all_years_var3), axis=0)
X_test_all_years_var3 = np.concatenate((Braeburn_X_test_all_years_var3, Cox_X_test_all_years_var3, Fuji_X_test_all_years_var3, Gala_X_test_all_years_var3, GD_X_test_all_years_var3, JZ_X_test_all_years_var3), axis=0)

# Hot encoding

Braeburn_X_train_all_years_var3_labels = np.array(["BB"]*len(Braeburn_X_train_all_years_var3))
Cox_X_train_all_years_var3_labels = np.array(["CX"]*len(Cox_X_train_all_years_var3))
Fuji_X_train_all_years_var3_labels = np.array(["FJ"]*len(Fuji_X_train_all_years_var3))
Gala_X_train_all_years_var3_labels = np.array(["GL"]*len(Gala_X_train_all_years_var3))
GD_X_train_all_years_var3_labels = np.array(["GD"]*len(GD_X_train_all_years_var3))
JZ_X_train_all_years_var3_labels = np.array(["JZ"]*len(JZ_X_train_all_years_var3))
Braeburn_X_test_all_years_var3_labels = np.array(["BB"]*len(Braeburn_X_test_all_years_var3))
Cox_X_test_all_years_var3_labels = np.array(["CX"]*len(Cox_X_test_all_years_var3))
Fuji_X_test_all_years_var3_labels = np.array(["FJ"]*len(Fuji_X_test_all_years_var3))
Gala_X_test_all_years_var3_labels = np.array(["GL"]*len(Gala_X_test_all_years_var3))
GD_X_test_all_years_var3_labels = np.array(["GD"]*len(GD_X_test_all_years_var3))
JZ_X_test_all_years_var3_labels = np.array(["JZ"]*len(JZ_X_test_all_years_var3))
Braeburn_X_validate_all_years_var3_labels = np.array(["BB"]*len(Braeburn_X_validate_all_years_var3))
Cox_X_validate_all_years_var3_labels = np.array(["CX"]*len(Cox_X_validate_all_years_var3))
Fuji_X_validate_all_years_var3_labels = np.array(["FJ"]*len(Fuji_X_validate_all_years_var3))
Gala_X_validate_all_years_var3_labels = np.array(["GL"]*len(Gala_X_validate_all_years_var3))
GD_X_validate_all_years_var3_labels = np.array(["GD"]*len(GD_X_validate_all_years_var3))
JZ_X_validate_all_years_var3_labels = np.array(["JZ"]*len(JZ_X_validate_all_years_var3))

Braeburn_X_train_all_years_var3_encoded = encoder.fit_transform(Braeburn_X_train_all_years_var3_labels.reshape(-1, 1))
Cox_X_train_all_years_var3_encoded = encoder.fit_transform(Cox_X_train_all_years_var3_labels.reshape(-1, 1))
Fuji_X_train_all_years_var3_encoded = encoder.fit_transform(Fuji_X_train_all_years_var3_labels.reshape(-1, 1))
Gala_X_train_all_years_var3_encoded = encoder.fit_transform(Gala_X_train_all_years_var3_labels.reshape(-1, 1))
GD_X_train_all_years_var3_encoded = encoder.fit_transform(GD_X_train_all_years_var3_labels.reshape(-1, 1))
JZ_X_train_all_years_var3_encoded = encoder.fit_transform(JZ_X_train_all_years_var3_labels.reshape(-1, 1))
Braeburn_X_test_all_years_var3_encoded = encoder.fit_transform(Braeburn_X_test_all_years_var3_labels.reshape(-1, 1))
Cox_X_test_all_years_var3_encoded = encoder.fit_transform(Cox_X_test_all_years_var3_labels.reshape(-1, 1))
Fuji_X_test_all_years_var3_encoded = encoder.fit_transform(Fuji_X_test_all_years_var3_labels.reshape(-1, 1))
Gala_X_test_all_years_var3_encoded = encoder.fit_transform(Gala_X_test_all_years_var3_labels.reshape(-1, 1))
GD_X_test_all_years_var3_encoded = encoder.fit_transform(GD_X_test_all_years_var3_labels.reshape(-1, 1))
JZ_X_test_all_years_var3_encoded = encoder.fit_transform(JZ_X_test_all_years_var3_labels.reshape(-1, 1))
Braeburn_X_validate_all_years_var3_encoded = encoder.fit_transform(Braeburn_X_validate_all_years_var3_labels.reshape(-1, 1))
Cox_X_validate_all_years_var3_encoded = encoder.fit_transform(Cox_X_validate_all_years_var3_labels.reshape(-1, 1))
Fuji_X_validate_all_years_var3_encoded = encoder.fit_transform(Fuji_X_validate_all_years_var3_labels.reshape(-1, 1))
Gala_X_validate_all_years_var3_encoded = encoder.fit_transform(Gala_X_validate_all_years_var3_labels.reshape(-1, 1))
GD_X_validate_all_years_var3_encoded = encoder.fit_transform(GD_X_validate_all_years_var3_labels.reshape(-1, 1))
JZ_X_validate_all_years_var3_encoded = encoder.fit_transform(JZ_X_validate_all_years_var3_labels.reshape(-1, 1))


# Combined all cultivar labels together
X_train_all_years_var3_encoder = np.concatenate((Braeburn_X_train_all_years_var3_encoded, Cox_X_train_all_years_var3_encoded, Fuji_X_train_all_years_var3_encoded, Gala_X_train_all_years_var3_encoded, GD_X_train_all_years_var3_encoded, JZ_X_train_all_years_var3_encoded), axis=0)
X_validate_all_years_var3_encoder= np.concatenate((Braeburn_X_validate_all_years_var3_encoded, Cox_X_validate_all_years_var3_encoded, Fuji_X_validate_all_years_var3_encoded, Gala_X_validate_all_years_var3_encoded, GD_X_validate_all_years_var3_encoded, JZ_X_validate_all_years_var3_encoded), axis=0)
X_test_all_years_var3_encoder = np.concatenate((Braeburn_X_test_all_years_var3_encoded, Cox_X_test_all_years_var3_encoded, Fuji_X_test_all_years_var3_encoded, Gala_X_test_all_years_var3_encoded, GD_X_test_all_years_var3_encoded, JZ_X_test_all_years_var3_encoded), axis=0)



# Shuffle the data

Y_train_all_years_var3_shuffled, X_train_all_years_var3_shuffled, X_train_all_years_var3_encoder = shuffle(Y_train_all_years_var3, X_train_all_years_var3, X_train_all_years_var3_encoder, random_state=775)
Y_validate_all_years_var3_shuffled, X_validate_all_years_var3_shuffled, X_validate_all_years_var3_encoder = shuffle(Y_validate_all_years_var3, X_validate_all_years_var3, X_validate_all_years_var3_encoder, random_state=775)
Y_test_all_years_var3_shuffled, X_test_all_years_var3_shuffled, X_test_all_years_var3_encoder = shuffle(Y_test_all_years_var3, X_test_all_years_var3, X_test_all_years_var3_encoder, random_state=775)


if img_size == 30:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
elif img_size == 50:
    training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/'
var3_folder = 'all_3_variables/'

np.save(f'{training_data_save_path}all_years/{var3_folder}Y_train_all_years_var3_shuffled.npy', Y_train_all_years_var3_shuffled)
np.save(f'{training_data_save_path}all_years/{var3_folder}Y_validate_all_years_var3_shuffled.npy', Y_validate_all_years_var3_shuffled)
np.save(f'{training_data_save_path}all_years/{var3_folder}Y_test_all_years_var3_shuffled.npy', Y_test_all_years_var3_shuffled)
np.save(f'{training_data_save_path}all_years/{var3_folder}X_train_all_years_var3_shuffled.npy', X_train_all_years_var3_shuffled)
np.save(f'{training_data_save_path}all_years/{var3_folder}X_validate_all_years_var3_shuffled.npy', X_validate_all_years_var3_shuffled)
np.save(f'{training_data_save_path}all_years/{var3_folder}X_test_all_years_var3_shuffled.npy', X_test_all_years_var3_shuffled)
np.save(f'{training_data_save_path}all_years/{var3_folder}X_train_all_years_var3_encoder_shuffled.npy', X_train_all_years_var3_encoder)
np.save(f'{training_data_save_path}all_years/{var3_folder}X_validate_all_years_var3_encoder_shuffled.npy', X_validate_all_years_var3_encoder)
np.save(f'{training_data_save_path}all_years/{var3_folder}X_test_all_years_var3_encoder_shuffled.npy', X_test_all_years_var3_encoder)

# %% [markdown]
# # Checking the images are correct

# %%
training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
X_train_all_years_Starch_shuffled = np.load(f'{training_data_save_path}all_years/X_validate_all_years_Starch_shuffled.npy')

# %%
print(X_train_all_years_Starch_shuffled)
# Out:
# ['30x/NZ2024/30px_Fuji_1036_7387.npy' '30x/UK2024/30px_Gala_361_20078.npy'
#  '30x/UK2024/30px_Gala_318_20035.npy'
#  '30x/UK2024/30px_Fuji_1174_18291.npy'
#  '30x/UK2024/30px_Gala_2333_19422.npy'
#  "30x/NZ2023/30px_Cox's Orange Pippin_1049_2629.npy"
#  '30x/NZ2023/30px_Fuji_419_2075.npy'
#  '30x/UK2024/30px_Golden Delicious_2231_19320.npy'
#  '30x/UK2024/30px_Gala_41_12085.npy' '30x/NZ2023/30px_Fuji_755_5623.npy'
#  '30x/NZ2024/30px_Gala_59_7982.npy' '30x/NZ2024/30px_Fuji_847_8592.npy'
#  '30x/NZ2024/30px_Fuji_1308_11751.npy'
#  '30x/UK2024/30px_Braeburn_1245_20913.npy'
#  '30x/NZ2024/30px_Gala_709_7101.npy'
#  '30x/NZ2023/30px_Braeburn_1678_1605.npy'
#  '30x/UK2024/30px_Fuji_2146_16673.npy'
#  '30x/UK2024/30px_Gala_268_12312.npy'
#  '30x/NZ2024/30px_Fuji_1304_10392.npy'
#  "30x/NZ2023/30px_Cox's Orange Pippin_1067_1000.npy"
#  '30x/NZ2024/30px_Gala_722_9876.npy'
#  '30x/UK2024/30px_Golden Delicious_1183_20858.npy'
#  '30x/NZ2024/30px_Fuji_1245_11701.npy'
# ...

# %%
training_data_save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/'
X_train_all_years_Starch_shuffled = np.load(f'{training_data_save_path}all_years/X_validate_all_years_Starch_shuffled.npy')

# %%
print(X_train_all_years_Starch_shuffled)
# Out:
# ['50px/NZ2024/50px_Fuji_1036_7387.npy'
#  '50px/UK2024/50px_Gala_361_20078.npy'
#  '50px/UK2024/50px_Gala_318_20035.npy'
#  '50px/UK2024/50px_Fuji_1174_18291.npy'
#  '50px/UK2024/50px_Gala_2333_19422.npy'
#  "50px/NZ2023/50px_Cox's Orange Pippin_1049_2629.npy"
#  '50px/NZ2023/50px_Fuji_419_2075.npy'
#  '50px/UK2024/50px_Golden Delicious_2231_19320.npy'
#  '50px/UK2024/50px_Gala_41_12085.npy' '50px/NZ2023/50px_Fuji_755_5623.npy'
#  '50px/NZ2024/50px_Gala_59_7982.npy' '50px/NZ2024/50px_Fuji_847_8592.npy'
#  '50px/NZ2024/50px_Fuji_1308_11751.npy'
#  '50px/UK2024/50px_Braeburn_1245_20913.npy'
#  '50px/NZ2024/50px_Gala_709_7101.npy'
#  '50px/NZ2023/50px_Braeburn_1678_1605.npy'
#  '50px/UK2024/50px_Fuji_2146_16673.npy'
#  '50px/UK2024/50px_Gala_268_12312.npy'
#  '50px/NZ2024/50px_Fuji_1304_10392.npy'
#  "50px/NZ2023/50px_Cox's Orange Pippin_1067_1000.npy"
#  '50px/NZ2024/50px_Gala_722_9876.npy'
#  '50px/UK2024/50px_Golden Delicious_1183_20858.npy'
#  '50px/NZ2024/50px_Fuji_1245_11701.npy'
# ...

# %%
print(max(Y_train_all_years_Starch_shuffled))
print(min(Y_train_all_years_Starch_shuffled))
# Out:
# 100.0
# 0.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D
File_path = '/media/2tbdisk1/data/Haidee/Training_results/May2025/all_years_results/'
original_model = tf.keras.models.load_model(f"{File_path}2025-02-21run1_2025-02-21_model_file_firmness.keras")


original_layers = original_model.layers

first_conv_layer = original_layers[1] 

new_input = Input(shape=(30, 30, 204))

x = Conv2D(filters=first_conv_layer.filters,  # Same number of filters
           kernel_size=first_conv_layer.kernel_size,
           strides=first_conv_layer.strides,
           padding=first_conv_layer.padding,
           activation=first_conv_layer.activation,
           use_bias=first_conv_layer.use_bias,
           kernel_initializer=first_conv_layer.kernel_initializer)(new_input)

for layer in original_layers[2:]:  
    x = layer(x)

model_complex_firmness = Model(inputs=new_input, outputs=x)

model_complex_firmness.compile(optimizer="adam", loss="mean_squared_error", metrics=["mae"])
model_complex_firmness.summary()

# %%
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D

File_path = '/media/2tbdisk1/data/Haidee/Training_results/May2025/all_years_results/'
original_model = tf.keras.models.load_model(f"{File_path}2025-02-21run1_2025-02-21_model_file_firmness.keras")


original_layers = original_model.layers

# Print model summary in text form
original_model.summary()

# Save model architecture as a PNG image
plot_model(original_model, to_file="model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
original_layers = original_model.layers

first_conv_layer = original_layers[1]

# %%
from keras.models import clone_model   
clone_model = clone_model (original_model)
from tensorflow.keras.layers import Input


clone_model.build((None, 30, 30, 204))

clone_model.compile(optimizer="adam", loss="mean_squared_error", metrics=["mae"])
# clone_model.summary()

print(clone_model.layers[0].input)

print(original_model.layers[0].input)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    Flatten,
    Dense,
    BatchNormalization,
    Dropout,
    GlobalAveragePooling2D,
)

img_size = 30

input_shape = (img_size, img_size, 204)

# Extract the first convolutional layer from the original model
first_conv_layer = original_model.layers[1]

# Define a new input with the correct shape
new_input = Input(shape=(30, 30, 204))

# Create a new Conv2D layer with the same parameters but updated input shape
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    # Create a Sequential model
    x = Sequential()

    # Convolutional Block 1
    x.add(
        Conv2D(64, kernel_size=(2, 2), activation="relu", input_shape=input_shape) # kernal size format is common choice for image data
    )
    x.add(BatchNormalization())
    # model_complex_starch_only.add(MaxPooling2D(pool_size=(2, 2))) # cuts image in half
    x.add(Dropout(0.25))

# Reconnect the rest of the layers
for layer in original_model.layers[2:]:  # Start from the batch normalization layer
    x = layer(x)

# Create a new model with the modified input
modified_model = Model(inputs=new_input, outputs=x)

# Compile the new model
modified_model.compile(optimizer="adam", loss="mean_squared_error", metrics=["mae"])

# Print model summary
modified_model.summary()
