# %%
import torch
print(torch.cuda.is_available())


from detecto import core, utils, visualize
from detecto.visualize import show_labeled_image, plot_prediction_grid
from torchvision import transforms
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import re
import os

pd.set_option('display.max_columns', None)
# Out:
# True
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 5
#       1 import torch
#       2 print(torch.cuda.is_available())
# ----> 5 from detecto import core, utils, visualize
#       6 from detecto.visualize import show_labeled_image, plot_prediction_grid
#       7 from torchvision import transforms
#
# File ~/.local/lib/python3.10/site-packages/detecto/core.py:5
#       3 import random
#       4 import torch
# ----> 5 import torchvision
#       7 from detecto.config import config
#       8 from detecto.utils import default_transforms, filter_top_predictions, xml_to_csv, _is_iterable, read_image
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/torchvision/__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/torchvision/models/convnext.py:8
#       5 from torch import nn, Tensor
#       6 from torch.nn import functional as F
# ----> 8 from ..ops.misc import Conv2dNormActivation, Permute
#       9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/torchvision/ops/__init__.py:1
# ----> 1 from ._register_onnx_ops import _register_custom_op
#       2 from .boxes import (
#       3     batched_nms,
#       4     box_area,
#    (...)
#      13     remove_small_boxes,
#      14 )
#      15 from .ciou_loss import complete_box_iou_loss
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/torchvision/ops/_register_onnx_ops.py:5
#       2 import warnings
#       4 import torch
# ----> 5 from torch.onnx import symbolic_opset11 as opset11
#       6 from torch.onnx.symbolic_helper import parse_args
#       8 _ONNX_OPSET_VERSION_11 = 11
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/torch/onnx/__init__.py:46
#      33 from .errors import CheckerError  # Backwards compatibility
#      34 from .utils import (
#      35     _optimize_graph,
#      36     _run_symbolic_function,
#    (...)
#      43     unregister_custom_op_symbolic,
#      44 )
# ---> 46 from ._internal.exporter import (  # usort:skip. needs to be last to avoid circular import
#      47     ExportOptions,
#      48     ExportOutput,
#      49     ExportOutputSerializer,
#      50     dynamo_export,
#      51     OnnxExporterError,
#      52     enable_fake_mode,
#      53     OnnxRegistry,
#      54     DiagnosticOptions,
#      55 )
#      57 from ._internal.onnxruntime import (
#      58     is_onnxrt_backend_supported,
#      59     OrtBackend as _OrtBackend,
#      60     OrtBackendOptions as _OrtBackendOptions,
#      61     OrtExecutionProvider as _OrtExecutionProvider,
#      62 )
#      64 __all__ = [
#      65     # Modules
#      66     "symbolic_helper",
#    (...)
#     110     "is_onnxrt_backend_supported",
#     111 ]
#
# ImportError: cannot import name 'ExportOptions' from 'torch.onnx._internal.exporter' (/home/ht21074/miniconda3/envs/dl/lib/python3.10/site-packages/torch/onnx/_internal/exporter/__init__.py)

# %%
# load detection AI 

# model2 = core.Model.load("/media/data/model_weights.pth",['Apple'])
model2 = core.Model.load("/home/ht21074/Auto_box_apples/Auto_box_apples/new_detection_model2.pth",['Apple'])

# %%
# Sort bounding boxes
    # Read csv for all apples

##### Read csv file #####
data_NZ = pd.read_csv("/home/ht21074/Auto_box_apples/Auto_box_apples/maturity_data_2024NZ2.csv")
data_UK = pd.read_csv("/home/ht21074/Auto_box_apples/Auto_box_apples/maturity_data_2024UK2.csv")

data_NZ = data_NZ.dropna()
data_UK = data_UK.dropna()

data_NZ = data_NZ.reset_index()
data_UK = data_UK.reset_index()

print(data_NZ.head())
print(data_UK.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 # Sort bounding boxes
#       2     # Read csv for all apples
#       3
#       4 ##### Read csv file #####
# ----> 5 data_NZ = pd.read_csv("/home/ht21074/Auto_box_apples/Auto_box_apples/maturity_data_2024NZ2.csv")
#       6 data_UK = pd.read_csv("/home/ht21074/Auto_box_apples/Auto_box_apples/maturity_data_2024UK2.csv")
#       8 data_NZ = data_NZ.dropna()
#
# NameError: name 'pd' is not defined

# %%
import numpy as np
img_size = 40
if img_size == 30 or img_size == 20:
    training_data_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/30px/all_years/'
elif img_size == 50 or img_size ==40:
    training_data_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Training_data_May2025/50px/all_years/'


X_train_brix          = np.load(f'{training_data_path}X_train_all_years_Brix_shuffled.npy')
# print(X_train_brix)
Y_train_brix          = np.load(f'{training_data_path}Y_train_all_years_Brix_shuffled.npy')
X_validate_brix       = np.load(f'{training_data_path}X_validate_all_years_Brix_shuffled.npy')
Y_validate_brix       = np.load(f'{training_data_path}Y_validate_all_years_Brix_shuffled.npy')
Frmness_encoder_shuffled  = np.load(f'{training_data_path}X_train_all_years_Brix_encoder_shuffled.npy')
validate_encoder        = np.load(f'{training_data_path}X_validate_all_years_Brix_encoder_shuffled.npy')

# %%
print(X_train_brix[:2])

# test = np.load(X_train_brix[0])
# print(test.shape)
# Out:
# ['50px/NZ2024/50px_Braeburn_1453_7768.npy'
#  '50px/NZ2024/50px_Fuji_1423_11860.npy']

# %%
print(len(data_NZ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(len(data_NZ))
#
# NameError: name 'data_NZ' is not defined
