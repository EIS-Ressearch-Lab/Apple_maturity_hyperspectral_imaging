# %% [markdown]
# # Using FLOPs (Floating Point Operations) to calculate model complexity

# %%
import tensorflow as tf
# from tensorflow.keras import Model, Input
# from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout


from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
    forward_pass = tf.function(model.call, input_signature=[
        tf.TensorSpec(shape=(1,) + model.input_shape[1:], dtype=tf.float32)
    ])
    graph_info = profile(forward_pass.get_concrete_function().graph,
                         options=ProfileOptionBuilder.float_operation())
    return graph_info.total_float_ops

# %%
#Load models run 5 (before optimising) vs run 20 (bays opt)

File_path = '/media/2tbdisk3/data/Haidee/Results/'


# Run 5
prediction_model_starch_5 = tf.keras.models.load_model(f"{File_path}2025-05-21run5_40px_model_file_starch.keras")
prediction_model_brix_5 = tf.keras.models.load_model(f"{File_path}2025-05-21run5_40px_model_file_brix.keras")
prediction_model_firmness_5 = tf.keras.models.load_model(f"{File_path}2025-05-21run5_40px_model_file_firmness.keras")

# Run 20
prediction_model_starch_20 = tf.keras.models.load_model(f"{File_path}2025-07-04run_20_40px_model_trained_vit_starch.keras")
prediction_model_brix_20 = tf.keras.models.load_model(f"{File_path}2025-07-04run_20_40px_model_trained_vit_brix.keras")
prediction_model_firmness_20 = tf.keras.models.load_model(f"{File_path}2025-07-04run_20_40px_model_trained_vit_firmness.keras")
# Out:
# 2025-07-31 22:08:31.108679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79086 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:65:00.0, compute capability: 8.0
# 2025-07-31 22:08:31.110990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 79086 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:ca:00.0, compute capability: 8.0
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPUs will likely run quickly with dtype policy mixed_float16 as they all have compute capability of at least 7.0

# %%
get_flops(prediction_model_brix_5)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# ...

# %%
get_flops(prediction_model_brix_20)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# 239170785
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# ...

# %%
get_flops(prediction_model_firmness_5)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# ...

# %%
get_flops(prediction_model_firmness_20)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# ...

# %%
get_flops(prediction_model_starch_5)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# 459252801
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# ...

# %%
get_flops(prediction_model_starch_20)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# ...
