# %% [markdown]
# # Split the datasets into cultivars

# %%
# load modules

import numpy as np
import pandas as pd


# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)

pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 50)

# %%
# x_train = np.load('/home/ht21074/Auto_box_apples/Auto_box_apples/X_train.npy')
# y_train = np.load('/home/ht21074/Auto_box_apples/Auto_box_apples/Y_train.npy')

img_size = 30

# print(x_train[:3])
# print(y_train[:3])

# %%
# Load pickles

# save the metadata and processed images 
# Repeat for NZ2024 and UK2024

# save the metadata and processed images 
pickle_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/Tensors/'


files_NZ2023_a =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_a.pkl')
files_NZ2023_b =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_b.pkl')
files_NZ2023_c =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_c.pkl')
files_NZ2023_d =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_d.pkl')

files_NZ2024_a =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_a.pkl')
files_NZ2024_b =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_b.pkl')
files_NZ2024_c =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_c.pkl')
files_NZ2024_d =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_d.pkl')

files_UK2024_a =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_a.pkl')
files_UK2024_b =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_b.pkl')
files_UK2024_c =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_c.pkl')
files_UK2024_d =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_d.pkl')

# %%
print(len(files_UK2024_a))
print(len(files_UK2024_b))
print(len(files_UK2024_c))
print(len(files_UK2024_d))
# Out:
# 2569
# 2542
# 2562
# 2572

# %%
print(files_NZ2024_d.head())
# Out:
#                                     Image_folder_D    image_filename_D  \
# 0  20240307 Gala/2024-03-07_004/2024-03-07_004.png  2024-03-07_004.png
# 1  20240307 Gala/2024-03-07_004/2024-03-07_004.png  2024-03-07_004.png
# 2  20240307 Gala/2024-03-07_004/2024-03-07_004.png  2024-03-07_004.png
# 3  20240307 Gala/2024-03-07_004/2024-03-07_004.png  2024-03-07_004.png
# 4  20240307 Gala/2024-03-07_004/2024-03-07_004.png  2024-03-07_004.png
#
#        ID  Number  Firmness1  Firmness2   Brix  Starch  Starch2    Streif  \
# 0  Gala_1       1       7.75       7.44  12.69      32      9.0  5.386525
# 1  Gala_2       2       8.10       7.42  12.53      22      9.0  5.573823
# 2  Gala_3       3       8.02       7.09  11.80      28      9.0  5.762288
# 3  Gala_4       4       7.53       7.07  12.15      38      9.0  5.407407
# 4  Gala_5       5       7.30       7.11  12.36      31      9.0  5.246359
#
#    Avg_firmness Cultivar                      Spectral_folder_D  Count  \
# ...

# %%
print(files_NZ2024_d['Spectral_folder_D'][:1])
# Out:
# 0    20240307 Gala/2024-03-07_004/results/
# Name: Spectral_folder_D, dtype: object

# %%
# Get list of files via glob
# file_list_NZ2024 = glob.glob("/media/2tbdisk1/data/Haidee/Training_results/Spectral_numpys/NZ2024_Spectral/*.npy")
# file_list_UK2024 = glob.glob("/media/2tbdisk1/data/Haidee/Training_results/Spectral_numpys/UK2024_Spectral/*.npy")

# %%
# Create spectral_path_column

# spectral_path = '/media/2tbdisk3/data/Haidee/May_2025_spectral_img/Spectral/'

if img_size == 30:
    files_NZ2023_a['spectral_path'] = '30x/NZ2023/30px_' + files_NZ2023_a['img_ID'] + '.npy'
    files_NZ2023_b['spectral_path'] = '30x/NZ2023/30px_' + files_NZ2023_b['img_ID'] + '.npy'
    files_NZ2023_c['spectral_path'] = '30x/NZ2023/30px_' + files_NZ2023_c['img_ID'] + '.npy'
    files_NZ2023_d['spectral_path'] = '30x/NZ2023/30px_' + files_NZ2023_d['img_ID'] + '.npy'

    files_NZ2024_a['spectral_path'] = '30x/NZ2024/30px_' + files_NZ2024_a['img_ID'] + '.npy'
    files_NZ2024_b['spectral_path'] = '30x/NZ2024/30px_' + files_NZ2024_b['img_ID'] + '.npy'
    files_NZ2024_c['spectral_path'] = '30x/NZ2024/30px_' + files_NZ2024_c['img_ID'] + '.npy'
    files_NZ2024_d['spectral_path'] = '30x/NZ2024/30px_' + files_NZ2024_d['img_ID'] + '.npy'

    files_UK2024_a['spectral_path'] = '30x/UK2024/30px_' + files_UK2024_a['img_ID'] + '.npy'
    files_UK2024_b['spectral_path'] = '30x/UK2024/30px_' + files_UK2024_b['img_ID'] + '.npy'
    files_UK2024_c['spectral_path'] = '30x/UK2024/30px_' + files_UK2024_c['img_ID'] + '.npy'
    files_UK2024_d['spectral_path'] = '30x/UK2024/30px_' + files_UK2024_d['img_ID'] + '.npy'



    # # 50px files
elif img_size == 50:
    files_NZ2023_a['spectral_path'] = '50px/NZ2023/50px_' + files_NZ2023_a['img_ID'] + '.npy'
    files_NZ2023_b['spectral_path'] = '50px/NZ2023/50px_' + files_NZ2023_b['img_ID'] + '.npy'
    files_NZ2023_c['spectral_path'] = '50px/NZ2023/50px_' + files_NZ2023_c['img_ID'] + '.npy'
    files_NZ2023_d['spectral_path'] = '50px/NZ2023/50px_' + files_NZ2023_d['img_ID'] + '.npy'

    files_NZ2024_a['spectral_path'] = '50px/NZ2024/50px_' + files_NZ2024_a['img_ID'] + '.npy'
    files_NZ2024_b['spectral_path'] = '50px/NZ2024/50px_' + files_NZ2024_b['img_ID'] + '.npy'
    files_NZ2024_c['spectral_path'] = '50px/NZ2024/50px_' + files_NZ2024_c['img_ID'] + '.npy'
    files_NZ2024_d['spectral_path'] = '50px/NZ2024/50px_' + files_NZ2024_d['img_ID'] + '.npy'

    files_UK2024_a['spectral_path'] = '50px/UK2024/50px_' + files_UK2024_a['img_ID'] + '.npy'
    files_UK2024_b['spectral_path'] = '50px/UK2024/50px_' + files_UK2024_b['img_ID'] + '.npy'
    files_UK2024_c['spectral_path'] = '50px/UK2024/50px_' + files_UK2024_c['img_ID'] + '.npy'
    files_UK2024_d['spectral_path'] = '50px/UK2024/50px_' + files_UK2024_d['img_ID'] + '.npy'

# %%
print(files_UK2024_a['spectral_path'].head())
# Out:
# 0     30x/UK2024/30px_Cox_1_12045.npy
# 1     30x/UK2024/30px_Cox_2_12046.npy
# 2     30x/UK2024/30px_Cox_3_12047.npy
# 3     30x/UK2024/30px_Cox_4_12048.npy
# 4    30x/UK2024/30px_Gala_5_12049.npy
# Name: spectral_path, dtype: object

# %%
NZ2023_a = files_NZ2023_a.groupby(by="Cultivar")
NZ2023_b = files_NZ2023_b.groupby(by="Cultivar")
NZ2023_c = files_NZ2023_c.groupby(by="Cultivar")
NZ2023_d = files_NZ2023_d.groupby(by="Cultivar")

NZ2024_a = files_NZ2024_a.groupby(by="Cultivar")
NZ2024_b = files_NZ2024_b.groupby(by="Cultivar")
NZ2024_c = files_NZ2024_c.groupby(by="Cultivar")
NZ2024_d = files_NZ2024_d.groupby(by="Cultivar")

UK2024_a = files_UK2024_a.groupby(by="Cultivar")
UK2024_b = files_UK2024_b.groupby(by="Cultivar")
UK2024_c = files_UK2024_c.groupby(by="Cultivar")
UK2024_d = files_UK2024_d.groupby(by="Cultivar")

# %%
print(NZ2023_a.size())
print(NZ2024_b.size())
print(UK2024_c.size())
# Out:
# Cultivar
# Braeburn                47
# Cox's Orange Pippin    234
# Fuji                   803
# Gala                   463
# Golden Delicious       121
# dtype: int64
# Cultivar
# Braeburn            344
# Fuji                509
# Gala                417
# Golden Delicious    111
# dtype: int64
# Cultivar
# Braeburn            761
# Cox                 119
#                    ...
# Golden Delicious    553
# Jazz                 19
# Length: 6, dtype: int64

# %%
# # Get x file lists
# NZ2023
BB_NZ2023 = NZ2023_a.get_group('Braeburn')['spectral_path'].tolist() + NZ2023_b.get_group('Braeburn')['spectral_path'].tolist() + NZ2023_c.get_group('Braeburn')['spectral_path'].tolist() + NZ2023_d.get_group('Braeburn')['spectral_path'].tolist() 
CX_NZ2023 = NZ2023_a.get_group("Cox's Orange Pippin")['spectral_path'].tolist() + NZ2023_b.get_group("Cox's Orange Pippin")['spectral_path'].tolist() + NZ2023_c.get_group("Cox's Orange Pippin")['spectral_path'].tolist() + NZ2023_d.get_group("Cox's Orange Pippin")['spectral_path'].tolist() 
FJ_NZ2023 = NZ2023_a.get_group('Fuji')['spectral_path'].tolist() + NZ2023_b.get_group('Fuji')['spectral_path'].tolist() + NZ2023_c.get_group('Fuji')['spectral_path'].tolist() + NZ2023_d.get_group('Fuji')['spectral_path'].tolist() 
GL_NZ2023 = NZ2023_a.get_group('Gala')['spectral_path'].tolist() + NZ2023_b.get_group('Gala')['spectral_path'].tolist() + NZ2023_c.get_group('Gala')['spectral_path'].tolist() + NZ2023_d.get_group('Gala')['spectral_path'].tolist() 
GD_NZ2023 = NZ2023_a.get_group('Golden Delicious')['spectral_path'].tolist() + NZ2023_b.get_group('Golden Delicious')['spectral_path'].tolist() + NZ2023_c.get_group('Golden Delicious')['spectral_path'].tolist() + NZ2023_d.get_group('Golden Delicious')['spectral_path'].tolist() 

# All_cultivar_NZ2023 = BB_NZ2023 + CX_NZ2023 + FJ_NZ2023 + GL_NZ2023 + GD_NZ2023


#NZ2024
BB_NZ2024 = NZ2024_a.get_group('Braeburn')['spectral_path'].tolist() + NZ2024_b.get_group('Braeburn')['spectral_path'].tolist() + NZ2024_c.get_group('Braeburn')['spectral_path'].tolist() + NZ2024_d.get_group('Braeburn')['spectral_path'].tolist() 
FJ_NZ2024 = NZ2024_a.get_group('Fuji')['spectral_path'].tolist() + NZ2024_b.get_group('Fuji')['spectral_path'].tolist() + NZ2024_c.get_group('Fuji')['spectral_path'].tolist() + NZ2024_d.get_group('Fuji')['spectral_path'].tolist() 
GL_NZ2024 = NZ2024_a.get_group('Gala')['spectral_path'].tolist() + NZ2024_b.get_group('Gala')['spectral_path'].tolist() + NZ2024_c.get_group('Gala')['spectral_path'].tolist() + NZ2024_d.get_group('Gala')['spectral_path'].tolist() 
GD_NZ2024 = NZ2024_a.get_group('Golden Delicious')['spectral_path'].tolist() + NZ2024_b.get_group('Golden Delicious')['spectral_path'].tolist() + NZ2024_c.get_group('Golden Delicious')['spectral_path'].tolist() + NZ2024_d.get_group('Golden Delicious')['spectral_path'].tolist() 

# All_cultivar_NZ2024 = Braeburn_NZ2024 + Cox_NZ2024 + Fuji_NZ2024 + Gala_NZ2024 + Golden_Delicious_NZ2024
# All_cultivar_NZ2024 = BB_NZ2024 + FJ_NZ2024 + GL_NZ2024 + GD_NZ2024


#UK2024
BB_UK2024 = UK2024_a.get_group('Braeburn')['spectral_path'].tolist() + UK2024_b.get_group('Braeburn')['spectral_path'].tolist() + UK2024_c.get_group('Braeburn')['spectral_path'].tolist() + UK2024_d.get_group('Braeburn')['spectral_path'].tolist() 
CX_UK2024 = UK2024_a.get_group('Cox')['spectral_path'].tolist() + UK2024_b.get_group('Cox')['spectral_path'].tolist() + UK2024_c.get_group('Cox')['spectral_path'].tolist() + UK2024_d.get_group('Cox')['spectral_path'].tolist() 
FJ_UK2024 = UK2024_a.get_group('Fuji')['spectral_path'].tolist() + UK2024_b.get_group('Fuji')['spectral_path'].tolist() + UK2024_c.get_group('Fuji')['spectral_path'].tolist() + UK2024_d.get_group('Fuji')['spectral_path'].tolist() 
GL_UK2024 = UK2024_a.get_group('Gala')['spectral_path'].tolist() + UK2024_b.get_group('Gala')['spectral_path'].tolist() + UK2024_c.get_group('Gala')['spectral_path'].tolist() + UK2024_d.get_group('Gala')['spectral_path'].tolist() 
GD_UK2024 = UK2024_a.get_group('Golden Delicious')['spectral_path'].tolist() + UK2024_b.get_group('Golden Delicious')['spectral_path'].tolist() + UK2024_c.get_group('Golden Delicious')['spectral_path'].tolist() + UK2024_d.get_group('Golden Delicious')['spectral_path'].tolist() 
JZ_UK2024 = UK2024_a.get_group('Jazz')['spectral_path'].tolist() + UK2024_b.get_group('Jazz')['spectral_path'].tolist() + UK2024_c.get_group('Jazz')['spectral_path'].tolist() + UK2024_d.get_group('Jazz')['spectral_path'].tolist()

# All_cultivar_UK2024 = BB_UK2024 + CX_UK2024 + FJ_UK2024 + GL_UK2024 + GD_UK2024 + JZ_UK2024


Side_A_BB = NZ2023_a.get_group('Braeburn')['spectral_path'].tolist()  + NZ2024_a.get_group('Braeburn')['spectral_path'].tolist()  +UK2024_a.get_group('Braeburn')['spectral_path'].tolist() 
Side_A_CX = NZ2023_a.get_group("Cox's Orange Pippin")['spectral_path'].tolist() + UK2024_a.get_group('Cox')['spectral_path'].tolist() 
Side_A_FJ = NZ2023_a.get_group('Fuji')['spectral_path'].tolist() + NZ2024_a.get_group('Fuji')['spectral_path'].tolist() +UK2024_a.get_group('Fuji')['spectral_path'].tolist()
Side_A_GL = NZ2023_a.get_group('Gala')['spectral_path'].tolist() + NZ2024_a.get_group('Gala')['spectral_path'].tolist()+ UK2024_a.get_group('Gala')['spectral_path'].tolist()
Side_A_GD = NZ2023_a.get_group('Golden Delicious')['spectral_path'].tolist() +NZ2024_a.get_group('Golden Delicious')['spectral_path'].tolist() + UK2024_a.get_group('Golden Delicious')['spectral_path'].tolist() 
Side_A_JZ = UK2024_a.get_group('Jazz')['spectral_path'].tolist()

# %%
# # all cultivar should be generated after the train test splits

BB_NZ2023_array = np.array(BB_NZ2023)
CX_NZ2023_array = np.array(CX_NZ2023)
FJ_NZ2023_array = np.array(FJ_NZ2023)
GL_NZ2023_array = np.array(GL_NZ2023)
GD_NZ2023_array = np.array(GD_NZ2023)
# All_cultivar_NZ2023_array = np.array(All_cultivar_NZ2023)
BB_NZ2024_array = np.array(BB_NZ2024)
FJ_NZ2024_array = np.array(FJ_NZ2024)
GL_NZ2024_array = np.array(GL_NZ2024)
GD_NZ2024_array = np.array(GD_NZ2024)
# All_cultivar_NZ2024_array = np.array(All_cultivar_NZ2024)
BB_UK2024_array = np.array(BB_UK2024)
CX_UK2024_array = np.array(CX_UK2024)
FJ_UK2024_array = np.array(FJ_UK2024)
GL_UK2024_array = np.array(GL_UK2024)
GD_UK2024_array = np.array(GD_UK2024)
JZ_UK2024_array = np.array(JZ_UK2024)
# All_cultivar_UK2024_array = np.array(All_cultivar_UK2024)
Side_A_BB_array = np.array(Side_A_BB)
Side_A_CX_array = np.array(Side_A_CX)
Side_A_FJ_array = np.array(Side_A_FJ)
Side_A_GL_array = np.array(Side_A_GL)
Side_A_GD_array = np.array(Side_A_GD)
Side_A_JZ_array = np.array(Side_A_JZ)

# %%
print(Side_A_BB_array)
# Out:
# ['30x/NZ2023/30px_Braeburn_1655_1582.npy'
#  '30x/NZ2023/30px_Braeburn_1656_1583.npy'
#  '30x/NZ2023/30px_Braeburn_1657_1584.npy' ...
#  '30x/UK2024/30px_Braeburn_2654_14573.npy'
#  '30x/UK2024/30px_Braeburn_2655_14574.npy'
#  '30x/UK2024/30px_Braeburn_2656_14575.npy']

# %%
# Save x files (spectral path names)

if img_size == 30:
    x_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/x_files_May2025/30px_files/'
elif img_size == 50:
    x_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/x_files_May2025/50px_files/'

np.save(f'{x_file_path}BB_NZ2023_x.npy', BB_NZ2023_array)
np.save(f'{x_file_path}CX_NZ2023_x.npy', CX_NZ2023_array)
np.save(f'{x_file_path}FJ_NZ2023_x.npy', FJ_NZ2023_array)
np.save(f'{x_file_path}GL_NZ2023_x.npy', GL_NZ2023_array)
np.save(f'{x_file_path}GD_NZ2023_x.npy', GD_NZ2023_array)
# np.save(f'{x_file_path}All_cultivar_NZ2023_x.npy', All_cultivar_NZ2023_array)
np.save(f'{x_file_path}BB_NZ2024_x.npy', BB_NZ2024_array)
np.save(f'{x_file_path}FJ_NZ2024_x.npy', FJ_NZ2024_array)
np.save(f'{x_file_path}GL_NZ2024_x.npy', GL_NZ2024_array)
np.save(f'{x_file_path}GD_NZ2024_x.npy', GD_NZ2024_array)
# np.save(f'{x_file_path}All_cultivar_NZ2024_x.npy', All_cultivar_NZ2024_array)
np.save(f'{x_file_path}BB_UK2024_x.npy', BB_UK2024_array)
np.save(f'{x_file_path}CX_UK2024_x.npy', CX_UK2024_array)
np.save(f'{x_file_path}FJ_UK2024_x.npy', FJ_UK2024_array)
np.save(f'{x_file_path}GL_UK2024_x.npy', GL_UK2024_array)
np.save(f'{x_file_path}GD_UK2024_x.npy', GD_UK2024_array)
np.save(f'{x_file_path}JZ_UK2024_x.npy', JZ_UK2024_array)
# np.save(f'{x_file_path}All_cultivar_UK2024_x.npy', All_cultivar_UK2024_array)


np.save(f'{x_file_path}Side_A_BB_x.npy', Side_A_BB_array)
np.save(f'{x_file_path}Side_A_CX_x.npy', Side_A_CX_array)
np.save(f'{x_file_path}Side_A_FJ_x.npy', Side_A_FJ_array)
np.save(f'{x_file_path}Side_A_GL_x.npy', Side_A_GL_array)
np.save(f'{x_file_path}Side_A_GD_x.npy', Side_A_GD_array)
np.save(f'{x_file_path}Side_A_JZ_x.npy', Side_A_JZ_array)

# %%
print(CX_NZ2023_array[:3])
# Out:
# ["50px/NZ2023/50px_Cox's Orange Pippin_944_885.npy"
#  "50px/NZ2023/50px_Cox's Orange Pippin_945_886.npy"
#  "50px/NZ2023/50px_Cox's Orange Pippin_946_887.npy"]

# %%
test_dat = np.load('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/x_files_May2025/30px_files/BB_UK2024_x.npy')

# %%
print(test_dat)
# Out:
# ['30x/UK2024/30px_Braeburn_58_12102.npy'
#  '30x/UK2024/30px_Braeburn_59_12103.npy'
#  '30x/UK2024/30px_Braeburn_60_12104.npy' ...
#  '30x/UK2024/30px_Braeburn_1501_22273.npy'
#  '30x/UK2024/30px_Braeburn_1502_22274.npy'
#  '30x/UK2024/30px_Braeburn_1503_22275.npy']

# %%
NZ2023_a.get_group('Braeburn').columns
# Out:
# Index(['Image_folder_A', 'image_filename_A', 'ID', 'Number', 'Firmness1',
#        'Firmness2', 'Brix', 'Starch', 'Starch2', 'Streif', 'Avg_firmness',
#        'Cultivar', 'Spectral_folder_A', 'Count', 'tensors', 'img_ID',
#        'spectral_path'],
#       dtype='object')

# %%
# Create y files (maturity data) - fimrness

# # NZ2023
BB_NZ2023_y_firmness = NZ2023_a.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2023_b.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2023_c.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2023_d.get_group('Braeburn')['Avg_firmness'].tolist() 
CX_NZ2023_y_firmness = NZ2023_a.get_group("Cox's Orange Pippin")['Avg_firmness'].tolist() + NZ2023_b.get_group("Cox's Orange Pippin")['Avg_firmness'].tolist() + NZ2023_c.get_group("Cox's Orange Pippin")['Avg_firmness'].tolist() + NZ2023_d.get_group("Cox's Orange Pippin")['Avg_firmness'].tolist() 
FJ_NZ2023_y_firmness = NZ2023_a.get_group('Fuji')['Avg_firmness'].tolist() + NZ2023_b.get_group('Fuji')['Avg_firmness'].tolist() + NZ2023_c.get_group('Fuji')['Avg_firmness'].tolist() + NZ2023_d.get_group('Fuji')['Avg_firmness'].tolist() 
GL_NZ2023_y_firmness = NZ2023_a.get_group('Gala')['Avg_firmness'].tolist() + NZ2023_b.get_group('Gala')['Avg_firmness'].tolist() + NZ2023_c.get_group('Gala')['Avg_firmness'].tolist() + NZ2023_d.get_group('Gala')['Avg_firmness'].tolist() 
GD_NZ2023_y_firmness = NZ2023_a.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2023_b.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2023_c.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2023_d.get_group('Golden Delicious')['Avg_firmness'].tolist() 

# All_cultivar_NZ2023_y_firmness = BB_NZ2023_y_firmness + CX_NZ2023_y_firmness + FJ_NZ2023_y_firmness + GL_NZ2023_y_firmness + GD_NZ2023_y_firmness


# #NZ2024
BB_NZ2024_y_firmness = NZ2024_a.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2024_b.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2024_c.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2024_d.get_group('Braeburn')['Avg_firmness'].tolist() 
FJ_NZ2024_y_firmness = NZ2024_a.get_group('Fuji')['Avg_firmness'].tolist() + NZ2024_b.get_group('Fuji')['Avg_firmness'].tolist() + NZ2024_c.get_group('Fuji')['Avg_firmness'].tolist() + NZ2024_d.get_group('Fuji')['Avg_firmness'].tolist() 
GL_NZ2024_y_firmness = NZ2024_a.get_group('Gala')['Avg_firmness'].tolist() + NZ2024_b.get_group('Gala')['Avg_firmness'].tolist() + NZ2024_c.get_group('Gala')['Avg_firmness'].tolist() + NZ2024_d.get_group('Gala')['Avg_firmness'].tolist() 
GD_NZ2024_y_firmness = NZ2024_a.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2024_b.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2024_c.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2024_d.get_group('Golden Delicious')['Avg_firmness'].tolist() 

# All_cultivar_NZ2024 = Braeburn_NZ2024 + Cox_NZ2024 + Fuji_NZ2024 + Gala_NZ2024 + Golden_Delicious_NZ2024
# All_cultivar_NZ2024_y_firmness = BB_NZ2024_y_firmness + FJ_NZ2024_y_firmness + GL_NZ2024_y_firmness + GD_NZ2024_y_firmness


# #UK2024
BB_UK2024_y_firmness = UK2024_a.get_group('Braeburn')['Avg_firmness'].tolist() + UK2024_b.get_group('Braeburn')['Avg_firmness'].tolist() + UK2024_c.get_group('Braeburn')['Avg_firmness'].tolist() + UK2024_d.get_group('Braeburn')['Avg_firmness'].tolist() 
CX_UK2024_y_firmness = UK2024_a.get_group('Cox')['Avg_firmness'].tolist() + UK2024_b.get_group('Cox')['Avg_firmness'].tolist() + UK2024_c.get_group('Cox')['Avg_firmness'].tolist() + UK2024_d.get_group('Cox')['Avg_firmness'].tolist() 
FJ_UK2024_y_firmness = UK2024_a.get_group('Fuji')['Avg_firmness'].tolist() + UK2024_b.get_group('Fuji')['Avg_firmness'].tolist() + UK2024_c.get_group('Fuji')['Avg_firmness'].tolist() + UK2024_d.get_group('Fuji')['Avg_firmness'].tolist() 
GL_UK2024_y_firmness = UK2024_a.get_group('Gala')['Avg_firmness'].tolist() + UK2024_b.get_group('Gala')['Avg_firmness'].tolist() + UK2024_c.get_group('Gala')['Avg_firmness'].tolist() + UK2024_d.get_group('Gala')['Avg_firmness'].tolist() 
GD_UK2024_y_firmness = UK2024_a.get_group('Golden Delicious')['Avg_firmness'].tolist() + UK2024_b.get_group('Golden Delicious')['Avg_firmness'].tolist() + UK2024_c.get_group('Golden Delicious')['Avg_firmness'].tolist() + UK2024_d.get_group('Golden Delicious')['Avg_firmness'].tolist() 
JZ_UK2024_y_firmness = UK2024_a.get_group('Jazz')['Avg_firmness'].tolist() + UK2024_b.get_group('Jazz')['Avg_firmness'].tolist() + UK2024_c.get_group('Jazz')['Avg_firmness'].tolist() + UK2024_d.get_group('Jazz')['Avg_firmness'].tolist()

# All_cultivar_UK2024_y_firmness = BB_UK2024_y_firmness + CX_UK2024_y_firmness + FJ_UK2024_y_firmness + GL_UK2024_y_firmness + GD_UK2024_y_firmness + JZ_UK2024_y_firmness



BB_side_A_y_firmness = NZ2023_a.get_group('Braeburn')['Avg_firmness'].tolist() + NZ2024_a.get_group('Braeburn')['Avg_firmness'].tolist() +UK2024_a.get_group('Braeburn')['Avg_firmness'].tolist() 
CX_side_A_y_firmness = NZ2023_a.get_group("Cox's Orange Pippin")['Avg_firmness'].tolist() + UK2024_a.get_group('Cox')['Avg_firmness'].tolist() 
FJ_side_A_y_firmness = NZ2023_a.get_group('Fuji')['Avg_firmness'].tolist() + NZ2024_a.get_group('Fuji')['Avg_firmness'].tolist() +UK2024_a.get_group('Fuji')['Avg_firmness'].tolist() 
GL_side_A_y_firmness = NZ2023_a.get_group('Gala')['Avg_firmness'].tolist() + NZ2024_a.get_group('Gala')['Avg_firmness'].tolist() +UK2024_a.get_group('Gala')['Avg_firmness'].tolist() 
GD_side_A_y_firmness = NZ2023_a.get_group('Golden Delicious')['Avg_firmness'].tolist() + NZ2024_a.get_group('Golden Delicious')['Avg_firmness'].tolist() +UK2024_a.get_group('Golden Delicious')['Avg_firmness'].tolist() 
JZ_side_A_y_firmness = UK2024_a.get_group('Jazz')['Avg_firmness'].tolist()

# %%
# Create y files (maturity data) - Starch percentage

# NZ2023
BB_NZ2023_y_starch = NZ2023_a.get_group('Braeburn')['Starch'].tolist() + NZ2023_b.get_group('Braeburn')['Starch'].tolist() + NZ2023_c.get_group('Braeburn')['Starch'].tolist() + NZ2023_d.get_group('Braeburn')['Starch'].tolist() 
CX_NZ2023_y_starch = NZ2023_a.get_group("Cox's Orange Pippin")['Starch'].tolist() + NZ2023_b.get_group("Cox's Orange Pippin")['Starch'].tolist() + NZ2023_c.get_group("Cox's Orange Pippin")['Starch'].tolist() + NZ2023_d.get_group("Cox's Orange Pippin")['Starch'].tolist() 
FJ_NZ2023_y_starch = NZ2023_a.get_group('Fuji')['Starch'].tolist() + NZ2023_b.get_group('Fuji')['Starch'].tolist() + NZ2023_c.get_group('Fuji')['Starch'].tolist() + NZ2023_d.get_group('Fuji')['Starch'].tolist() 
GL_NZ2023_y_starch = NZ2023_a.get_group('Gala')['Starch'].tolist() + NZ2023_b.get_group('Gala')['Starch'].tolist() + NZ2023_c.get_group('Gala')['Starch'].tolist() + NZ2023_d.get_group('Gala')['Starch'].tolist() 
GD_NZ2023_y_starch = NZ2023_a.get_group('Golden Delicious')['Starch'].tolist() + NZ2023_b.get_group('Golden Delicious')['Starch'].tolist() + NZ2023_c.get_group('Golden Delicious')['Starch'].tolist() + NZ2023_d.get_group('Golden Delicious')['Starch'].tolist() 

# All_cultivar_NZ2023_y_starch = BB_NZ2023_y_starch + CX_NZ2023_y_starch + FJ_NZ2023_y_starch + GL_NZ2023_y_starch + GD_NZ2023_y_starch


#NZ2024
BB_NZ2024_y_starch = NZ2024_a.get_group('Braeburn')['Starch'].tolist() + NZ2024_b.get_group('Braeburn')['Starch'].tolist() + NZ2024_c.get_group('Braeburn')['Starch'].tolist() + NZ2024_d.get_group('Braeburn')['Starch'].tolist() 
FJ_NZ2024_y_starch = NZ2024_a.get_group('Fuji')['Starch'].tolist() + NZ2024_b.get_group('Fuji')['Starch'].tolist() + NZ2024_c.get_group('Fuji')['Starch'].tolist() + NZ2024_d.get_group('Fuji')['Starch'].tolist() 
GL_NZ2024_y_starch = NZ2024_a.get_group('Gala')['Starch'].tolist() + NZ2024_b.get_group('Gala')['Starch'].tolist() + NZ2024_c.get_group('Gala')['Starch'].tolist() + NZ2024_d.get_group('Gala')['Starch'].tolist() 
GD_NZ2024_y_starch = NZ2024_a.get_group('Golden Delicious')['Starch'].tolist() + NZ2024_b.get_group('Golden Delicious')['Starch'].tolist() + NZ2024_c.get_group('Golden Delicious')['Starch'].tolist() + NZ2024_d.get_group('Golden Delicious')['Starch'].tolist() 

# All_cultivar_NZ2024 = Braeburn_NZ2024 + Cox_NZ2024 + Fuji_NZ2024 + Gala_NZ2024 + Golden_Delicious_NZ2024
# All_cultivar_NZ2024_y_starch = BB_NZ2024_y_starch + FJ_NZ2024_y_starch + GL_NZ2024_y_starch + GD_NZ2024_y_starch


# UK2024
BB_UK2024_y_starch = UK2024_a.get_group('Braeburn')['Starch'].tolist() + UK2024_b.get_group('Braeburn')['Starch'].tolist() + UK2024_c.get_group('Braeburn')['Starch'].tolist() + UK2024_d.get_group('Braeburn')['Starch'].tolist() 
CX_UK2024_y_starch = UK2024_a.get_group('Cox')['Starch'].tolist() + UK2024_b.get_group('Cox')['Starch'].tolist() + UK2024_c.get_group('Cox')['Starch'].tolist() + UK2024_d.get_group('Cox')['Starch'].tolist() 
FJ_UK2024_y_starch = UK2024_a.get_group('Fuji')['Starch'].tolist() + UK2024_b.get_group('Fuji')['Starch'].tolist() + UK2024_c.get_group('Fuji')['Starch'].tolist() + UK2024_d.get_group('Fuji')['Starch'].tolist() 
GL_UK2024_y_starch = UK2024_a.get_group('Gala')['Starch'].tolist() + UK2024_b.get_group('Gala')['Starch'].tolist() + UK2024_c.get_group('Gala')['Starch'].tolist() + UK2024_d.get_group('Gala')['Starch'].tolist() 
GD_UK2024_y_starch = UK2024_a.get_group('Golden Delicious')['Starch'].tolist() + UK2024_b.get_group('Golden Delicious')['Starch'].tolist() + UK2024_c.get_group('Golden Delicious')['Starch'].tolist() + UK2024_d.get_group('Golden Delicious')['Starch'].tolist() 
JZ_UK2024_y_starch = UK2024_a.get_group('Jazz')['Starch'].tolist() + UK2024_b.get_group('Jazz')['Starch'].tolist() + UK2024_c.get_group('Jazz')['Starch'].tolist() + UK2024_d.get_group('Jazz')['Starch'].tolist()

# All_cultivar_UK2024_y_starch = BB_UK2024_y_starch + CX_UK2024_y_starch + FJ_UK2024_y_starch + GL_UK2024_y_starch + GD_UK2024_y_starch + JZ_UK2024_y_starch


BB_side_A_y_starch = NZ2023_a.get_group('Braeburn')['Starch'].tolist() + NZ2024_a.get_group('Braeburn')['Starch'].tolist() +UK2024_a.get_group('Braeburn')['Starch'].tolist() 
CX_side_A_y_starch = NZ2023_a.get_group("Cox's Orange Pippin")['Starch'].tolist() + UK2024_a.get_group('Cox')['Starch'].tolist() 
FJ_side_A_y_starch = NZ2023_a.get_group('Fuji')['Starch'].tolist() + NZ2024_a.get_group('Fuji')['Starch'].tolist() +UK2024_a.get_group('Fuji')['Starch'].tolist() 
GL_side_A_y_starch = NZ2023_a.get_group('Gala')['Starch'].tolist() + NZ2024_a.get_group('Gala')['Starch'].tolist() +UK2024_a.get_group('Gala')['Starch'].tolist() 
GD_side_A_y_starch = NZ2023_a.get_group('Golden Delicious')['Starch'].tolist() + NZ2024_a.get_group('Golden Delicious')['Starch'].tolist() +UK2024_a.get_group('Golden Delicious')['Starch'].tolist() 
JZ_side_A_y_starch = UK2024_a.get_group('Jazz')['Starch'].tolist()

# %%
# print(max(All_cultivar_UK2024_y_starch))

# %%
# Create y files (maturity data) - Brix

# NZ2023
BB_NZ2023_y_brix = NZ2023_a.get_group('Braeburn')['Brix'].tolist() + NZ2023_b.get_group('Braeburn')['Brix'].tolist() + NZ2023_c.get_group('Braeburn')['Brix'].tolist() + NZ2023_d.get_group('Braeburn')['Brix'].tolist() 
CX_NZ2023_y_brix = NZ2023_a.get_group("Cox's Orange Pippin")['Brix'].tolist() + NZ2023_b.get_group("Cox's Orange Pippin")['Brix'].tolist() + NZ2023_c.get_group("Cox's Orange Pippin")['Brix'].tolist() + NZ2023_d.get_group("Cox's Orange Pippin")['Brix'].tolist() 
FJ_NZ2023_y_brix = NZ2023_a.get_group('Fuji')['Brix'].tolist() + NZ2023_b.get_group('Fuji')['Brix'].tolist() + NZ2023_c.get_group('Fuji')['Brix'].tolist() + NZ2023_d.get_group('Fuji')['Brix'].tolist() 
GL_NZ2023_y_brix = NZ2023_a.get_group('Gala')['Brix'].tolist() + NZ2023_b.get_group('Gala')['Brix'].tolist() + NZ2023_c.get_group('Gala')['Brix'].tolist() + NZ2023_d.get_group('Gala')['Brix'].tolist() 
GD_NZ2023_y_brix = NZ2023_a.get_group('Golden Delicious')['Brix'].tolist() + NZ2023_b.get_group('Golden Delicious')['Brix'].tolist() + NZ2023_c.get_group('Golden Delicious')['Brix'].tolist() + NZ2023_d.get_group('Golden Delicious')['Brix'].tolist() 

# All_cultivar_NZ2023_y_brix = BB_NZ2023_y_brix + CX_NZ2023_y_brix + FJ_NZ2023_y_brix + GL_NZ2023_y_brix + GD_NZ2023_y_brix


#NZ2024
BB_NZ2024_y_brix = NZ2024_a.get_group('Braeburn')['Brix'].tolist() + NZ2024_b.get_group('Braeburn')['Brix'].tolist() + NZ2024_c.get_group('Braeburn')['Brix'].tolist() + NZ2024_d.get_group('Braeburn')['Brix'].tolist() 
FJ_NZ2024_y_brix = NZ2024_a.get_group('Fuji')['Brix'].tolist() + NZ2024_b.get_group('Fuji')['Brix'].tolist() + NZ2024_c.get_group('Fuji')['Brix'].tolist() + NZ2024_d.get_group('Fuji')['Brix'].tolist() 
GL_NZ2024_y_brix = NZ2024_a.get_group('Gala')['Brix'].tolist() + NZ2024_b.get_group('Gala')['Brix'].tolist() + NZ2024_c.get_group('Gala')['Brix'].tolist() + NZ2024_d.get_group('Gala')['Brix'].tolist() 
GD_NZ2024_y_brix = NZ2024_a.get_group('Golden Delicious')['Brix'].tolist() + NZ2024_b.get_group('Golden Delicious')['Brix'].tolist() + NZ2024_c.get_group('Golden Delicious')['Brix'].tolist() + NZ2024_d.get_group('Golden Delicious')['Brix'].tolist() 

# All_cultivar_NZ2024 = Braeburn_NZ2024 + Cox_NZ2024 + Fuji_NZ2024 + Gala_NZ2024 + Golden_Delicious_NZ2024
# All_cultivar_NZ2024_y_brix = BB_NZ2024_y_brix + FJ_NZ2024_y_brix + GL_NZ2024_y_brix + GD_NZ2024_y_brix


#UK2024
BB_UK2024_y_brix = UK2024_a.get_group('Braeburn')['Brix'].tolist() + UK2024_b.get_group('Braeburn')['Brix'].tolist() + UK2024_c.get_group('Braeburn')['Brix'].tolist() + UK2024_d.get_group('Braeburn')['Brix'].tolist() 
CX_UK2024_y_brix = UK2024_a.get_group('Cox')['Brix'].tolist() + UK2024_b.get_group('Cox')['Brix'].tolist() + UK2024_c.get_group('Cox')['Brix'].tolist() + UK2024_d.get_group('Cox')['Brix'].tolist() 
FJ_UK2024_y_brix = UK2024_a.get_group('Fuji')['Brix'].tolist() + UK2024_b.get_group('Fuji')['Brix'].tolist() + UK2024_c.get_group('Fuji')['Brix'].tolist() + UK2024_d.get_group('Fuji')['Brix'].tolist() 
GL_UK2024_y_brix = UK2024_a.get_group('Gala')['Brix'].tolist() + UK2024_b.get_group('Gala')['Brix'].tolist() + UK2024_c.get_group('Gala')['Brix'].tolist() + UK2024_d.get_group('Gala')['Brix'].tolist() 
GD_UK2024_y_brix = UK2024_a.get_group('Golden Delicious')['Brix'].tolist() + UK2024_b.get_group('Golden Delicious')['Brix'].tolist() + UK2024_c.get_group('Golden Delicious')['Brix'].tolist() + UK2024_d.get_group('Golden Delicious')['Brix'].tolist() 
JZ_UK2024_y_brix = UK2024_a.get_group('Jazz')['Brix'].tolist() + UK2024_b.get_group('Jazz')['Brix'].tolist() + UK2024_c.get_group('Jazz')['Brix'].tolist() + UK2024_d.get_group('Jazz')['Brix'].tolist()

# All_cultivar_UK2024_y_brix = BB_UK2024_y_brix + CX_UK2024_y_brix + FJ_UK2024_y_brix + GL_UK2024_y_brix + GD_UK2024_y_brix + JZ_UK2024_y_brix



# Side A only
BB_side_A_y_brix = NZ2023_a.get_group('Braeburn')['Brix'].tolist() + NZ2024_a.get_group('Braeburn')['Brix'].tolist() +UK2024_a.get_group('Braeburn')['Brix'].tolist() 
CX_side_A_y_brix = NZ2023_a.get_group("Cox's Orange Pippin")['Brix'].tolist() + UK2024_a.get_group('Cox')['Brix'].tolist() 
FJ_side_A_y_brix = NZ2023_a.get_group('Fuji')['Brix'].tolist() + NZ2024_a.get_group('Fuji')['Brix'].tolist() +UK2024_a.get_group('Fuji')['Brix'].tolist() 
GL_side_A_y_brix = NZ2023_a.get_group('Gala')['Brix'].tolist() + NZ2024_a.get_group('Gala')['Brix'].tolist() +UK2024_a.get_group('Gala')['Brix'].tolist() 
GD_side_A_y_brix = NZ2023_a.get_group('Golden Delicious')['Brix'].tolist() + NZ2024_a.get_group('Golden Delicious')['Brix'].tolist() +UK2024_a.get_group('Golden Delicious')['Brix'].tolist() 
JZ_side_A_y_brix = UK2024_a.get_group('Jazz')['Brix'].tolist() 


### All 3 variables in y
vars = ["Brix", "Avg_firmness", "Starch"]

# NZ2023
BB_NZ2023_y_3_var = pd.concat([NZ2023_a.get_group('Braeburn')[vars] , NZ2023_b.get_group('Braeburn')[vars] , NZ2023_c.get_group('Braeburn')[vars] , NZ2023_d.get_group('Braeburn')[vars] ])
CX_NZ2023_y_3_var = pd.concat([NZ2023_a.get_group("Cox's Orange Pippin")[vars] , NZ2023_b.get_group("Cox's Orange Pippin")[vars] , NZ2023_c.get_group("Cox's Orange Pippin")[vars] , NZ2023_d.get_group("Cox's Orange Pippin")[vars] ])
FJ_NZ2023_y_3_var = pd.concat([NZ2023_a.get_group('Fuji')[vars] , NZ2023_b.get_group('Fuji')[vars] , NZ2023_c.get_group('Fuji')[vars] , NZ2023_d.get_group('Fuji')[vars] ])
GL_NZ2023_y_3_var = pd.concat([NZ2023_a.get_group('Gala')[vars] , NZ2023_b.get_group('Gala')[vars] , NZ2023_c.get_group('Gala')[vars] , NZ2023_d.get_group('Gala')[vars] ])
GD_NZ2023_y_3_var = pd.concat([NZ2023_a.get_group('Golden Delicious')[vars] , NZ2023_b.get_group('Golden Delicious')[vars] , NZ2023_c.get_group('Golden Delicious')[vars] , NZ2023_d.get_group('Golden Delicious')[vars] ])

#NZ2024
BB_NZ2024_y_3_var = pd.concat([NZ2024_a.get_group('Braeburn')[vars] , NZ2024_b.get_group('Braeburn')[vars] , NZ2024_c.get_group('Braeburn')[vars] , NZ2024_d.get_group('Braeburn')[vars] ])
FJ_NZ2024_y_3_var = pd.concat([NZ2024_a.get_group('Fuji')[vars] , NZ2024_b.get_group('Fuji')[vars] , NZ2024_c.get_group('Fuji')[vars] , NZ2024_d.get_group('Fuji')[vars] ])
GL_NZ2024_y_3_var = pd.concat([NZ2024_a.get_group('Gala')[vars] , NZ2024_b.get_group('Gala')[vars] , NZ2024_c.get_group('Gala')[vars] , NZ2024_d.get_group('Gala')[vars] ])
GD_NZ2024_y_3_var = pd.concat([NZ2024_a.get_group('Golden Delicious')[vars] , NZ2024_b.get_group('Golden Delicious')[vars] , NZ2024_c.get_group('Golden Delicious')[vars] , NZ2024_d.get_group('Golden Delicious')[vars] ])

#UK2024
BB_UK2024_y_3_var = pd.concat([UK2024_a.get_group('Braeburn')[vars] , UK2024_b.get_group('Braeburn')[vars] , UK2024_c.get_group('Braeburn')[vars] , UK2024_d.get_group('Braeburn')[vars] ])
CX_UK2024_y_3_var = pd.concat([UK2024_a.get_group('Cox')[vars] , UK2024_b.get_group('Cox')[vars] , UK2024_c.get_group('Cox')[vars] , UK2024_d.get_group('Cox')[vars] ])
FJ_UK2024_y_3_var = pd.concat([UK2024_a.get_group('Fuji')[vars] , UK2024_b.get_group('Fuji')[vars] , UK2024_c.get_group('Fuji')[vars] , UK2024_d.get_group('Fuji')[vars] ])
GL_UK2024_y_3_var = pd.concat([UK2024_a.get_group('Gala')[vars] , UK2024_b.get_group('Gala')[vars] , UK2024_c.get_group('Gala')[vars] , UK2024_d.get_group('Gala')[vars] ])
GD_UK2024_y_3_var = pd.concat([UK2024_a.get_group('Golden Delicious')[vars] , UK2024_b.get_group('Golden Delicious')[vars] , UK2024_c.get_group('Golden Delicious')[vars] , UK2024_d.get_group('Golden Delicious')[vars] ])
JZ_UK2024_y_3_var = pd.concat([UK2024_a.get_group('Jazz')[vars] , UK2024_b.get_group('Jazz')[vars] , UK2024_c.get_group('Jazz')[vars] , UK2024_d.get_group('Jazz')[vars]])

# %%
print(BB_NZ2023_y_3_var.describe())
# Out:
#             Brix  Avg_firmness  Starch
# count  188.00000    188.000000   188.0
# mean    12.40766      8.107979    55.0
# ...          ...           ...     ...
# 75%     13.00000      8.640000    80.0
# max     15.35000      9.640000    89.0
#
# [8 rows x 3 columns]

# %%
print(CX_NZ2023_y_brix[105:115])

for element in CX_NZ2023_y_brix[105:115]:
    print(f"Element: {element}, Type: {type(element)}")
# Out:
# [13.53, 12.92, 11.72, 12.84, 13.55, 13.08, 12.57, 13.07, 11.51, 12.16]
# Element: 13.53, Type: <class 'float'>
# Element: 12.92, Type: <class 'float'>
# Element: 11.72, Type: <class 'float'>
# Element: 12.84, Type: <class 'float'>
# Element: 13.55, Type: <class 'float'>
# Element: 13.08, Type: <class 'float'>
# Element: 12.57, Type: <class 'float'>
# Element: 13.07, Type: <class 'float'>
# Element: 11.51, Type: <class 'float'>
# Element: 12.16, Type: <class 'float'>

# %%
if img_size == 30:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/30px_files/'
elif img_size == 50:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/50px_files/'

np.save(f'{y_file_path}BB_NZ2023_y_brix.npy', BB_NZ2023_y_brix)
np.save(f'{y_file_path}CX_NZ2023_y_brix.npy', CX_NZ2023_y_brix)
np.save(f'{y_file_path}FJ_NZ2023_y_brix.npy', FJ_NZ2023_y_brix)
np.save(f'{y_file_path}GL_NZ2023_y_brix.npy', GL_NZ2023_y_brix)
np.save(f'{y_file_path}GD_NZ2023_y_brix.npy', GD_NZ2023_y_brix)
# np.save(f'{y_file_path}All_cultivar_NZ2023_y_brix.npy', All_cultivar_NZ2023_y_brix)
np.save(f'{y_file_path}BB_NZ2024_y_brix.npy', BB_NZ2024_y_brix)
np.save(f'{y_file_path}FJ_NZ2024_y_brix.npy', FJ_NZ2024_y_brix)
np.save(f'{y_file_path}GL_NZ2024_y_brix.npy', GL_NZ2024_y_brix)
np.save(f'{y_file_path}GD_NZ2024_y_brix.npy', GD_NZ2024_y_brix)
# np.save(f'{y_file_path}All_cultivar_NZ2024_y_brix.npy', All_cultivar_NZ2024_y_brix)
np.save(f'{y_file_path}BB_UK2024_y_brix.npy', BB_UK2024_y_brix)
np.save(f'{y_file_path}CX_UK2024_y_brix.npy', CX_UK2024_y_brix)
np.save(f'{y_file_path}FJ_UK2024_y_brix.npy', FJ_UK2024_y_brix)
np.save(f'{y_file_path}GL_UK2024_y_brix.npy', GL_UK2024_y_brix)
np.save(f'{y_file_path}GD_UK2024_y_brix.npy', GD_UK2024_y_brix)
np.save(f'{y_file_path}JZ_UK2024_y_brix.npy', JZ_UK2024_y_brix)
# np.save(f'{y_file_path}All_cultivar_UK2024_y_brix.npy', All_cultivar_UK2024_y_brix)


np.save('BB_side_A_y_brix.npy', BB_side_A_y_brix)
np.save('CX_side_A_y_brix.npy', CX_side_A_y_brix)
np.save('FJ_side_A_y_brix.npy', FJ_side_A_y_brix)
np.save('GL_side_A_y_brix.npy', GL_side_A_y_brix)
np.save('GD_side_A_y_brix.npy', GD_side_A_y_brix)
np.save('JZ_side_A_y_brix.npy', JZ_side_A_y_brix)

# %%
if img_size == 30:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/30px_files/'
elif img_size == 50:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/50px_files/'

np.save(f'{y_file_path}BB_NZ2023_y_firmness.npy', BB_NZ2023_y_firmness)
np.save(f'{y_file_path}CX_NZ2023_y_firmness.npy', CX_NZ2023_y_firmness)
np.save(f'{y_file_path}FJ_NZ2023_y_firmness.npy', FJ_NZ2023_y_firmness)
np.save(f'{y_file_path}GL_NZ2023_y_firmness.npy', GL_NZ2023_y_firmness)
np.save(f'{y_file_path}GD_NZ2023_y_firmness.npy', GD_NZ2023_y_firmness)
# np.save(f'{y_file_path}All_cultivar_NZ2023_y_firmness.npy', All_cultivar_NZ2023_y_firmness)
np.save(f'{y_file_path}BB_NZ2024_y_firmness.npy', BB_NZ2024_y_firmness)
np.save(f'{y_file_path}FJ_NZ2024_y_firmness.npy', FJ_NZ2024_y_firmness)
np.save(f'{y_file_path}GL_NZ2024_y_firmness.npy', GL_NZ2024_y_firmness)
np.save(f'{y_file_path}GD_NZ2024_y_firmness.npy', GD_NZ2024_y_firmness)
# np.save(f'{y_file_path}All_cultivar_NZ2024_y_firmness.npy', All_cultivar_NZ2024_y_firmness)
np.save(f'{y_file_path}BB_UK2024_y_firmness.npy', BB_UK2024_y_firmness)
np.save(f'{y_file_path}CX_UK2024_y_firmness.npy', CX_UK2024_y_firmness)
np.save(f'{y_file_path}FJ_UK2024_y_firmness.npy', FJ_UK2024_y_firmness)
np.save(f'{y_file_path}GL_UK2024_y_firmness.npy', GL_UK2024_y_firmness)
np.save(f'{y_file_path}GD_UK2024_y_firmness.npy', GD_UK2024_y_firmness)
np.save(f'{y_file_path}JZ_UK2024_y_firmness.npy', JZ_UK2024_y_firmness)
# np.save(f'{y_file_path}All_cultivar_UK2024_y_firmness.npy', All_cultivar_UK2024_y_firmness)

np.save('BB_side_A_y_firmness.npy', BB_side_A_y_firmness)
np.save('CX_side_A_y_firmness.npy', CX_side_A_y_firmness)
np.save('FJ_side_A_y_firmness.npy', FJ_side_A_y_firmness)
np.save('GL_side_A_y_firmness.npy', GL_side_A_y_firmness)
np.save('GD_side_A_y_firmness.npy', GD_side_A_y_firmness)
np.save('JZ_side_A_y_firmness.npy', JZ_side_A_y_firmness)

# %%
if img_size == 30:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/30px_files/'
elif img_size == 50:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/50px_files/'


np.save(f'{y_file_path}BB_NZ2023_y_starch.npy', BB_NZ2023_y_starch)
np.save(f'{y_file_path}CX_NZ2023_y_starch.npy', CX_NZ2023_y_starch)
np.save(f'{y_file_path}FJ_NZ2023_y_starch.npy', FJ_NZ2023_y_starch)
np.save(f'{y_file_path}GL_NZ2023_y_starch.npy', GL_NZ2023_y_starch)
np.save(f'{y_file_path}GD_NZ2023_y_starch.npy', GD_NZ2023_y_starch)
# np.save(f'{y_file_path}All_cultivar_NZ2023_y_starch.npy', All_cultivar_NZ2023_y_starch)
np.save(f'{y_file_path}BB_NZ2024_y_starch.npy', BB_NZ2024_y_starch)
np.save(f'{y_file_path}FJ_NZ2024_y_starch.npy', FJ_NZ2024_y_starch)
np.save(f'{y_file_path}GL_NZ2024_y_starch.npy', GL_NZ2024_y_starch)
np.save(f'{y_file_path}GD_NZ2024_y_starch.npy', GD_NZ2024_y_starch)
# np.save(f'{y_file_path}All_cultivar_NZ2024_y_starch.npy', All_cultivar_NZ2024_y_starch)
np.save(f'{y_file_path}BB_UK2024_y_starch.npy', BB_UK2024_y_starch)
np.save(f'{y_file_path}CX_UK2024_y_starch.npy', CX_UK2024_y_starch)
np.save(f'{y_file_path}FJ_UK2024_y_starch.npy', FJ_UK2024_y_starch)
np.save(f'{y_file_path}GL_UK2024_y_starch.npy', GL_UK2024_y_starch)
np.save(f'{y_file_path}GD_UK2024_y_starch.npy', GD_UK2024_y_starch)
np.save(f'{y_file_path}JZ_UK2024_y_starch.npy', JZ_UK2024_y_starch)
# np.save(f'{y_file_path}All_cultivar_UK2024_y_starch.npy', All_cultivar_UK2024_y_starch)


np.save('BB_side_A_y_starch.npy', BB_side_A_y_starch)
np.save('CX_side_A_y_starch.npy', CX_side_A_y_starch)
np.save('FJ_side_A_y_starch.npy', FJ_side_A_y_starch)
np.save('GL_side_A_y_starch.npy', GL_side_A_y_starch)
np.save('GD_side_A_y_starch.npy', GD_side_A_y_starch)
np.save('JZ_side_A_y_starch.npy', JZ_side_A_y_starch)

# %%
print(BB_UK2024_y_firmness[:3])
# Out:
# [10.456170047875675, 10.55763181106698, 10.626462655442992]

# %%
if img_size == 30:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/30px_files/'
elif img_size == 50:
    y_file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/y_files_May2025/50px_files/'

# 3_var_folder 

var3_folder = 'all_3_variables/'

np.save(f'{y_file_path}{var3_folder}BB_NZ2023_y_3_var.npy', BB_NZ2023_y_3_var)
np.save(f'{y_file_path}{var3_folder}CX_NZ2023_y_3_var.npy', CX_NZ2023_y_3_var)
np.save(f'{y_file_path}{var3_folder}FJ_NZ2023_y_3_var.npy', FJ_NZ2023_y_3_var)
np.save(f'{y_file_path}{var3_folder}GL_NZ2023_y_3_var.npy', GL_NZ2023_y_3_var)
np.save(f'{y_file_path}{var3_folder}GD_NZ2023_y_3_var.npy', GD_NZ2023_y_3_var)
np.save(f'{y_file_path}{var3_folder}BB_NZ2024_y_3_var.npy', BB_NZ2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}FJ_NZ2024_y_3_var.npy', FJ_NZ2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}GL_NZ2024_y_3_var.npy', GL_NZ2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}GD_NZ2024_y_3_var.npy', GD_NZ2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}BB_UK2024_y_3_var.npy', BB_UK2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}CX_UK2024_y_3_var.npy', CX_UK2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}FJ_UK2024_y_3_var.npy', FJ_UK2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}GL_UK2024_y_3_var.npy', GL_UK2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}GD_UK2024_y_3_var.npy', GD_UK2024_y_3_var)
np.save(f'{y_file_path}{var3_folder}JZ_UK2024_y_3_var.npy', JZ_UK2024_y_3_var)
