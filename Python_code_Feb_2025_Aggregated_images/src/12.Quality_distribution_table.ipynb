# %% [markdown]
# ## Quality distribution table for each cultivar ###

# %%
# Create table: for each cultivar get the number of apples, mean, max and min Avg_firmness, brix and starch and the std of each attribute
# The table is saved in a latex file format
# save table in html format

import pandas as pd
import numpy as np
import os

pickle_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/Tensors/'

# Load data
files_NZ2023_a =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_a.pkl')
files_NZ2023_b =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_b.pkl')
files_NZ2023_c =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_c.pkl')
files_NZ2023_d =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2023_d.pkl')
NZ2023_a = files_NZ2023_a.rename(columns={'Image_folder_A': 'Image_folder', 'image_filename_A': 'image_filename', 'Spectral_folder_A': 'Spectral_folder'})
NZ2023_b = files_NZ2023_b.rename(columns={'Image_folder_B': 'Image_folder', 'image_filename_B': 'image_filename', 'Spectral_folder_B': 'Spectral_folder'})
NZ2023_c = files_NZ2023_c.rename(columns={'Image_folder_C': 'Image_folder', 'image_filename_C': 'image_filename', 'Spectral_folder_C': 'Spectral_folder'})
NZ2023_d = files_NZ2023_d.rename(columns={'Image_folder_D': 'Image_folder', 'image_filename_D': 'image_filename', 'Spectral_folder_D': 'Spectral_folder'})

files_NZ2024_a =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_a.pkl')
files_NZ2024_b =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_b.pkl')
files_NZ2024_c =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_c.pkl')
files_NZ2024_d =  pd.read_pickle(f'{pickle_path}aggregated_files_NZ2024_d.pkl')
NZ2024_a = files_NZ2024_a.rename(columns={'Image_folder_A': 'Image_folder', 'image_filename_A': 'image_filename', 'Spectral_folder_A': 'Spectral_folder'})
NZ2024_b = files_NZ2024_b.rename(columns={'Image_folder_B': 'Image_folder', 'image_filename_B': 'image_filename', 'Spectral_folder_B': 'Spectral_folder'})
NZ2024_c = files_NZ2024_c.rename(columns={'Image_folder_C': 'Image_folder', 'image_filename_C': 'image_filename', 'Spectral_folder_C': 'Spectral_folder'})
NZ2024_d = files_NZ2024_d.rename(columns={'Image_folder_D': 'Image_folder', 'image_filename_D': 'image_filename', 'Spectral_folder_D': 'Spectral_folder'})

files_UK2024_a =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_a.pkl')
files_UK2024_b =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_b.pkl')
files_UK2024_c =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_c.pkl')
files_UK2024_d =  pd.read_pickle(f'{pickle_path}aggregated_files_UK2024_d.pkl')
UK2024_a = files_UK2024_a.rename(columns={'Image_folder_A': 'Image_folder', 'image_filename_A': 'image_filename', 'Spectral_folder_A': 'Spectral_folder'})
UK2024_b = files_UK2024_b.rename(columns={'Image_folder_B': 'Image_folder', 'image_filename_B': 'image_filename', 'Spectral_folder_B': 'Spectral_folder'})
UK2024_c = files_UK2024_c.rename(columns={'Image_folder_C': 'Image_folder', 'image_filename_C': 'image_filename', 'Spectral_folder_C': 'Spectral_folder'})
UK2024_d = files_UK2024_d.rename(columns={'Image_folder_D': 'Image_folder', 'image_filename_D': 'image_filename', 'Spectral_folder_D': 'Spectral_folder'})

# All data
# All_data = pd.concat([NZ2023_a, NZ2023_b, NZ2023_c, NZ2023_d, NZ2024_a, NZ2024_b, NZ2024_c, NZ2024_d, UK2024_a, UK2024_b, UK2024_c, UK2024_d])
# print(All_data.head())

# %%
All_data['Cultivar'] = All_data['Cultivar'].str.replace('Cox', "Cox's Orange Pippin")

# %% [markdown]
# ### Quality distribution table ###

# %%
# # Load files

# # Load data
# # data_NZ2023_final_a = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2023_a_final2.pkl')
# # data_NZ2023_final_b = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2023_b_final2.pkl')
# # data_NZ2023_final_c = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2023_c_final2.pkl')
# # data_NZ2023_final_d = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2023_d_final2.pkl')
# # data_NZ2024_final_a = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2024_a_final2.pkl')
# # data_NZ2024_final_b = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2024_b_final2.pkl')
# # data_NZ2024_final_c = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2024_c_final2.pkl')
# # data_NZ2024_final_d = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_NZ2024_d_final2.pkl')
# # data_UK2024_final_a = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_UK2024_a_final2.pkl')
# # data_UK2024_final_b = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_UK2024_b_final2.pkl')
# # data_UK2024_final_c = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_UK2024_c_final2.pkl')
# # data_UK2024_final_d = pd.read_pickle('/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/data_UK2024_d_final2.pkl')

# data_NZ2023_final_a['Season'] = 'NZ2023'
# data_NZ2023_final_b['Season'] = 'NZ2023'
# data_NZ2023_final_c['Season'] = 'NZ2023'
# data_NZ2023_final_d['Season'] = 'NZ2024'
# data_NZ2024_final_a['Season'] = 'NZ2024'
# data_NZ2024_final_b['Season'] = 'NZ2024'
# data_NZ2024_final_c['Season'] = 'NZ2024'
# data_NZ2024_final_d['Season'] = 'NZ2024'
# data_UK2024_final_a['Season'] = 'UK2024'
# data_UK2024_final_b['Season'] = 'UK2024'
# data_UK2024_final_c['Season'] = 'UK2024'
# data_UK2024_final_d['Season'] = 'UK2024'


# # All data
# data_final = pd.concat([data_NZ2023_final_a, data_NZ2023_final_b, data_NZ2023_final_c, data_NZ2023_final_d, data_NZ2024_final_a, data_NZ2024_final_b, data_NZ2024_final_c, data_NZ2024_final_d, data_UK2024_final_a, data_UK2024_final_b, data_UK2024_final_c, data_UK2024_final_d])


# data_final['Cultivar'] = data_final['Cultivar'].str.replace("Cox's Orange Pippin", "Cox")
# data_final['Cultivar'] = data_final['Cultivar'].str.replace("Cox", "Cox's Orange Pippin")

# print(All_data.head())
# Out:
#                                         Image_folder      image_filename  \
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
#
#        ID  Number  Firmness1  Firmness2   Brix  Starch  Starch2    Streif  \
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
#
#    Avg_firmness Cultivar                                      sorted_tensor  \
# ...

# %%
print(NZ2023_a.head())
# Out:
#                                         Image_folder      image_filename  \
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 1  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 2  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 3  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 4  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
#
#        ID  Number  Firmness1  Firmness2   Brix  Starch  Starch2    Streif  \
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 1  Fuji_2     2.0       7.32       8.84  14.04    43.0      8.0  4.603989
# 2  Fuji_3     3.0       8.02       8.86  11.53    80.0      4.0  2.928014
# 3  Fuji_4     4.0       6.36       7.82  12.18    63.0      7.0  4.074713
# 4  Fuji_5     5.0       8.13       7.38  12.10    45.0      8.0  5.127273
#
#    Avg_firmness Cultivar                                    Spectral_folder  \
# ...

# %%
# Only get maturity columns

NZ2023_a = NZ2023_a.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2023_b = NZ2023_b.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2023_c = NZ2023_c.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2023_d = NZ2023_d.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2024_a = NZ2024_a.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2024_b = NZ2024_b.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2024_c = NZ2024_c.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
NZ2024_d = NZ2024_d.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
UK2024_a = UK2024_a.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
UK2024_b = UK2024_b.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
UK2024_c = UK2024_c.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])
UK2024_d = UK2024_d.filter(['ID', 'Number','Brix', 'Starch', 'Streif', 'Avg_firmness', 'Cultivar', 'Count'])

NZ2023_a['Season'] = 'NZ2023'
NZ2023_b['Season'] = 'NZ2023'
NZ2023_c['Season'] = 'NZ2023'
NZ2023_d['Season'] = 'NZ2023'
NZ2024_a['Season'] = 'NZ2024'
NZ2024_b['Season'] = 'NZ2024'
NZ2024_c['Season'] = 'NZ2024'
NZ2024_d['Season'] = 'NZ2024'
UK2024_a['Season'] = 'UK2024'
UK2024_b['Season'] = 'UK2024'
UK2024_c['Season'] = 'UK2024'
UK2024_d['Season'] = 'UK2024'

All_data = pd.concat([NZ2023_a, NZ2023_b, NZ2023_c, NZ2023_d, NZ2024_a, NZ2024_b, NZ2024_c, NZ2024_d, UK2024_a, UK2024_b, UK2024_c, UK2024_d])

# %%
All_data_unique = All_data.drop_duplicates(subset=['ID'])

# %%
print(len(All_data_unique))
# Out:
# 4991

# %%
All_data_unique['Cultivar'] = All_data_unique['Cultivar'].str.replace(r"\bCox\b(?!'s Orange Pippin)", "Cox's Orange Pippin", regex = True)
# Out:
# /tmp/ipykernel_3510959/3250545454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   All_data_unique['Cultivar'] = All_data_unique['Cultivar'].str.replace(r"\bCox\b(?!'s Orange Pippin)", "Cox's Orange Pippin", regex = True)

# %%
Counts = All_data_unique.groupby(['Cultivar']).size()

print(Counts)
# Out:
# Cultivar
# Braeburn                945
# Cox's Orange Pippin     361
# Fuji                   1562
# Gala                   1291
# Golden Delicious        813
# Jazz                     19
# dtype: int64

# %%
save_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/Pickle_files/Result_tables/'
# Get mean, max, min and std for each cultivar
columns_order = ['Count', 'Mean Firmness', 'Max Firmness', 'Min Firmness', 'Std Firmness']

data_final_grouped_firmness = All_data.groupby(['Cultivar', 'Season']).agg({'Avg_firmness': ['mean', 'max', 'min', 'std']})


data_final_grouped_firmness.rename(columns ={'Avg_firmness':'Firmness'})
data_final_grouped_firmness = data_final_grouped_firmness.map(lambda x: round(x, 2))
data_final_grouped_firmness['Number'] = Counts
# print(data_final_grouped_firmness.columns)
columns_order =[(      'Number',     ''),
                ('Avg_firmness', 'mean'),
            ('Avg_firmness',  'max'),
            ('Avg_firmness',  'min'),
            ('Avg_firmness',  'std')
            ]
           
data_final_grouped_firmness = data_final_grouped_firmness[columns_order]
# print(data_final_grouped_firmness.head())

data_final_grouped_brix = All_data.groupby(['Cultivar', 'Season']).agg({'Brix': ['mean', 'max', 'min', 'std']})
data_final_grouped_brix = data_final_grouped_brix.map(lambda x: round(x, 2))
# print(data_final_grouped_brix.columns)
# print(data_final_grouped_brix.head())

data_final_grouped_starch = All_data.groupby(['Cultivar', 'Season']).agg({'Starch': ['mean', 'max', 'min', 'std']})
data_final_grouped_starch = data_final_grouped_starch.map(lambda x: round(x, 2))
# print(data_final_grouped_starch.columns)
# print(data_final_grouped_starch.head())

data_final_grouped_all3 = All_data.groupby(['Cultivar', 'Season']).agg({'Avg_firmness': ['mean', 'max', 'min', 'std'], 'Brix': ['mean', 'max', 'min', 'std'], 'Starch': ['mean', 'max', 'min', 'std']})
data_final_grouped_all3.rename(columns ={'Avg_firmness':'Firmness'})
data_final_grouped_all3 = data_final_grouped_all3.map(lambda x: round(x, 2))
data_final_grouped_all3['Number'] = Counts
print(data_final_grouped_all3.head())
columns_order = [
    ('Number', ''),
    ('Avg_firmness', 'mean'),
    ('Avg_firmness', 'max'),
    ('Avg_firmness', 'min'),
    ('Avg_firmness', 'std'),
    ('Brix', 'mean'),
    ('Brix', 'max'),
    ('Brix', 'min'),
    ('Brix', 'std'),
    ('Starch', 'mean'),
    ('Starch', 'max'),
    ('Starch', 'min'),
    ('Starch', 'std')
]
data_final_grouped_all3 = data_final_grouped_all3[columns_order]
print(data_final_grouped_all3.head())


data_final_grouped_firmness.to_latex(f'{save_path}/quality_table_firmness.tex')
data_final_grouped_brix.to_latex(f'{save_path}/quality_table_brix.tex')
data_final_grouped_starch.to_latex(f'{save_path}/quality_table_starch.tex')
data_final_grouped_all3.to_latex(f'{save_path}/quality_table_all3.tex')

data_final_grouped_firmness.to_csv(f'{save_path}/quality_table_firmness.csv')
data_final_grouped_brix.to_csv(f'{save_path}/quality_table_brix.csv')
data_final_grouped_starch.to_csv(f'{save_path}/quality_table_starch.csv')
data_final_grouped_all3.to_csv(f'{save_path}/quality_table_all3.csv')
# Out:
#                     Avg_firmness                      Brix                     \
#                             mean    max   min   std   mean    max   min   std
# Cultivar
# Braeburn                    9.51  13.72  6.54  0.98  11.07  17.39   7.9  1.13
# Cox's Orange Pippin         8.26  12.95  2.97  1.33  12.28  18.71   7.7  1.69
# Fuji                        7.71  13.07  5.51  1.03  14.09  19.60  10.3  1.66
# Gala                        8.27  12.29  4.13  1.02  11.96  19.18   8.0  1.42
# Golden Delicious            7.30  10.72  4.94  0.75  11.88  16.57   8.7  1.27
#
#                     Starch                     Number
#                       mean    max   min    std
# Cultivar
# Braeburn             77.73  100.0  18.0  19.71    NaN
# Cox's Orange Pippin  65.76  100.0   2.0  20.39    NaN
# Fuji                 38.67   99.0   0.0  23.99    NaN
# Gala                 55.27  100.0   0.0  29.18    NaN
# Golden Delicious     30.66  100.0   0.0  29.83    NaN
# ...

# %% [markdown]
# #### standard deviation of firmness between sides of apples

# %%
print(data_final.head())
# Out:
#                                        Image_folder_A    image_filename_A  \
# 0   20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 6   20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_006.png
# 12  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_010.png
# 18  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_014.png
# 24  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_018.png
#
#          ID  Number  Firmness1  Firmness2   Brix  Starch  Starch2    Streif  \
# 0    Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 6    Fuji_7     7.0       6.34       6.92  12.67    33.0      9.0  4.709550
# 12  Fuji_13    13.0       7.09       7.61  12.40    25.0      9.0  5.334677
# 18  Fuji_19    19.0       7.80       9.14  12.26    69.0      6.0  4.145188
# 24  Fuji_25    25.0       7.42       7.25  13.92    17.0     10.0  5.269397
#
# ...

# %%
firmness_data = data_final[['ID','Number', 'Firmness1', 'Firmness2', 'Cultivar', 'Season']]

# %%
print(firmness_data.head())
# Out:
#          ID  Number  Firmness1  Firmness2 Cultivar  Season
# 0    Fuji_1     1.0       6.38       6.23     Fuji  NZ2023
# 6    Fuji_7     7.0       6.34       6.92     Fuji  NZ2023
# 12  Fuji_13    13.0       7.09       7.61     Fuji  NZ2023
# 18  Fuji_19    19.0       7.80       9.14     Fuji  NZ2023
# 24  Fuji_25    25.0       7.42       7.25     Fuji  NZ2023

# %%
# Get standard deviation of Firmness1 and Firmness2 for each season
firmness_data['firmness_sd'] = firmness_data[['Firmness1', 'Firmness2']].std(axis=1)
# print(firmness_data.head())

firmness_season = firmness_data.groupby('Season').agg(mean_firmness_std=('firmness_sd', 'mean'), std_firmness_std = ('firmness_sd', 'std')).reset_index()
firmness_season['mean_firmness_std'] = firmness_season['mean_firmness_std'].round(2)
print(firmness_season.head())

firmness_cultivar = firmness_data.groupby('Cultivar').agg(mean_firmness_std=('firmness_sd', 'mean'), std_firmness_std = ('firmness_sd', 'std')).reset_index()
firmness_cultivar['mean_firmness_std'] = firmness_cultivar['mean_firmness_std'].round(2)
print(firmness_cultivar)

firmness_cultivar_season = firmness_data.groupby(['Cultivar', 'Season']).agg(mean_firmness_std=('firmness_sd', 'mean'), std_firmness_std = ('firmness_sd', 'std')).reset_index()
firmness_cultivar_season['mean_firmness_std'] = firmness_cultivar_season['mean_firmness_std'].round(2)
print(firmness_cultivar_season)

overall_firmness_mean = firmness_data[['Firmness1', 'Firmness2']].std(axis=1).mean()
overall_firmness_std = firmness_data[['Firmness1', 'Firmness2']].std(axis=1).std()
overall_firmness_max = firmness_data[['Firmness1', 'Firmness2']].std(axis=1).max()
overall_firmness_min = firmness_data[['Firmness1', 'Firmness2']].std(axis=1).min()

print(f"Overall standard deviation of Firmness1 and Firmness2: {overall_firmness_mean:.2f}+/- {overall_firmness_std:.2f}")
print(f"Overall max standard deviation of Firmness1 and Firmness2: {overall_firmness_max:.2f}")
print(f"Overall min standard deviation of Firmness1 and Firmness2: {overall_firmness_min:.2f}")



# firmness_data_grouped = firmness_data.groupby(['Season']).agg({'Firmness1': ['mean', 'std'], 'Firmness2': ['mean', 'std']})
# firmness_data_grouped = firmness_data_grouped.map(lambda x: round(x, 2))

# Get standard deviation of Firmness1 and Firmness2 for each cultivar


# Get overall standard deviation of Firmness1 and Firmness2
# Out:
#    Season  mean_firmness_std  std_firmness_std
# 0  NZ2023               0.48          0.386093
# 1  NZ2024               0.46          0.378492
# 2  UK2024               0.45          0.361714
#               Cultivar  mean_firmness_std  std_firmness_std
# 0             Braeburn               0.49          0.422822
# 1  Cox's Orange Pippin               0.54          0.385360
# 2                 Fuji               0.48          0.393607
# 3                 Gala               0.44          0.325171
# 4     Golden Delicious               0.40          0.345260
# 5                 Jazz               0.56          0.226790
#                Cultivar  Season  mean_firmness_std  std_firmness_std
# 0              Braeburn  NZ2023               0.45          0.403818
# 1              Braeburn  NZ2024               0.54          0.473762
# 2              Braeburn  UK2024               0.46          0.394023
# 3   Cox's Orange Pippin  NZ2023               0.52          0.362085
# ...

# %%
print(firmness_cultivar)
# Out:
#               Cultivar  mean_firmness_std
# 0             Braeburn               0.49
# 1  Cox's Orange Pippin               0.54
# 2                 Fuji               0.48
# 3                 Gala               0.44
# 4     Golden Delicious               0.40
# 5                 Jazz               0.56
