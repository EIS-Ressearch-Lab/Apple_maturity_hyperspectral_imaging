# %%
import numpy as np
import pandas as pd

# %%
file_path = '/home/ht21074/Auto_box_apples/Auto_box_apples/Source_folder/csv_files/All_data_csv/'

data_NZ2023 = pd.read_csv(f'{file_path}data_NZ2023.csv')
data_NZ2024 = pd.read_csv(f'{file_path}data_NZ2024.csv')
data_UK2024 = pd.read_csv(f'{file_path}data_UK2024.csv')

# %%
print(data_NZ2023.head(5))
print(data_NZ2024.head(5))
print(data_UK2024.head(5))
# Out:
#                      Date Site Cultivar  Number  Firmness1  Firmness2   Brix  \
# 0  Tuesday, 28 March 2023  PFR     Fuji     1.0       6.38       6.23  12.43
# 1  Tuesday, 28 March 2023  PFR     Fuji     2.0       7.32       8.84  14.04
# 2  Tuesday, 28 March 2023  PFR     Fuji     3.0       8.02       8.86  11.53
# 3  Tuesday, 28 March 2023  PFR     Fuji     4.0       6.36       7.82  12.18
# 4  Tuesday, 28 March 2023  PFR     Fuji     5.0       8.13       7.38  12.10
#
#    Starch                                     Image_folder_A  \
# 0    50.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 1    43.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 2    80.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 3    63.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 4    45.0  20230328 Fuji PFR orchard early pick/2023-03-2...
#
#                                       Image_folder_B  ...    image_filename_A  \
# ...

# %%
data_spec_NZ2023 = data_NZ2023
data_spec_NZ2024 = data_NZ2024
data_spec_UK2024 = data_UK2024

# %%
print(data_spec_NZ2023.head(5))
# Out:
#                      Date Site Cultivar  Number  Firmness1  Firmness2   Brix  \
# 0  Tuesday, 28 March 2023  PFR     Fuji     1.0       6.38       6.23  12.43
# 1  Tuesday, 28 March 2023  PFR     Fuji     2.0       7.32       8.84  14.04
# 2  Tuesday, 28 March 2023  PFR     Fuji     3.0       8.02       8.86  11.53
# 3  Tuesday, 28 March 2023  PFR     Fuji     4.0       6.36       7.82  12.18
# 4  Tuesday, 28 March 2023  PFR     Fuji     5.0       8.13       7.38  12.10
#
#    Starch                                     Image_folder_A  \
# 0    50.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 1    43.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 2    80.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 3    63.0  20230328 Fuji PFR orchard early pick/2023-03-2...
# 4    45.0  20230328 Fuji PFR orchard early pick/2023-03-2...
#
#                                       Image_folder_B  ...    image_filename_A  \
# ...

# %%
data_NZ2023_a_spec = data_spec_NZ2023[['Image_folder_A', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_NZ2023_b_spec = data_spec_NZ2023[['Image_folder_B', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_NZ2023_c_spec = data_spec_NZ2023[['Image_folder_C', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_NZ2023_d_spec = data_spec_NZ2023[['Image_folder_D', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()

data_NZ2024_a_spec = data_spec_NZ2024[['Image_folder_A', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_NZ2024_b_spec = data_spec_NZ2024[['Image_folder_B', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_NZ2024_c_spec = data_spec_NZ2024[['Image_folder_C', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_NZ2024_d_spec = data_spec_NZ2024[['Image_folder_D', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()


data_UK2024_a_spec = data_spec_UK2024[['Image_folder_A', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_UK2024_b_spec = data_spec_UK2024[['Image_folder_B', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_UK2024_c_spec = data_spec_UK2024[['Image_folder_C', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()
data_UK2024_d_spec = data_spec_UK2024[['Image_folder_D', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Avg_firmness', 'Starch2', 'Cultivar']].copy()

print(len(data_NZ2023_a_spec))
print(len(data_NZ2023_b_spec))
print(len(data_NZ2023_c_spec))
print(len(data_NZ2023_d_spec))

print(len(data_NZ2024_a_spec))
print(len(data_NZ2024_b_spec))
print(len(data_NZ2024_c_spec))
print(len(data_NZ2024_d_spec))

print(len(data_UK2024_a_spec))
print(len(data_UK2024_b_spec))
print(len(data_UK2024_c_spec))
print(len(data_UK2024_d_spec))
# Out:
# 1701
# 1701
# 1701
# 1701
# 1409
# 1409
# 1409
# 1409
# 2646
# 2646
# 2646
# 2646

# %%
data_NZ2023_a = data_NZ2023[['Image_folder_A', 'image_filename_A', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_NZ2023_b = data_NZ2023[['Image_folder_B', 'image_filename_B', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_NZ2023_c = data_NZ2023[['Image_folder_C', 'image_filename_C', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_NZ2023_d = data_NZ2023[['Image_folder_D', 'image_filename_D', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()

data_NZ2024_a = data_NZ2024[['Image_folder_A', 'image_filename_A', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_NZ2024_b = data_NZ2024[['Image_folder_B', 'image_filename_B', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_NZ2024_c = data_NZ2024[['Image_folder_C', 'image_filename_C', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_NZ2024_d = data_NZ2024[['Image_folder_D', 'image_filename_D', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()

data_UK2024_a = data_UK2024[['Image_folder_A', 'image_filename_A', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_UK2024_b = data_UK2024[['Image_folder_B', 'image_filename_B', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_UK2024_c = data_UK2024[['Image_folder_C', 'image_filename_C', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()
data_UK2024_d = data_UK2024[['Image_folder_D', 'image_filename_D', "ID", 'Number', 'Firmness1','Firmness2','Brix','Starch', 'Starch2', 'Streif', "Avg_firmness", 'Cultivar']].copy()

print(data_NZ2023_a.head())
print(data_NZ2024_b.tail())
print(data_UK2024_a.tail())
# Out:
#                                       Image_folder_A    image_filename_A  \
# 0  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 1  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 2  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 3  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
# 4  20230328 Fuji PFR orchard early pick/2023-03-2...  2023-03-28_002.png
#
#        ID  Number  Firmness1  Firmness2   Brix  Starch  Starch2    Streif  \
# 0  Fuji_1     1.0       6.38       6.23  12.43    50.0      8.0  4.057924
# 1  Fuji_2     2.0       7.32       8.84  14.04    43.0      8.0  4.603989
# 2  Fuji_3     3.0       8.02       8.86  11.53    80.0      4.0  2.928014
# 3  Fuji_4     4.0       6.36       7.82  12.18    63.0      7.0  4.074713
# 4  Fuji_5     5.0       8.13       7.38  12.10    45.0      8.0  5.127273
#
#    Avg_firmness Cultivar
# 0         6.305     Fuji
# 1         8.080     Fuji
# ...

# %%
# Check for empty rows

non_strings_folder = data_NZ2024[~data_NZ2024['Image_folder_A'].apply(lambda x: isinstance(x, str))]
non_strings_filename = data_NZ2024[~data_NZ2024['image_filename_A'].apply(lambda x: isinstance(x, str))]

print("Non-string values in 'Image_folder_A':")
print(non_strings_folder)

print("Non-string values in 'image_filename_A':")
print(non_strings_filename)
# Out:
# Non-string values in 'Image_folder_A':
# Empty DataFrame
# Columns: [index, Date, Number, Site, Cultivar, Firmness1, Firmness2, Brix, Starch, Image_folder_A, Image_folder_B, Image_folder_C, Image_folder_D, ID, image_num_A, image_filename_A, image_num_B, image_filename_B, image_num_C, image_filename_C, image_num_D, image_filename_D, Avg_firmness, Starch2, Streif]
# Index: []
#
# [0 rows x 25 columns]
# Non-string values in 'image_filename_A':
# Empty DataFrame
# Columns: [index, Date, Number, Site, Cultivar, Firmness1, Firmness2, Brix, Starch, Image_folder_A, Image_folder_B, Image_folder_C, Image_folder_D, ID, image_num_A, image_filename_A, image_num_B, image_filename_B, image_num_C, image_filename_C, image_num_D, image_filename_D, Avg_firmness, Starch2, Streif]
# Index: []
#
# [0 rows x 25 columns]

# %%
# drop na rows and reset index

print(len(data_NZ2023_a))
print(len(data_NZ2024_a))
print(len(data_UK2024_a))

data_NZ2023_a_na = data_NZ2023_a.dropna()
data_NZ2023_b_na = data_NZ2023_b.dropna()
data_NZ2023_c_na = data_NZ2023_c.dropna()
data_NZ2023_d_na = data_NZ2023_d.dropna()
data_NZ2023_a_na = data_NZ2023_a_na.reset_index(drop=True)
data_NZ2023_b_na = data_NZ2023_b_na.reset_index(drop=True)
data_NZ2023_c_na = data_NZ2023_c_na.reset_index(drop=True)
data_NZ2023_d_na = data_NZ2023_d_na.reset_index(drop=True)


data_NZ2024_a_na = data_NZ2024_a.dropna()
data_NZ2024_b_na = data_NZ2024_b.dropna()
data_NZ2024_c_na = data_NZ2024_c.dropna()
data_NZ2024_d_na = data_NZ2024_d.dropna()
data_NZ2024_a_na = data_NZ2024_a_na.reset_index(drop=True)
data_NZ2024_b_na = data_NZ2024_b_na.reset_index(drop=True)
data_NZ2024_c_na = data_NZ2024_c_na.reset_index(drop=True)
data_NZ2024_d_na = data_NZ2024_d_na.reset_index(drop=True)


data_UK2024_a_na = data_UK2024_a.dropna()
data_UK2024_b_na = data_UK2024_b.dropna()
data_UK2024_c_na = data_UK2024_c.dropna()
data_UK2024_d_na = data_UK2024_d.dropna()
data_UK2024_a_na = data_UK2024_a_na.reset_index(drop=True)
data_UK2024_b_na = data_UK2024_b_na.reset_index(drop=True)
data_UK2024_c_na = data_UK2024_c_na.reset_index(drop=True)
data_UK2024_d_na = data_UK2024_d_na.reset_index(drop=True)


print(len(data_NZ2023_a_na))
print(len(data_NZ2024_a_na))
print(len(data_UK2024_a_na))
# Out:
# 1701
# 1409
# 2646
# 1701
# 1409
# 2646

# %%
# Save data to csv


data_NZ2023_a_na.to_csv(f'{file_path}data_NZ2023_a_na.csv', index = False)
data_NZ2023_b_na.to_csv(f'{file_path}data_NZ2023_b_na.csv', index = False)
data_NZ2023_c_na.to_csv(f'{file_path}data_NZ2023_c_na.csv', index = False)
data_NZ2023_d_na.to_csv(f'{file_path}data_NZ2023_d_na.csv', index = False)
data_NZ2024_a_na.to_csv(f'{file_path}data_NZ2024_a_na.csv', index = False)
data_NZ2024_b_na.to_csv(f'{file_path}data_NZ2024_b_na.csv', index = False)
data_NZ2024_c_na.to_csv(f'{file_path}data_NZ2024_c_na.csv', index = False)
data_NZ2024_d_na.to_csv(f'{file_path}data_NZ2024_d_na.csv', index = False)
data_UK2024_a_na.to_csv(f'{file_path}data_UK2024_a_na.csv', index = False)
data_UK2024_b_na.to_csv(f'{file_path}data_UK2024_b_na.csv', index = False)
data_UK2024_c_na.to_csv(f'{file_path}data_UK2024_c_na.csv', index = False)
data_UK2024_d_na.to_csv(f'{file_path}data_UK2024_d_na.csv', index = False)

# %%
print(data_NZ2023_a_na.describe())
# Out:
#             Number    Firmness1    Firmness2         Brix       Starch  \
# count  1701.000000  1701.000000  1701.000000  1701.000000  1701.000000
# mean     81.968254     7.705638     7.713445    13.603204    44.013521
# std      79.201464     1.154582     1.152185     1.627579    29.474343
# min       1.000000     3.830000     3.860000     9.260000     0.000000
# 25%      27.000000     6.960000     6.940000    12.480000    18.000000
# 50%      55.000000     7.590000     7.550000    13.490000    37.000000
# 75%     108.000000     8.320000     8.380000    14.570000    71.000000
# max     360.000000    15.300000    13.930000    18.860000   100.000000
#
#            Starch2       Streif  Avg_firmness
# count  1701.000000  1701.000000   1701.000000
# mean      7.476778     4.118373      7.709541
# std       2.715352     1.387764      1.065978
# min       1.000000     0.544781      4.130000
# 25%       5.000000     3.245935      7.015000
# 50%       9.000000     4.471963      7.580000
# ...
